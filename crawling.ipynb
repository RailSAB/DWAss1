# %%
from typing import Iterable

from matplotlib.pyplot import title
from scrapy import Request
# !pip install scrapy
# Out:
# Requirement already satisfied: scrapy in c:\users\rails\appdata\local\programs\python\python312\lib\site-packages (2.12.0)
# Requirement already satisfied: Twisted>=21.7.0 in c:\users\rails\appdata\local\programs\python\python312\lib\site-packages (from scrapy) (24.11.0)
# Requirement already satisfied: cryptography>=37.0.0 in c:\users\rails\appdata\local\programs\python\python312\lib\site-packages (from scrapy) (44.0.1)
# Requirement already satisfied: cssselect>=0.9.1 in c:\users\rails\appdata\local\programs\python\python312\lib\site-packages (from scrapy) (1.2.0)
# Requirement already satisfied: itemloaders>=1.0.1 in c:\users\rails\appdata\local\programs\python\python312\lib\site-packages (from scrapy) (1.3.2)
# Requirement already satisfied: parsel>=1.5.0 in c:\users\rails\appdata\local\programs\python\python312\lib\site-packages (from scrapy) (1.10.0)
# Requirement already satisfied: pyOpenSSL>=22.0.0 in c:\users\rails\appdata\local\programs\python\python312\lib\site-packages (from scrapy) (25.0.0)
# Requirement already satisfied: queuelib>=1.4.2 in c:\users\rails\appdata\local\programs\python\python312\lib\site-packages (from scrapy) (1.7.0)
# Requirement already satisfied: service-identity>=18.1.0 in c:\users\rails\appdata\local\programs\python\python312\lib\site-packages (from scrapy) (24.2.0)
# Requirement already satisfied: w3lib>=1.17.0 in c:\users\rails\appdata\local\programs\python\python312\lib\site-packages (from scrapy) (2.3.1)
# Requirement already satisfied: zope.interface>=5.1.0 in c:\users\rails\appdata\local\programs\python\python312\lib\site-packages (from scrapy) (7.2)
# Requirement already satisfied: protego>=0.1.15 in c:\users\rails\appdata\local\programs\python\python312\lib\site-packages (from scrapy) (0.4.0)
# Requirement already satisfied: itemadapter>=0.1.0 in c:\users\rails\appdata\local\programs\python\python312\lib\site-packages (from scrapy) (0.11.0)
# Requirement already satisfied: packaging in c:\users\rails\appdata\local\programs\python\python312\lib\site-packages (from scrapy) (24.1)
# Requirement already satisfied: tldextract in c:\users\rails\appdata\local\programs\python\python312\lib\site-packages (from scrapy) (5.1.3)
# Requirement already satisfied: lxml>=4.6.0 in c:\users\rails\appdata\local\programs\python\python312\lib\site-packages (from scrapy) (5.3.1)
# Requirement already satisfied: defusedxml>=0.7.1 in c:\users\rails\appdata\local\programs\python\python312\lib\site-packages (from scrapy) (0.7.1)
# Requirement already satisfied: PyDispatcher>=2.0.5 in c:\users\rails\appdata\local\programs\python\python312\lib\site-packages (from scrapy) (2.0.7)
# Requirement already satisfied: cffi>=1.12 in c:\users\rails\appdata\local\programs\python\python312\lib\site-packages (from cryptography>=37.0.0->scrapy) (1.17.0)
# Requirement already satisfied: jmespath>=0.9.5 in c:\users\rails\appdata\local\programs\python\python312\lib\site-packages (from itemloaders>=1.0.1->scrapy) (1.0.1)
# Requirement already satisfied: typing-extensions>=4.9 in c:\users\rails\appdata\local\programs\python\python312\lib\site-packages (from pyOpenSSL>=22.0.0->scrapy) (4.12.2)
# Requirement already satisfied: attrs>=19.1.0 in c:\users\rails\appdata\local\programs\python\python312\lib\site-packages (from service-identity>=18.1.0->scrapy) (24.2.0)
# Requirement already satisfied: pyasn1 in c:\users\rails\appdata\local\programs\python\python312\lib\site-packages (from service-identity>=18.1.0->scrapy) (0.6.1)
# Requirement already satisfied: pyasn1-modules in c:\users\rails\appdata\local\programs\python\python312\lib\site-packages (from service-identity>=18.1.0->scrapy) (0.4.1)
# Requirement already satisfied: automat>=24.8.0 in c:\users\rails\appdata\local\programs\python\python312\lib\site-packages (from Twisted>=21.7.0->scrapy) (24.8.1)
# Requirement already satisfied: constantly>=15.1 in c:\users\rails\appdata\local\programs\python\python312\lib\site-packages (from Twisted>=21.7.0->scrapy) (23.10.4)
# Requirement already satisfied: hyperlink>=17.1.1 in c:\users\rails\appdata\local\programs\python\python312\lib\site-packages (from Twisted>=21.7.0->scrapy) (21.0.0)
# Requirement already satisfied: incremental>=24.7.0 in c:\users\rails\appdata\local\programs\python\python312\lib\site-packages (from Twisted>=21.7.0->scrapy) (24.7.2)
# Requirement already satisfied: setuptools in c:\users\rails\appdata\local\programs\python\python312\lib\site-packages (from zope.interface>=5.1.0->scrapy) (74.0.0)
# Requirement already satisfied: idna in c:\users\rails\appdata\local\programs\python\python312\lib\site-packages (from tldextract->scrapy) (3.8)
# Requirement already satisfied: requests>=2.1.0 in c:\users\rails\appdata\local\programs\python\python312\lib\site-packages (from tldextract->scrapy) (2.32.3)
# Requirement already satisfied: requests-file>=1.4 in c:\users\rails\appdata\local\programs\python\python312\lib\site-packages (from tldextract->scrapy) (2.1.0)
# Requirement already satisfied: filelock>=3.0.8 in c:\users\rails\appdata\local\programs\python\python312\lib\site-packages (from tldextract->scrapy) (3.17.0)
# Requirement already satisfied: pycparser in c:\users\rails\appdata\local\programs\python\python312\lib\site-packages (from cffi>=1.12->cryptography>=37.0.0->scrapy) (2.22)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\rails\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.1.0->tldextract->scrapy) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\rails\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.1.0->tldextract->scrapy) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\rails\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.1.0->tldextract->scrapy) (2024.8.30)
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: C:\Users\rails\AppData\Local\Programs\Python\Python312\python.exe -m pip install --upgrade pip

# %%
from typing import Iterable
import scrapy
from scrapy.crawler import CrawlerProcess
import json
from scrapy import Request

class WikipediaFilmSpider(scrapy.Spider):
    name = 'wikipedia_film'
    start_urls = ['https://en.wikipedia.org/wiki/']

    def start_requests(self) -> Iterable[Request]:
        url = 'https://en.wikipedia.org/wiki/List_of_highest-grossing_films'
        yield scrapy.Request(url, callback=self.page_parse)

    def page_parse(self, response):
        seen_movies = set()
        tables = response.xpath('//table[contains(@class, "wikitable") and contains(@class, "plainrowheaders")]')

        i = 0
        for table in tables:
            i += 1
            if i > 3:
                break

            rows = table.xpath('.//tbody/tr')

            before = 1925
            for row in rows:
                if i == 3:
                    link = row.xpath('.//td[1]//a/@href').get()
                    name = row.xpath('.//td[1]//a/text()').get()
                    year = row.xpath('.//th[@scope="row"]//a/text()').get()
                    if not year:
                        year = before
                    else:
                        before = year
                else:
                    link = row.xpath('.//th[@scope="row"]//a/@href').get()
                    name = row.xpath('.//th[@scope="row"]//a/text()').get()
                    if i == 1:
                        year = row.xpath('.//td[4]/text()').get()
                    else:
                        year = row.xpath('./td[last()]/text()').get()

                if name and name not in seen_movies:
                    seen_movies.add(name)

                    if link:
                        film_link = 'https://en.wikipedia.org' + link
                        yield scrapy.Request(film_link, callback=self.parse, meta={'name': name, 'link': link, 'year': year})

    def parse(self, response):
        film_data = {}
        film_data['title'] = response.meta['name']
        film_data['link'] = response.meta['link']
        film_data['release_year'] = int(response.meta['year'])

        directors = response.xpath('//th[contains(text(), "Directed by")]/following-sibling::td//a/text()').getall()
        film_data['directors'] = directors if directors else None

        box_office = response.xpath(
            '//th[contains(text(), "Box office")]/following-sibling::td//text()[normalize-space()]').get()
        film_data['box_office'] = box_office.strip().replace("\xa0", " ") if box_office else None

        country = response.xpath('//th[contains(text(), "Country")]/following-sibling::td//text()').get()
        if country:
            film_data['country'] = country.strip()
        else:
            countries = response.xpath(
                '//th[contains(text(), "Countries")]/following-sibling::td//li/text()').getall()
            film_data['countries'] = countries

        yield film_data


process = CrawlerProcess(settings={
    "FEEDS": {
        "films.json": {"format": "json"},
    },
})
process.crawl(WikipediaFilmSpider)
process.start()
# Out:
# 2025-02-24 13:30:22 [scrapy.utils.log] INFO: Scrapy 2.12.0 started (bot: scrapybot)
# 2025-02-24 13:30:22 [scrapy.utils.log] INFO: Versions: lxml 5.3.1.0, libxml2 2.11.7, cssselect 1.2.0, parsel 1.10.0, w3lib 2.3.1, Twisted 24.11.0, Python 3.12.3 (tags/v3.12.3:f6650f9, Apr  9 2024, 14:05:25) [MSC v.1938 64 bit (AMD64)], pyOpenSSL 25.0.0 (OpenSSL 3.4.1 11 Feb 2025), cryptography 44.0.1, Platform Windows-11-10.0.26100-SP0
# 2025-02-24 13:30:22 [scrapy.addons] INFO: Enabled addons:
# []
# 2025-02-24 13:30:22 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.selectreactor.SelectReactor
# 2025-02-24 13:30:22 [scrapy.extensions.telnet] INFO: Telnet Password: 9da3865f97793862
# 2025-02-24 13:30:22 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.feedexport.FeedExporter',
#  'scrapy.extensions.logstats.LogStats']
# 2025-02-24 13:30:22 [scrapy.crawler] INFO: Overridden settings:
# {}
# 2025-02-24 13:30:23 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2025-02-24 13:30:23 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2025-02-24 13:30:23 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2025-02-24 13:30:23 [scrapy.core.engine] INFO: Spider opened
# 2025-02-24 13:30:23 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2025-02-24 13:30:23 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2025-02-24 13:30:24 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/List_of_highest-grossing_films> (referer: None)
# 2025-02-24 13:30:24 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Avatar_(2009_film)> (referer: https://en.wikipedia.org/wiki/List_of_highest-grossing_films)
# 2025-02-24 13:30:25 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Star_Wars:_The_Last_Jedi> (referer: https://en.wikipedia.org/wiki/List_of_highest-grossing_films)
# 2025-02-24 13:30:25 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/Avatar_(2009_film)>
# {'title': 'Avatar', 'link': '/wiki/Avatar_(2009_film)', 'release_year': 2009, 'directors': ['James Cameron'], 'box_office': '$2.923 billion', 'countries': ['United Kingdom', 'United States']}
# 2025-02-24 13:30:25 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Deadpool_%26_Wolverine> (referer: https://en.wikipedia.org/wiki/List_of_highest-grossing_films)
# 2025-02-24 13:30:25 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/Star_Wars:_The_Last_Jedi>
# {'title': 'Star Wars: The Last Jedi', 'link': '/wiki/Star_Wars:_The_Last_Jedi', 'release_year': 2017, 'directors': ['Rian Johnson'], 'box_office': '$1.334', 'country': 'United States'}
# 2025-02-24 13:30:25 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Harry_Potter_and_the_Deathly_Hallows_%E2%80%93_Part_2> (referer: https://en.wikipedia.org/wiki/List_of_highest-grossing_films)
# 2025-02-24 13:30:25 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/Deadpool_%26_Wolverine>
# {'title': 'Deadpool & Wolverine', 'link': '/wiki/Deadpool_%26_Wolverine', 'release_year': 2024, 'directors': ['Shawn Levy'], 'box_office': '$1.338 billion', 'country': 'United States'}
# 2025-02-24 13:30:25 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Black_Panther_(film)> (referer: https://en.wikipedia.org/wiki/List_of_highest-grossing_films)
# 2025-02-24 13:30:25 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/The_Fate_of_the_Furious> (referer: https://en.wikipedia.org/wiki/List_of_highest-grossing_films)
# 2025-02-24 13:30:25 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Incredibles_2> (referer: https://en.wikipedia.org/wiki/List_of_highest-grossing_films)
# 2025-02-24 13:30:25 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/Harry_Potter_and_the_Deathly_Hallows_%E2%80%93_Part_2>
# {'title': 'Harry Potter and the Deathly Hallows – Part 2', 'link': '/wiki/Harry_Potter_and_the_Deathly_Hallows_%E2%80%93_Part_2', 'release_year': 2011, 'directors': ['David Yates'], 'box_office': '$1.342 billion', 'countries': ['United Kingdom', 'United States']}
# 2025-02-24 13:30:25 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Minions_(film)> (referer: https://en.wikipedia.org/wiki/List_of_highest-grossing_films)
# 2025-02-24 13:30:25 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Jurassic_World:_Fallen_Kingdom> (referer: https://en.wikipedia.org/wiki/List_of_highest-grossing_films)
# 2025-02-24 13:30:25 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Iron_Man_3> (referer: https://en.wikipedia.org/wiki/List_of_highest-grossing_films)
# 2025-02-24 13:30:25 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Frozen_(2013_film)> (referer: https://en.wikipedia.org/wiki/List_of_highest-grossing_films)
# 2025-02-24 13:30:25 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Beauty_and_the_Beast_(2017_film)> (referer: https://en.wikipedia.org/wiki/List_of_highest-grossing_films)
# 2025-02-24 13:30:25 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/Black_Panther_(film)>
# {'title': 'Black Panther', 'link': '/wiki/Black_Panther_(film)', 'release_year': 2018, 'directors': ['Ryan Coogler'], 'box_office': '$1.35 billion', 'country': 'United States'}
# 2025-02-24 13:30:25 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/The_Fate_of_the_Furious>
# {'title': 'The Fate of the Furious', 'link': '/wiki/The_Fate_of_the_Furious', 'release_year': 2017, 'directors': ['F. Gary Gray'], 'box_office': '$1.236 billion', 'countries': ['United States', 'China']}
# 2025-02-24 13:30:25 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/The_Super_Mario_Bros._Movie> (referer: https://en.wikipedia.org/wiki/List_of_highest-grossing_films)
# 2025-02-24 13:30:25 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Harry_Potter_and_the_Goblet_of_Fire_(film)> (referer: https://en.wikipedia.org/wiki/List_of_highest-grossing_films)
# 2025-02-24 13:30:25 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Pirates_of_the_Caribbean:_At_World%27s_End> (referer: https://en.wikipedia.org/wiki/List_of_highest-grossing_films)
# 2025-02-24 13:30:25 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/Incredibles_2>
# {'title': 'Incredibles 2', 'link': '/wiki/Incredibles_2', 'release_year': 2018, 'directors': ['Brad Bird'], 'box_office': '$1.243 billion', 'country': 'United States'}
# 2025-02-24 13:30:25 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/Minions_(film)>
# {'title': 'Minions', 'link': '/wiki/Minions_(film)', 'release_year': 2015, 'directors': ['Pierre Coffin', 'Kyle Balda'], 'box_office': '$1.159 billion', 'country': 'United States'}
# 2025-02-24 13:30:25 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/Jurassic_World:_Fallen_Kingdom>
# {'title': 'Jurassic World: Fallen Kingdom', 'link': '/wiki/Jurassic_World:_Fallen_Kingdom', 'release_year': 2018, 'directors': ['J. A. Bayona'], 'box_office': '$1.31 billion', 'countries': ['China', 'United States']}
# 2025-02-24 13:30:25 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/Iron_Man_3>
# {'title': 'Iron Man 3', 'link': '/wiki/Iron_Man_3', 'release_year': 2013, 'directors': ['Shane Black'], 'box_office': '$1.266 billion', 'country': 'United States'}
# 2025-02-24 13:30:25 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/Frozen_(2013_film)>
# {'title': 'Frozen', 'link': '/wiki/Frozen_(2013_film)', 'release_year': 2013, 'directors': ['Chris Buck', 'Jennifer Lee'], 'box_office': '$1.280 billion', 'country': 'United States'}
# 2025-02-24 13:30:25 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Avengers:_Age_of_Ultron> (referer: https://en.wikipedia.org/wiki/List_of_highest-grossing_films)
# 2025-02-24 13:30:25 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Barbie_(film)> (referer: https://en.wikipedia.org/wiki/List_of_highest-grossing_films)
# 2025-02-24 13:30:25 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/Beauty_and_the_Beast_(2017_film)>
# {'title': 'Beauty and the Beast', 'link': '/wiki/Beauty_and_the_Beast_(2017_film)', 'release_year': 2017, 'directors': ['Bill Condon'], 'box_office': '$1.266', 'country': 'United States'}
# 2025-02-24 13:30:25 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/The_Dark_Knight> (referer: https://en.wikipedia.org/wiki/List_of_highest-grossing_films)
# 2025-02-24 13:30:25 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/The_Super_Mario_Bros._Movie>
# {'title': 'The Super Mario Bros. Movie', 'link': '/wiki/The_Super_Mario_Bros._Movie', 'release_year': 2023, 'directors': ['Aaron Horvath', 'Michael Jelenic'], 'box_office': '$1.360 billion', 'country': 'United States'}
# 2025-02-24 13:30:25 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/Harry_Potter_and_the_Goblet_of_Fire_(film)>
# {'title': 'Harry Potter and the Goblet of Fire', 'link': '/wiki/Harry_Potter_and_the_Goblet_of_Fire_(film)', 'release_year': 2005, 'directors': ['Mike Newell'], 'box_office': '$897.5 million', 'countries': ['United Kingdom', 'United States']}
# 2025-02-24 13:30:25 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/Pirates_of_the_Caribbean:_At_World%27s_End>
# {'title': "Pirates of the Caribbean: At World's End", 'link': '/wiki/Pirates_of_the_Caribbean:_At_World%27s_End', 'release_year': 2007, 'directors': ['Gore Verbinski'], 'box_office': '$963.4 million', 'country': 'United States'}
# 2025-02-24 13:30:25 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Shrek_2> (referer: https://en.wikipedia.org/wiki/List_of_highest-grossing_films)
# 2025-02-24 13:30:25 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Armageddon_(1998_film)> (referer: https://en.wikipedia.org/wiki/List_of_highest-grossing_films)
# 2025-02-24 13:30:25 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/The_Lord_of_the_Rings:_The_Two_Towers> (referer: https://en.wikipedia.org/wiki/List_of_highest-grossing_films)
# 2025-02-24 13:30:25 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Harry_Potter_and_the_Philosopher%27s_Stone_(film)> (referer: https://en.wikipedia.org/wiki/List_of_highest-grossing_films)
# 2025-02-24 13:30:25 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/Avengers:_Age_of_Ultron>
# {'title': 'Avengers: Age of Ultron', 'link': '/wiki/Avengers:_Age_of_Ultron', 'release_year': 2015, 'directors': ['Joss Whedon'], 'box_office': '$1.405 billion', 'country': 'United States'}
# 2025-02-24 13:30:26 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/Barbie_(film)>
# {'title': 'Barbie', 'link': '/wiki/Barbie_(film)', 'release_year': 2023, 'directors': ['Greta Gerwig'], 'box_office': '$1.446 billion', 'countries': ['United States', 'United Kingdom']}
# 2025-02-24 13:30:26 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Die_Hard_with_a_Vengeance> (referer: https://en.wikipedia.org/wiki/List_of_highest-grossing_films)
# 2025-02-24 13:30:26 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Mission:_Impossible_2> (referer: https://en.wikipedia.org/wiki/List_of_highest-grossing_films)
# 2025-02-24 13:30:26 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Independence_Day_(1996_film)> (referer: https://en.wikipedia.org/wiki/List_of_highest-grossing_films)
# 2025-02-24 13:30:26 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/The_Dark_Knight>
# {'title': 'The Dark Knight', 'link': '/wiki/The_Dark_Knight', 'release_year': 2008, 'directors': ['Christopher Nolan'], 'box_office': '$1.006', 'countries': ['United States', 'United Kingdom']}
# 2025-02-24 13:30:26 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/Shrek_2>
# {'title': 'Shrek 2', 'link': '/wiki/Shrek_2', 'release_year': 2004, 'directors': ['Andrew Adamson', 'Kelly Asbury', 'Conrad Vernon'], 'box_office': '$935.5 million', 'country': 'United States'}
# 2025-02-24 13:30:26 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/Armageddon_(1998_film)>
# {'title': 'Armageddon', 'link': '/wiki/Armageddon_(1998_film)', 'release_year': 1998, 'directors': ['Michael Bay'], 'box_office': '$553.7 million', 'country': 'United States'}
# 2025-02-24 13:30:26 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/Harry_Potter_and_the_Philosopher%27s_Stone_(film)>
# {'title': "Harry Potter and the Philosopher's Stone", 'link': '/wiki/Harry_Potter_and_the_Philosopher%27s_Stone_(film)', 'release_year': 2001, 'directors': ['Chris Columbus'], 'box_office': '$1.026 billion', 'countries': ['United Kingdom', 'United States']}
# 2025-02-24 13:30:26 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/The_Lord_of_the_Rings:_The_Two_Towers>
# {'title': 'The Lord of the Rings: The Two Towers', 'link': '/wiki/The_Lord_of_the_Rings:_The_Two_Towers', 'release_year': 2002, 'directors': ['Peter Jackson'], 'box_office': '$951.6 million', 'countries': ['New Zealand', 'United States']}
# 2025-02-24 13:30:26 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Rain_Man> (referer: https://en.wikipedia.org/wiki/List_of_highest-grossing_films)
# 2025-02-24 13:30:26 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Ghost_(1990_film)> (referer: https://en.wikipedia.org/wiki/List_of_highest-grossing_films)
# 2025-02-24 13:30:26 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Indiana_Jones_and_the_Last_Crusade> (referer: https://en.wikipedia.org/wiki/List_of_highest-grossing_films)
# 2025-02-24 13:30:26 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Toy_Story> (referer: https://en.wikipedia.org/wiki/List_of_highest-grossing_films)
# 2025-02-24 13:30:26 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Frozen_2> (referer: https://en.wikipedia.org/wiki/List_of_highest-grossing_films)
# 2025-02-24 13:30:26 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/Die_Hard_with_a_Vengeance>
# {'title': 'Die Hard with a Vengeance', 'link': '/wiki/Die_Hard_with_a_Vengeance', 'release_year': 1995, 'directors': ['John McTiernan'], 'box_office': '$366.1 million', 'country': 'United States'}
# 2025-02-24 13:30:26 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/Mission:_Impossible_2>
# {'title': 'Mission: Impossible 2', 'link': '/wiki/Mission:_Impossible_2', 'release_year': 2000, 'directors': ['John Woo'], 'box_office': '$546.3 million', 'countries': ['United States', 'Germany']}
# 2025-02-24 13:30:26 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/Independence_Day_(1996_film)>
# {'title': 'Independence Day', 'link': '/wiki/Independence_Day_(1996_film)', 'release_year': 1996, 'directors': ['Roland Emmerich'], 'box_office': '$817.4 million', 'country': 'United States'}
# 2025-02-24 13:30:26 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Fatal_Attraction> (referer: https://en.wikipedia.org/wiki/List_of_highest-grossing_films)
# 2025-02-24 13:30:26 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Terminator_2:_Judgment_Day> (referer: https://en.wikipedia.org/wiki/List_of_highest-grossing_films)
# 2025-02-24 13:30:26 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/Rain_Man>
# {'title': 'Rain Man', 'link': '/wiki/Rain_Man', 'release_year': 1988, 'directors': ['Barry Levinson'], 'box_office': '$354.8', 'country': 'United States'}
# 2025-02-24 13:30:26 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/Ghost_(1990_film)>
# {'title': 'Ghost', 'link': '/wiki/Ghost_(1990_film)', 'release_year': 1990, 'directors': ['Jerry Zucker'], 'box_office': '$505.7 million', 'country': 'United States'}
# 2025-02-24 13:30:26 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/Indiana_Jones_and_the_Last_Crusade>
# {'title': 'Indiana Jones and the Last Crusade', 'link': '/wiki/Indiana_Jones_and_the_Last_Crusade', 'release_year': 1989, 'directors': ['Steven Spielberg'], 'box_office': '$474.2 million', 'country': 'United States'}
# 2025-02-24 13:30:26 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Top_Gun> (referer: https://en.wikipedia.org/wiki/List_of_highest-grossing_films)
# 2025-02-24 13:30:26 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Back_to_the_Future> (referer: https://en.wikipedia.org/wiki/List_of_highest-grossing_films)
# 2025-02-24 13:30:26 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Rocky_II> (referer: https://en.wikipedia.org/wiki/List_of_highest-grossing_films)
# 2025-02-24 13:30:26 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/Toy_Story>
# {'title': 'Toy Story', 'link': '/wiki/Toy_Story', 'release_year': 1995, 'directors': ['John Lasseter'], 'box_office': '$394.4 million', 'country': 'United States'}
# 2025-02-24 13:30:26 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/Frozen_2>
# {'title': 'Frozen 2', 'link': '/wiki/Frozen_2', 'release_year': 2019, 'directors': ['Chris Buck', 'Jennifer Lee'], 'box_office': '$1.453', 'country': 'United States'}
# 2025-02-24 13:30:26 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Ghostbusters> (referer: https://en.wikipedia.org/wiki/List_of_highest-grossing_films)
# 2025-02-24 13:30:26 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Moonraker_(film)> (referer: https://en.wikipedia.org/wiki/List_of_highest-grossing_films)
# 2025-02-24 13:30:26 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Return_of_the_Jedi> (referer: https://en.wikipedia.org/wiki/List_of_highest-grossing_films)
# 2025-02-24 13:30:26 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Grease_(film)> (referer: https://en.wikipedia.org/wiki/List_of_highest-grossing_films)
# 2025-02-24 13:30:26 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/The_Empire_Strikes_Back> (referer: https://en.wikipedia.org/wiki/List_of_highest-grossing_films)
# 2025-02-24 13:30:26 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Raiders_of_the_Lost_Ark> (referer: https://en.wikipedia.org/wiki/List_of_highest-grossing_films)
# 2025-02-24 13:30:26 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/Fatal_Attraction>
# {'title': 'Fatal Attraction', 'link': '/wiki/Fatal_Attraction', 'release_year': 1987, 'directors': ['Adrian Lyne'], 'box_office': '$320.1 million', 'country': 'United States'}
# 2025-02-24 13:30:26 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/Terminator_2:_Judgment_Day>
# {'title': 'Terminator 2: Judgment Day', 'link': '/wiki/Terminator_2:_Judgment_Day', 'release_year': 1991, 'directors': ['James Cameron'], 'box_office': '$519–520.9', 'country': 'United States'}
# 2025-02-24 13:30:26 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/Top_Gun>
# {'title': 'Top Gun', 'link': '/wiki/Top_Gun', 'release_year': 1986, 'directors': ['Tony Scott'], 'box_office': '$357.3 million', 'country': 'United States'}
# 2025-02-24 13:30:26 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/Back_to_the_Future>
# {'title': 'Back to the Future', 'link': '/wiki/Back_to_the_Future', 'release_year': 1985, 'directors': ['Robert Zemeckis'], 'box_office': '$388.8 million', 'country': 'United States'}
# 2025-02-24 13:30:26 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/Rocky_II>
# {'title': 'Rocky II', 'link': '/wiki/Rocky_II', 'release_year': 1979, 'directors': ['Sylvester Stallone'], 'box_office': '$200.1 million', 'country': 'United States'}
# 2025-02-24 13:30:26 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/The_Towering_Inferno> (referer: https://en.wikipedia.org/wiki/List_of_highest-grossing_films)
# 2025-02-24 13:30:26 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/The_Sting> (referer: https://en.wikipedia.org/wiki/List_of_highest-grossing_films)
# 2025-02-24 13:30:26 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Jaws_(film)> (referer: https://en.wikipedia.org/wiki/List_of_highest-grossing_films)
# 2025-02-24 13:30:26 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Rocky> (referer: https://en.wikipedia.org/wiki/List_of_highest-grossing_films)
# 2025-02-24 13:30:26 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/Ghostbusters>
# {'title': 'Ghostbusters', 'link': '/wiki/Ghostbusters', 'release_year': 1984, 'directors': ['Ivan Reitman'], 'box_office': '$370 million', 'country': 'United States'}
# 2025-02-24 13:30:26 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/Moonraker_(film)>
# {'title': 'Moonraker', 'link': '/wiki/Moonraker_(film)', 'release_year': 1979, 'directors': ['Lewis Gilbert'], 'box_office': '$210.3 million', 'countries': []}
# 2025-02-24 13:30:26 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/Return_of_the_Jedi>
# {'title': 'Return of the Jedi', 'link': '/wiki/Return_of_the_Jedi', 'release_year': 1983, 'directors': ['Richard Marquand'], 'box_office': '$482 million', 'country': 'United States'}
# 2025-02-24 13:30:26 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/Grease_(film)>
# {'title': 'Grease', 'link': '/wiki/Grease_(film)', 'release_year': 1978, 'directors': ['Randal Kleiser'], 'box_office': '$396.3 million', 'country': 'United States'}
# 2025-02-24 13:30:26 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/The_Empire_Strikes_Back>
# {'title': 'The Empire Strikes Back', 'link': '/wiki/The_Empire_Strikes_Back', 'release_year': 1980, 'directors': ['Irvin Kershner'], 'box_office': '$538–549', 'country': 'United States'}
# 2025-02-24 13:30:26 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/Raiders_of_the_Lost_Ark>
# {'title': 'Raiders of the Lost Ark', 'link': '/wiki/Raiders_of_the_Lost_Ark', 'release_year': 1981, 'directors': ['Steven Spielberg'], 'box_office': '$389.9', 'country': 'United States'}
# 2025-02-24 13:30:26 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Fiddler_on_the_Roof_(film)> (referer: https://en.wikipedia.org/wiki/List_of_highest-grossing_films)
# 2025-02-24 13:30:26 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/The_French_Connection_(film)> (referer: https://en.wikipedia.org/wiki/List_of_highest-grossing_films)
# 2025-02-24 13:30:26 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Diamonds_Are_Forever_(film)> (referer: https://en.wikipedia.org/wiki/List_of_highest-grossing_films)
# 2025-02-24 13:30:26 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/The_Exorcist> (referer: https://en.wikipedia.org/wiki/List_of_highest-grossing_films)
# 2025-02-24 13:30:26 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/The_Godfather> (referer: https://en.wikipedia.org/wiki/List_of_highest-grossing_films)
# 2025-02-24 13:30:26 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/The_Towering_Inferno>
# {'title': 'The Towering Inferno', 'link': '/wiki/The_Towering_Inferno', 'release_year': 1974, 'directors': ['John Guillermin', 'Irwin Allen'], 'box_office': '$203.3 million', 'country': 'United States'}
# 2025-02-24 13:30:27 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/The_Sting>
# {'title': 'The Sting', 'link': '/wiki/The_Sting', 'release_year': 1973, 'directors': ['George Roy Hill'], 'box_office': '$257 million', 'country': 'United States'}
# 2025-02-24 13:30:27 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/Jaws_(film)>
# {'title': 'Jaws', 'link': '/wiki/Jaws_(film)', 'release_year': 1975, 'directors': ['Steven Spielberg'], 'box_office': '$476.5 million', 'country': 'United States'}
# 2025-02-24 13:30:27 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/Rocky>
# {'title': 'Rocky', 'link': '/wiki/Rocky', 'release_year': 1976, 'directors': ['John G. Avildsen'], 'box_office': '$225 million', 'country': 'United States'}
# 2025-02-24 13:30:27 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Love_Story_(1970_film)> (referer: https://en.wikipedia.org/wiki/List_of_highest-grossing_films)
# 2025-02-24 13:30:27 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Funny_Girl_(film)> (referer: https://en.wikipedia.org/wiki/List_of_highest-grossing_films)
# 2025-02-24 13:30:27 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Butch_Cassidy_and_the_Sundance_Kid> (referer: https://en.wikipedia.org/wiki/List_of_highest-grossing_films)
# 2025-02-24 13:30:27 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/The_Graduate> (referer: https://en.wikipedia.org/wiki/List_of_highest-grossing_films)
# 2025-02-24 13:30:27 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/The_Jungle_Book_(1967_film)> (referer: https://en.wikipedia.org/wiki/List_of_highest-grossing_films)
# 2025-02-24 13:30:27 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/Fiddler_on_the_Roof_(film)>
# {'title': 'Fiddler on the Roof', 'link': '/wiki/Fiddler_on_the_Roof_(film)', 'release_year': 1971, 'directors': ['Norman Jewison'], 'box_office': '$83.3 million', 'country': 'United States'}
# 2025-02-24 13:30:27 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/The_French_Connection_(film)>
# {'title': 'The French Connection', 'link': '/wiki/The_French_Connection_(film)', 'release_year': 1971, 'directors': ['William Friedkin'], 'box_office': '$75 million (worldwide', 'country': 'United States'}
# 2025-02-24 13:30:27 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/Diamonds_Are_Forever_(film)>
# {'title': 'Diamonds Are Forever', 'link': '/wiki/Diamonds_Are_Forever_(film)', 'release_year': 1971, 'directors': ['Guy Hamilton'], 'box_office': '$116 million', 'countries': []}
# 2025-02-24 13:30:27 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/The_Exorcist>
# {'title': 'The Exorcist', 'link': '/wiki/The_Exorcist', 'release_year': 1973, 'directors': ['William Friedkin'], 'box_office': '$441.3 million', 'country': 'United States'}
# 2025-02-24 13:30:27 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/The_Godfather>
# {'title': 'The Godfather', 'link': '/wiki/The_Godfather', 'release_year': 1972, 'directors': ['Francis Ford Coppola'], 'box_office': '$250–291 million', 'country': 'United States'}
# 2025-02-24 13:30:27 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Who%27s_Afraid_of_Virginia_Woolf%3F_(film)> (referer: https://en.wikipedia.org/wiki/List_of_highest-grossing_films)
# 2025-02-24 13:30:27 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Hawaii_(1966_film)> (referer: https://en.wikipedia.org/wiki/List_of_highest-grossing_films)
# 2025-02-24 13:30:27 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/The_Bible:_In_the_Beginning> (referer: https://en.wikipedia.org/wiki/List_of_highest-grossing_films)
# 2025-02-24 13:30:27 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/2001:_A_Space_Odyssey> (referer: https://en.wikipedia.org/wiki/List_of_highest-grossing_films)
# 2025-02-24 13:30:27 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Mary_Poppins_(film)> (referer: https://en.wikipedia.org/wiki/List_of_highest-grossing_films)
# 2025-02-24 13:30:27 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/Love_Story_(1970_film)>
# {'title': 'Love Story', 'link': '/wiki/Love_Story_(1970_film)', 'release_year': 1970, 'directors': ['Arthur Hiller'], 'box_office': '$173.4 million', 'country': 'United States'}
# 2025-02-24 13:30:27 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/Funny_Girl_(film)>
# {'title': 'Funny Girl', 'link': '/wiki/Funny_Girl_(film)', 'release_year': 1968, 'directors': ['William Wyler'], 'box_office': '$58.5 million', 'country': 'United States'}
# 2025-02-24 13:30:27 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/Butch_Cassidy_and_the_Sundance_Kid>
# {'title': 'Butch Cassidy and the Sundance Kid', 'link': '/wiki/Butch_Cassidy_and_the_Sundance_Kid', 'release_year': 1969, 'directors': ['George Roy Hill'], 'box_office': '$102.3 million', 'country': 'United States'}
# 2025-02-24 13:30:27 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/The_Graduate>
# {'title': 'The Graduate', 'link': '/wiki/The_Graduate', 'release_year': 1967, 'directors': ['Mike Nichols'], 'box_office': '$104.9 million (North America)', 'country': 'United States'}
# 2025-02-24 13:30:27 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/The_Jungle_Book_(1967_film)>
# {'title': 'The Jungle Book', 'link': '/wiki/The_Jungle_Book_(1967_film)', 'release_year': 1967, 'directors': ['Wolfgang Reitherman'], 'box_office': '$378 million', 'country': 'United States'}
# 2025-02-24 13:30:27 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/From_Russia_with_Love_(film)> (referer: https://en.wikipedia.org/wiki/List_of_highest-grossing_films)
# 2025-02-24 13:30:27 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/How_the_West_Was_Won_(film)> (referer: https://en.wikipedia.org/wiki/List_of_highest-grossing_films)
# 2025-02-24 13:30:27 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/The_Longest_Day_(film)> (referer: https://en.wikipedia.org/wiki/List_of_highest-grossing_films)
# 2025-02-24 13:30:27 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Lawrence_of_Arabia_(film)> (referer: https://en.wikipedia.org/wiki/List_of_highest-grossing_films)
# 2025-02-24 13:30:27 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Goldfinger_(film)> (referer: https://en.wikipedia.org/wiki/List_of_highest-grossing_films)
# 2025-02-24 13:30:27 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/My_Fair_Lady_(film)> (referer: https://en.wikipedia.org/wiki/List_of_highest-grossing_films)
# 2025-02-24 13:30:27 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/Who%27s_Afraid_of_Virginia_Woolf%3F_(film)>
# {'title': "Who's Afraid of Virginia Woolf?", 'link': '/wiki/Who%27s_Afraid_of_Virginia_Woolf%3F_(film)', 'release_year': 1966, 'directors': ['Mike Nichols'], 'box_office': '$33.7 million', 'country': 'United States'}
# 2025-02-24 13:30:27 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/Hawaii_(1966_film)>
# {'title': 'Hawaii', 'link': '/wiki/Hawaii_(1966_film)', 'release_year': 1966, 'directors': ['George Roy Hill'], 'box_office': '$34.5 million', 'country': 'United States'}
# 2025-02-24 13:30:27 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/The_Bible:_In_the_Beginning>
# {'title': 'The Bible: In the Beginning', 'link': '/wiki/The_Bible:_In_the_Beginning', 'release_year': 1966, 'directors': ['John Huston'], 'box_office': '$34.9 million', 'countries': []}
# 2025-02-24 13:30:27 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/2001:_A_Space_Odyssey>
# {'title': '2001: A Space Odyssey', 'link': '/wiki/2001:_A_Space_Odyssey', 'release_year': 1968, 'directors': ['Stanley Kubrick'], 'box_office': '$146 million', 'countries': ['United Kingdom', 'United States']}
# 2025-02-24 13:30:27 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/Mary_Poppins_(film)>
# {'title': 'Mary Poppins', 'link': '/wiki/Mary_Poppins_(film)', 'release_year': 1964, 'directors': ['Robert Stevenson'], 'box_office': '$103.1 million (US/Canada)', 'country': 'United States'}
# 2025-02-24 13:30:27 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Demon_Slayer:_Mugen_Train> (referer: https://en.wikipedia.org/wiki/List_of_highest-grossing_films)
# 2025-02-24 13:30:27 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/One_Hundred_and_One_Dalmatians> (referer: https://en.wikipedia.org/wiki/List_of_highest-grossing_films)
# 2025-02-24 13:30:27 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Psycho_(1960_film)> (referer: https://en.wikipedia.org/wiki/List_of_highest-grossing_films)
# 2025-02-24 13:30:27 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Swiss_Family_Robinson_(1960_film)> (referer: https://en.wikipedia.org/wiki/List_of_highest-grossing_films)
# 2025-02-24 13:30:27 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/South_Pacific_(1958_film)> (referer: https://en.wikipedia.org/wiki/List_of_highest-grossing_films)
# 2025-02-24 13:30:27 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/West_Side_Story_(1961_film)> (referer: https://en.wikipedia.org/wiki/List_of_highest-grossing_films)
# 2025-02-24 13:30:27 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/From_Russia_with_Love_(film)>
# {'title': 'From Russia with Love', 'link': '/wiki/From_Russia_with_Love_(film)', 'release_year': 1963, 'directors': ['Terence Young'], 'box_office': '$79 million', 'countries': []}
# 2025-02-24 13:30:27 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/How_the_West_Was_Won_(film)>
# {'title': 'How the West Was Won', 'link': '/wiki/How_the_West_Was_Won_(film)', 'release_year': 1962, 'directors': ['Henry Hathaway', 'John Ford', 'George Marshall'], 'box_office': '$50 million', 'country': 'United States'}
# 2025-02-24 13:30:27 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/The_Longest_Day_(film)>
# {'title': 'The Longest Day', 'link': '/wiki/The_Longest_Day_(film)', 'release_year': 1962, 'directors': ['Ken Annakin', 'Andrew Marton', 'Bernhard Wicki'], 'box_office': '$50.1 million', 'country': 'United States'}
# 2025-02-24 13:30:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/Goldfinger_(film)>
# {'title': 'Goldfinger', 'link': '/wiki/Goldfinger_(film)', 'release_year': 1964, 'directors': ['Guy Hamilton'], 'box_office': '$125 million', 'countries': []}
# 2025-02-24 13:30:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/Lawrence_of_Arabia_(film)>
# {'title': 'Lawrence of Arabia', 'link': '/wiki/Lawrence_of_Arabia_(film)', 'release_year': 1962, 'directors': ['David Lean'], 'box_office': '$70 million', 'countries': []}
# 2025-02-24 13:30:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/My_Fair_Lady_(film)>
# {'title': 'My Fair Lady', 'link': '/wiki/My_Fair_Lady_(film)', 'release_year': 1964, 'directors': ['George Cukor'], 'box_office': '$72.7 million', 'country': 'United States'}
# 2025-02-24 13:30:28 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Mister_Roberts_(1955_film)> (referer: https://en.wikipedia.org/wiki/List_of_highest-grossing_films)
# 2025-02-24 13:30:28 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Spartacus_(film)> (referer: https://en.wikipedia.org/wiki/List_of_highest-grossing_films)
# 2025-02-24 13:30:28 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/The_Bridge_on_the_River_Kwai> (referer: https://en.wikipedia.org/wiki/List_of_highest-grossing_films)
# 2025-02-24 13:30:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/Demon_Slayer:_Mugen_Train>
# {'title': 'Demon Slayer: Mugen Train', 'link': '/wiki/Demon_Slayer:_Mugen_Train', 'release_year': 2020, 'directors': ['Haruo Sotozaki'], 'box_office': '$507.1 million', 'country': 'Japan'}
# 2025-02-24 13:30:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/One_Hundred_and_One_Dalmatians>
# {'title': 'One Hundred and One Dalmatians', 'link': '/wiki/One_Hundred_and_One_Dalmatians', 'release_year': 1961, 'directors': ['Wolfgang Reitherman', 'Hamilton Luske', 'Clyde Geronimi'], 'box_office': '$303 million', 'country': 'United States'}
# 2025-02-24 13:30:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/Psycho_(1960_film)>
# {'title': 'Psycho', 'link': '/wiki/Psycho_(1960_film)', 'release_year': 1960, 'directors': ['Alfred Hitchcock'], 'box_office': '$50 million', 'country': 'United States'}
# 2025-02-24 13:30:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/West_Side_Story_(1961_film)>
# {'title': 'West Side Story', 'link': '/wiki/West_Side_Story_(1961_film)', 'release_year': 1961, 'directors': ['Robert Wise', 'Jerome Robbins'], 'box_office': '$44.1 million', 'country': 'United States'}
# 2025-02-24 13:30:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/South_Pacific_(1958_film)>
# {'title': 'South Pacific', 'link': '/wiki/South_Pacific_(1958_film)', 'release_year': 1958, 'directors': ['Joshua Logan'], 'box_office': '$17.5 million', 'country': 'United States'}
# 2025-02-24 13:30:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/Swiss_Family_Robinson_(1960_film)>
# {'title': 'Swiss Family Robinson', 'link': '/wiki/Swiss_Family_Robinson_(1960_film)', 'release_year': 1960, 'directors': ['Ken Annakin'], 'box_office': '$40 million', 'country': 'United States'}
# 2025-02-24 13:30:28 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/The_Robe_(film)> (referer: https://en.wikipedia.org/wiki/List_of_highest-grossing_films)
# 2025-02-24 13:30:28 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Cinerama_Holiday> (referer: https://en.wikipedia.org/wiki/List_of_highest-grossing_films)
# 2025-02-24 13:30:28 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/20,000_Leagues_Under_the_Sea_(1954_film)> (referer: https://en.wikipedia.org/wiki/List_of_highest-grossing_films)
# 2025-02-24 13:30:28 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/White_Christmas_(film)> (referer: https://en.wikipedia.org/wiki/List_of_highest-grossing_films)
# 2025-02-24 13:30:28 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Rear_Window> (referer: https://en.wikipedia.org/wiki/List_of_highest-grossing_films)
# 2025-02-24 13:30:28 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/The_Greatest_Show_on_Earth_(film)> (referer: https://en.wikipedia.org/wiki/List_of_highest-grossing_films)
# 2025-02-24 13:30:28 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Peter_Pan_(1953_film)> (referer: https://en.wikipedia.org/wiki/List_of_highest-grossing_films)
# 2025-02-24 13:30:28 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Lady_and_the_Tramp> (referer: https://en.wikipedia.org/wiki/List_of_highest-grossing_films)
# 2025-02-24 13:30:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/Mister_Roberts_(1955_film)>
# {'title': 'Mister Roberts', 'link': '/wiki/Mister_Roberts_(1955_film)', 'release_year': 1955, 'directors': ['John Ford', 'Mervyn LeRoy', 'Joshua Logan'], 'box_office': '$21.2 million', 'country': 'United States'}
# 2025-02-24 13:30:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/Spartacus_(film)>
# {'title': 'Spartacus', 'link': '/wiki/Spartacus_(film)', 'release_year': 1960, 'directors': ['Stanley Kubrick'], 'box_office': '$60 million (initial release)', 'country': 'United States'}
# 2025-02-24 13:30:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/The_Bridge_on_the_River_Kwai>
# {'title': 'The Bridge on the River Kwai', 'link': '/wiki/The_Bridge_on_the_River_Kwai', 'release_year': 1957, 'directors': ['David Lean'], 'box_office': '$30.6 million', 'countries': []}
# 2025-02-24 13:30:28 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/This_Is_Cinerama> (referer: https://en.wikipedia.org/wiki/List_of_highest-grossing_films)
# 2025-02-24 13:30:28 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Quo_Vadis_(1951_film)> (referer: https://en.wikipedia.org/wiki/List_of_highest-grossing_films)
# 2025-02-24 13:30:28 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/King_Solomon%27s_Mines_(1950_film)> (referer: https://en.wikipedia.org/wiki/List_of_highest-grossing_films)
# 2025-02-24 13:30:28 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Samson_and_Delilah_(1949_film)> (referer: https://en.wikipedia.org/wiki/List_of_highest-grossing_films)
# 2025-02-24 13:30:28 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/The_Snake_Pit> (referer: https://en.wikipedia.org/wiki/List_of_highest-grossing_films)
# 2025-02-24 13:30:28 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Cinderella_(1950_film)> (referer: https://en.wikipedia.org/wiki/List_of_highest-grossing_films)
# 2025-02-24 13:30:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/The_Robe_(film)>
# {'title': 'The Robe', 'link': '/wiki/The_Robe_(film)', 'release_year': 1953, 'directors': ['Henry Koster'], 'box_office': '$36 million (United States)', 'country': 'United States'}
# 2025-02-24 13:30:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/Cinerama_Holiday>
# {'title': 'Cinerama Holiday', 'link': '/wiki/Cinerama_Holiday', 'release_year': 1955, 'directors': ['Robert L. Bendick', 'Philippe De Lacy'], 'box_office': '$29.6 million', 'country': 'United States'}
# 2025-02-24 13:30:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/20,000_Leagues_Under_the_Sea_(1954_film)>
# {'title': '20,000 Leagues Under the Sea', 'link': '/wiki/20,000_Leagues_Under_the_Sea_(1954_film)', 'release_year': 1954, 'directors': ['Richard Fleischer'], 'box_office': '$28.2 million', 'country': 'United States'}
# 2025-02-24 13:30:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/White_Christmas_(film)>
# {'title': 'White Christmas', 'link': '/wiki/White_Christmas_(film)', 'release_year': 1954, 'directors': ['Michael Curtiz'], 'box_office': '$30 million', 'country': 'United States'}
# 2025-02-24 13:30:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/Rear_Window>
# {'title': 'Rear Window', 'link': '/wiki/Rear_Window', 'release_year': 1954, 'directors': ['Alfred Hitchcock'], 'box_office': '$37 million', 'country': 'United States'}
# 2025-02-24 13:30:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/The_Greatest_Show_on_Earth_(film)>
# {'title': 'The Greatest Show on Earth', 'link': '/wiki/The_Greatest_Show_on_Earth_(film)', 'release_year': 1952, 'directors': ['Cecil B. DeMille'], 'box_office': '$36 million', 'country': 'United States'}
# 2025-02-24 13:30:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/Peter_Pan_(1953_film)>
# {'title': 'Peter Pan', 'link': '/wiki/Peter_Pan_(1953_film)', 'release_year': 1953, 'directors': ['Hamilton Luske', 'Clyde Geronimi', 'Wilfred Jackson'], 'box_office': '$87.4 million (United States and Canada)', 'country': 'United States'}
# 2025-02-24 13:30:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/Lady_and_the_Tramp>
# {'title': 'Lady and the Tramp', 'link': '/wiki/Lady_and_the_Tramp', 'release_year': 1955, 'directors': ['Hamilton Luske', 'Clyde Geronimi', 'Wilfred Jackson'], 'box_office': '$187 million', 'country': 'United States'}
# 2025-02-24 13:30:28 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Unconquered_(1947_film)> (referer: https://en.wikipedia.org/wiki/List_of_highest-grossing_films)
# 2025-02-24 13:30:28 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Forever_Amber_(film)> (referer: https://en.wikipedia.org/wiki/List_of_highest-grossing_films)
# 2025-02-24 13:30:28 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/The_Red_Shoes_(1948_film)> (referer: https://en.wikipedia.org/wiki/List_of_highest-grossing_films)
# 2025-02-24 13:30:28 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Easter_Parade_(film)> (referer: https://en.wikipedia.org/wiki/List_of_highest-grossing_films)
# 2025-02-24 13:30:28 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Duel_in_the_Sun_(film)> (referer: https://en.wikipedia.org/wiki/List_of_highest-grossing_films)
# 2025-02-24 13:30:28 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/The_Best_Years_of_Our_Lives> (referer: https://en.wikipedia.org/wiki/List_of_highest-grossing_films)
# 2025-02-24 13:30:28 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Song_of_the_South> (referer: https://en.wikipedia.org/wiki/List_of_highest-grossing_films)
# 2025-02-24 13:30:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/This_Is_Cinerama>
# {'title': 'This Is Cinerama', 'link': '/wiki/This_Is_Cinerama', 'release_year': 1952, 'directors': ['Mike Todd', 'Michael Todd, Jr.'], 'box_office': '$41.6 million', 'country': 'United States'}
# 2025-02-24 13:30:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/Quo_Vadis_(1951_film)>
# {'title': 'Quo Vadis', 'link': '/wiki/Quo_Vadis_(1951_film)', 'release_year': 1951, 'directors': ['Mervyn LeRoy'], 'box_office': '$21 million', 'country': 'United States'}
# 2025-02-24 13:30:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/King_Solomon%27s_Mines_(1950_film)>
# {'title': "King Solomon's Mines", 'link': '/wiki/King_Solomon%27s_Mines_(1950_film)', 'release_year': 1950, 'directors': ['Compton Bennett', 'Andrew Marton'], 'box_office': '$15.1 million', 'country': 'United States'}
# ...
# {'title': 'Jurassic Park', 'link': '/wiki/Jurassic_Park_(film)', 'release_year': 1993, 'directors': ['Steven Spielberg'], 'box_office': '$1.058 billion', 'country': 'United States'}
# 2025-02-24 13:30:30 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/Moana_2>
# {'title': 'Moana 2', 'link': '/wiki/Moana_2', 'release_year': 2024, 'directors': ['David Derrick Jr.', '1', '1', '1'], 'box_office': '$1.05 billion', 'country': 'United States'}
# 2025-02-24 13:30:30 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/Star_Wars:_Episode_I_%E2%80%93_The_Phantom_Menace>
# {'title': 'Star Wars: Episode I – The Phantom Menace', 'link': '/wiki/Star_Wars:_Episode_I_%E2%80%93_The_Phantom_Menace', 'release_year': 1999, 'directors': ['George Lucas'], 'box_office': '$1.047 billion', 'country': 'United States'}
# 2025-02-24 13:30:30 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/Aladdin_(2019_film)>
# {'title': 'Aladdin', 'link': '/wiki/Aladdin_(2019_film)', 'release_year': 2019, 'directors': ['Guy Ritchie'], 'box_office': '$1.054 billion', 'country': 'United States'}
# 2025-02-24 13:30:30 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Star_Wars:_The_Rise_of_Skywalker> (referer: https://en.wikipedia.org/wiki/List_of_highest-grossing_films)
# 2025-02-24 13:30:30 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Transformers:_Age_of_Extinction> (referer: https://en.wikipedia.org/wiki/List_of_highest-grossing_films)
# 2025-02-24 13:30:30 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/Ben-Hur_(1925_film)>
# {'title': 'Ben-Hur', 'link': '/wiki/Ben-Hur_(1925_film)', 'release_year': 1925, 'directors': ['Fred Niblo', 'Charles Brabin'], 'box_office': '$10.7 million', 'country': 'United States'}
# 2025-02-24 13:30:30 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/Pirates_of_the_Caribbean:_Dead_Man%27s_Chest>
# {'title': "Pirates of the Caribbean: Dead Man's Chest", 'link': '/wiki/Pirates_of_the_Caribbean:_Dead_Man%27s_Chest', 'release_year': 2006, 'directors': ['Gore Verbinski'], 'box_office': '$1.066 billion', 'country': 'United States'}
# 2025-02-24 13:30:30 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/Rogue_One:_A_Star_Wars_Story>
# {'title': 'Rogue One: A Star Wars Story', 'link': '/wiki/Rogue_One:_A_Star_Wars_Story', 'release_year': 2016, 'directors': ['Gareth Edwards'], 'box_office': '$1.059 billion', 'country': 'United States'}
# 2025-02-24 13:30:30 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/Toy_Story_3>
# {'title': 'Toy Story 3', 'link': '/wiki/Toy_Story_3', 'release_year': 2010, 'directors': ['Lee Unkrich'], 'box_office': '$1.067 billion', 'country': 'United States'}
# 2025-02-24 13:30:30 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/Toy_Story_4>
# {'title': 'Toy Story 4', 'link': '/wiki/Toy_Story_4', 'release_year': 2019, 'directors': ['Josh Cooley'], 'box_office': '$1.074 billion', 'country': 'United States'}
# 2025-02-24 13:30:30 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Skyfall> (referer: https://en.wikipedia.org/wiki/List_of_highest-grossing_films)
# 2025-02-24 13:30:30 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Transformers:_Dark_of_the_Moon> (referer: https://en.wikipedia.org/wiki/List_of_highest-grossing_films)
# 2025-02-24 13:30:30 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Spider-Man:_Far_From_Home> (referer: https://en.wikipedia.org/wiki/List_of_highest-grossing_films)
# 2025-02-24 13:30:30 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Joker_(2019_film)> (referer: https://en.wikipedia.org/wiki/List_of_highest-grossing_films)
# 2025-02-24 13:30:30 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/The_Dark_Knight_Rises> (referer: https://en.wikipedia.org/wiki/List_of_highest-grossing_films)
# 2025-02-24 13:30:30 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Captain_Marvel_(film)> (referer: https://en.wikipedia.org/wiki/List_of_highest-grossing_films)
# 2025-02-24 13:30:30 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/Star_Wars:_The_Rise_of_Skywalker>
# {'title': 'Star Wars: The Rise of Skywalker', 'link': '/wiki/Star_Wars:_The_Rise_of_Skywalker', 'release_year': 2019, 'directors': ['J. J. Abrams'], 'box_office': '$1.077 billion', 'country': 'United States'}
# 2025-02-24 13:30:30 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/Transformers:_Age_of_Extinction>
# {'title': 'Transformers: Age of Extinction', 'link': '/wiki/Transformers:_Age_of_Extinction', 'release_year': 2014, 'directors': ['Michael Bay'], 'box_office': '$1.104 billion', 'country': 'United States'}
# 2025-02-24 13:30:30 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/Skyfall>
# {'title': 'Skyfall', 'link': '/wiki/Skyfall', 'release_year': 2012, 'directors': ['Sam Mendes'], 'box_office': '$1.109 billion', 'countries': ['United Kingdom', 'United States']}
# 2025-02-24 13:30:30 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/Transformers:_Dark_of_the_Moon>
# {'title': 'Transformers: Dark of the Moon', 'link': '/wiki/Transformers:_Dark_of_the_Moon', 'release_year': 2011, 'directors': ['Michael Bay'], 'box_office': '$1.124 billion', 'country': 'United States'}
# 2025-02-24 13:30:30 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/Spider-Man:_Far_From_Home>
# {'title': 'Spider-Man: Far From Home', 'link': '/wiki/Spider-Man:_Far_From_Home', 'release_year': 2019, 'directors': ['Jon Watts'], 'box_office': '$1.133 billion', 'country': 'United States'}
# 2025-02-24 13:30:30 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/The_Dark_Knight_Rises>
# {'title': 'The Dark Knight Rises', 'link': '/wiki/The_Dark_Knight_Rises', 'release_year': 2012, 'directors': ['Christopher Nolan'], 'box_office': '$1.115 billion', 'countries': ['United States', 'United Kingdom']}
# 2025-02-24 13:30:30 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/Joker_(2019_film)>
# {'title': 'Joker', 'link': '/wiki/Joker_(2019_film)', 'release_year': 2019, 'directors': ['Todd Phillips'], 'box_office': '$1.079 billion', 'country': 'United States'}
# 2025-02-24 13:30:30 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Captain_America:_Civil_War> (referer: https://en.wikipedia.org/wiki/List_of_highest-grossing_films)
# 2025-02-24 13:30:30 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Aquaman_(film)> (referer: https://en.wikipedia.org/wiki/List_of_highest-grossing_films)
# 2025-02-24 13:30:30 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Top_Gun:_Maverick> (referer: https://en.wikipedia.org/wiki/List_of_highest-grossing_films)
# 2025-02-24 13:30:30 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/The_Lord_of_the_Rings:_The_Return_of_the_King> (referer: https://en.wikipedia.org/wiki/List_of_highest-grossing_films)
# 2025-02-24 13:30:30 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Jurassic_World> (referer: https://en.wikipedia.org/wiki/List_of_highest-grossing_films)
# 2025-02-24 13:30:30 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Furious_7> (referer: https://en.wikipedia.org/wiki/List_of_highest-grossing_films)
# 2025-02-24 13:30:30 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/The_Lion_King_(2019_film)> (referer: https://en.wikipedia.org/wiki/List_of_highest-grossing_films)
# 2025-02-24 13:30:30 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/Captain_Marvel_(film)>
# {'title': 'Captain Marvel', 'link': '/wiki/Captain_Marvel_(film)', 'release_year': 2019, 'directors': ['Anna Boden', 'Ryan Fleck'], 'box_office': '$1.131 billion', 'country': 'United States'}
# 2025-02-24 13:30:30 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/The_Avengers_(2012_film)> (referer: https://en.wikipedia.org/wiki/List_of_highest-grossing_films)
# 2025-02-24 13:30:30 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/Captain_America:_Civil_War>
# {'title': 'Captain America: Civil War', 'link': '/wiki/Captain_America:_Civil_War', 'release_year': 2016, 'directors': None, 'box_office': '$1.155', 'country': 'United States'}
# 2025-02-24 13:30:30 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Ne_Zha_2> (referer: https://en.wikipedia.org/wiki/List_of_highest-grossing_films)
# 2025-02-24 13:30:30 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Inside_Out_2> (referer: https://en.wikipedia.org/wiki/List_of_highest-grossing_films)
# 2025-02-24 13:30:30 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/Aquaman_(film)>
# {'title': 'Aquaman', 'link': '/wiki/Aquaman_(film)', 'release_year': 2018, 'directors': ['James Wan'], 'box_office': '$1.152 billion', 'country': 'United States'}
# 2025-02-24 13:30:30 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/Top_Gun:_Maverick>
# {'title': 'Top Gun: Maverick', 'link': '/wiki/Top_Gun:_Maverick', 'release_year': 2022, 'directors': ['Joseph Kosinski'], 'box_office': '$1.496 billion', 'country': 'United States'}
# 2025-02-24 13:30:30 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/The_Lord_of_the_Rings:_The_Return_of_the_King>
# {'title': 'The Lord of the Rings: The Return of the King', 'link': '/wiki/The_Lord_of_the_Rings:_The_Return_of_the_King', 'release_year': 2003, 'directors': ['Peter Jackson'], 'box_office': '$1.151 billion', 'countries': ['New Zealand', 'Germany', 'United States']}
# 2025-02-24 13:30:30 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/The_Lion_King_(2019_film)>
# {'title': 'The Lion King', 'link': '/wiki/The_Lion_King_(2019_film)', 'release_year': 2019, 'directors': ['Jon Favreau'], 'box_office': '$1.657 billion', 'country': 'United States'}
# 2025-02-24 13:30:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/Jurassic_World>
# {'title': 'Jurassic World', 'link': '/wiki/Jurassic_World', 'release_year': 2015, 'directors': ['Colin Trevorrow'], 'box_office': '$1.671 billion', 'country': 'United States'}
# 2025-02-24 13:30:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/Furious_7>
# {'title': 'Furious 7', 'link': '/wiki/Furious_7', 'release_year': 2015, 'directors': ['James Wan'], 'box_office': '$1.515 billion', 'countries': []}
# 2025-02-24 13:30:31 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Spider-Man:_No_Way_Home> (referer: https://en.wikipedia.org/wiki/List_of_highest-grossing_films)
# 2025-02-24 13:30:31 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Avengers:_Endgame> (referer: https://en.wikipedia.org/wiki/List_of_highest-grossing_films)
# 2025-02-24 13:30:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/The_Avengers_(2012_film)>
# {'title': 'The Avengers', 'link': '/wiki/The_Avengers_(2012_film)', 'release_year': 2012, 'directors': ['Joss Whedon'], 'box_office': '$1.521 billion', 'country': 'United States'}
# 2025-02-24 13:30:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/Ne_Zha_2>
# {'title': 'Ne Zha 2', 'link': '/wiki/Ne_Zha_2', 'release_year': 2025, 'directors': ['Jiaozi'], 'box_office': '$1.87 billion', 'country': 'China'}
# 2025-02-24 13:30:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/Inside_Out_2>
# {'title': 'Inside Out 2', 'link': '/wiki/Inside_Out_2', 'release_year': 2024, 'directors': ['Kelsey Mann'], 'box_office': '$1.699 billion', 'country': 'United States'}
# 2025-02-24 13:30:31 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Avengers:_Infinity_War> (referer: https://en.wikipedia.org/wiki/List_of_highest-grossing_films)
# 2025-02-24 13:30:31 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Star_Wars:_The_Force_Awakens> (referer: https://en.wikipedia.org/wiki/List_of_highest-grossing_films)
# 2025-02-24 13:30:31 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Titanic_(1997_film)> (referer: https://en.wikipedia.org/wiki/List_of_highest-grossing_films)
# 2025-02-24 13:30:31 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Avatar:_The_Way_of_Water> (referer: https://en.wikipedia.org/wiki/List_of_highest-grossing_films)
# 2025-02-24 13:30:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/Spider-Man:_No_Way_Home>
# {'title': 'Spider-Man: No Way Home', 'link': '/wiki/Spider-Man:_No_Way_Home', 'release_year': 2021, 'directors': ['Jon Watts'], 'box_office': '$1.953 billion', 'country': 'United States'}
# 2025-02-24 13:30:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/Avengers:_Endgame>
# {'title': 'Avengers: Endgame', 'link': '/wiki/Avengers:_Endgame', 'release_year': 2019, 'directors': None, 'box_office': '$2.799', 'country': 'United States'}
# 2025-02-24 13:30:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/Avengers:_Infinity_War>
# {'title': 'Avengers: Infinity War', 'link': '/wiki/Avengers:_Infinity_War', 'release_year': 2018, 'directors': None, 'box_office': '$2.052 billion', 'country': 'United States'}
# 2025-02-24 13:30:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/Star_Wars:_The_Force_Awakens>
# {'title': 'Star Wars: The Force Awakens', 'link': '/wiki/Star_Wars:_The_Force_Awakens', 'release_year': 2015, 'directors': ['J. J. Abrams'], 'box_office': '$2.07', 'country': 'United States'}
# 2025-02-24 13:30:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/Titanic_(1997_film)>
# {'title': 'Titanic', 'link': '/wiki/Titanic_(1997_film)', 'release_year': 1997, 'directors': ['James Cameron'], 'box_office': '$2.264 billion', 'country': 'United States'}
# 2025-02-24 13:30:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/Avatar:_The_Way_of_Water>
# {'title': 'Avatar: The Way of Water', 'link': '/wiki/Avatar:_The_Way_of_Water', 'release_year': 2022, 'directors': ['James Cameron'], 'box_office': '$2.320 billion', 'country': 'United States'}
# 2025-02-24 13:30:31 [scrapy.core.engine] INFO: Closing spider (finished)
# 2025-02-24 13:30:31 [scrapy.extensions.feedexport] INFO: Stored json feed (177 items) in: films.json
# 2025-02-24 13:30:31 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 79937,
#  'downloader/request_count': 178,
#  'downloader/request_method_count/GET': 178,
#  'downloader/response_bytes': 14430765,
#  'downloader/response_count': 178,
#  'downloader/response_status_count/200': 178,
#  'elapsed_time_seconds': 7.601035,
#  'feedexport/success_count/FileFeedStorage': 1,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2025, 2, 24, 10, 30, 31, 466800, tzinfo=datetime.timezone.utc),
#  'httpcompression/response_bytes': 78754690,
#  'httpcompression/response_count': 178,
#  'item_scraped_count': 177,
#  'items_per_minute': None,
#  'log_count/DEBUG': 356,
#  'log_count/INFO': 11,
#  'request_depth_max': 1,
#  'response_received_count': 178,
#  'responses_per_minute': None,
#  'scheduler/dequeued': 178,
#  'scheduler/dequeued/memory': 178,
#  'scheduler/enqueued': 178,
#  'scheduler/enqueued/memory': 178,
#  'start_time': datetime.datetime(2025, 2, 24, 10, 30, 23, 865765, tzinfo=datetime.timezone.utc)}
# 2025-02-24 13:30:31 [scrapy.core.engine] INFO: Spider closed (finished)

# %%
import json

with open('films.json', 'r') as f:
    films_data = json.load(f)

# %%
films_data
# Out:
# [{'title': 'Avatar',
#   'link': '/wiki/Avatar_(2009_film)',
#   'release_year': 2009,
#   'directors': ['James Cameron'],
#   'box_office': '$2.923 billion',
#   'countries': ['United Kingdom', 'United States']},
#  {'title': 'Star Wars: The Last Jedi',
#   'link': '/wiki/Star_Wars:_The_Last_Jedi',
#   'release_year': 2017,
#   'directors': ['Rian Johnson'],
#   'box_office': '$1.334',
#   'country': 'United States'},
#  {'title': 'Deadpool & Wolverine',
#   'link': '/wiki/Deadpool_%26_Wolverine',
#   'release_year': 2024,
#   'directors': ['Shawn Levy'],
#   'box_office': '$1.338 billion',
#   'country': 'United States'},
#  {'title': 'Harry Potter and the Deathly Hallows – Part 2',
#   'link': '/wiki/Harry_Potter_and_the_Deathly_Hallows_%E2%80%93_Part_2',
#   'release_year': 2011,
#   'directors': ['David Yates'],
#   'box_office': '$1.342 billion',
#   'countries': ['United Kingdom', 'United States']},
#  {'title': 'Black Panther',
#   'link': '/wiki/Black_Panther_(film)',
#   'release_year': 2018,
#   'directors': ['Ryan Coogler'],
#   'box_office': '$1.35 billion',
#   'country': 'United States'},
#  {'title': 'The Fate of the Furious',
#   'link': '/wiki/The_Fate_of_the_Furious',
#   'release_year': 2017,
#   'directors': ['F. Gary Gray'],
#   'box_office': '$1.236 billion',
#   'countries': ['United States', 'China']},
#  {'title': 'Incredibles 2',
#   'link': '/wiki/Incredibles_2',
#   'release_year': 2018,
#   'directors': ['Brad Bird'],
#   'box_office': '$1.243 billion',
#   'country': 'United States'},
#  {'title': 'Minions',
#   'link': '/wiki/Minions_(film)',
#   'release_year': 2015,
#   'directors': ['Pierre Coffin', 'Kyle Balda'],
#   'box_office': '$1.159 billion',
#   'country': 'United States'},
#  {'title': 'Jurassic World: Fallen Kingdom',
#   'link': '/wiki/Jurassic_World:_Fallen_Kingdom',
#   'release_year': 2018,
#   'directors': ['J. A. Bayona'],
#   'box_office': '$1.31 billion',
#   'countries': ['China', 'United States']},
#  {'title': 'Iron Man 3',
#   'link': '/wiki/Iron_Man_3',
#   'release_year': 2013,
#   'directors': ['Shane Black'],
#   'box_office': '$1.266 billion',
#   'country': 'United States'},
#  {'title': 'Frozen',
#   'link': '/wiki/Frozen_(2013_film)',
#   'release_year': 2013,
#   'directors': ['Chris Buck', 'Jennifer Lee'],
#   'box_office': '$1.280 billion',
#   'country': 'United States'},
#  {'title': 'Beauty and the Beast',
#   'link': '/wiki/Beauty_and_the_Beast_(2017_film)',
#   'release_year': 2017,
#   'directors': ['Bill Condon'],
#   'box_office': '$1.266',
#   'country': 'United States'},
#  {'title': 'The Super Mario Bros. Movie',
#   'link': '/wiki/The_Super_Mario_Bros._Movie',
#   'release_year': 2023,
#   'directors': ['Aaron Horvath', 'Michael Jelenic'],
#   'box_office': '$1.360 billion',
#   'country': 'United States'},
#  {'title': 'Harry Potter and the Goblet of Fire',
#   'link': '/wiki/Harry_Potter_and_the_Goblet_of_Fire_(film)',
#   'release_year': 2005,
#   'directors': ['Mike Newell'],
#   'box_office': '$897.5 million',
#   'countries': ['United Kingdom', 'United States']},
#  {'title': "Pirates of the Caribbean: At World's End",
#   'link': '/wiki/Pirates_of_the_Caribbean:_At_World%27s_End',
#   'release_year': 2007,
#   'directors': ['Gore Verbinski'],
#   'box_office': '$963.4 million',
#   'country': 'United States'},
#  {'title': 'Avengers: Age of Ultron',
#   'link': '/wiki/Avengers:_Age_of_Ultron',
#   'release_year': 2015,
#   'directors': ['Joss Whedon'],
#   'box_office': '$1.405 billion',
#   'country': 'United States'},
#  {'title': 'Barbie',
#   'link': '/wiki/Barbie_(film)',
#   'release_year': 2023,
#   'directors': ['Greta Gerwig'],
#   'box_office': '$1.446 billion',
#   'countries': ['United States', 'United Kingdom']},
#  {'title': 'The Dark Knight',
#   'link': '/wiki/The_Dark_Knight',
#   'release_year': 2008,
#   'directors': ['Christopher Nolan'],
#   'box_office': '$1.006',
#   'countries': ['United States', 'United Kingdom']},
#  {'title': 'Shrek 2',
#   'link': '/wiki/Shrek_2',
#   'release_year': 2004,
#   'directors': ['Andrew Adamson', 'Kelly Asbury', 'Conrad Vernon'],
#   'box_office': '$935.5 million',
#   'country': 'United States'},
#  {'title': 'Armageddon',
#   'link': '/wiki/Armageddon_(1998_film)',
#   'release_year': 1998,
#   'directors': ['Michael Bay'],
#   'box_office': '$553.7 million',
#   'country': 'United States'},
#  {'title': "Harry Potter and the Philosopher's Stone",
#   'link': '/wiki/Harry_Potter_and_the_Philosopher%27s_Stone_(film)',
#   'release_year': 2001,
#   'directors': ['Chris Columbus'],
#   'box_office': '$1.026 billion',
#   'countries': ['United Kingdom', 'United States']},
#  {'title': 'The Lord of the Rings: The Two Towers',
#   'link': '/wiki/The_Lord_of_the_Rings:_The_Two_Towers',
#   'release_year': 2002,
#   'directors': ['Peter Jackson'],
#   'box_office': '$951.6 million',
#   'countries': ['New Zealand', 'United States']},
#  {'title': 'Die Hard with a Vengeance',
#   'link': '/wiki/Die_Hard_with_a_Vengeance',
#   'release_year': 1995,
#   'directors': ['John McTiernan'],
#   'box_office': '$366.1 million',
#   'country': 'United States'},
#  {'title': 'Mission: Impossible 2',
#   'link': '/wiki/Mission:_Impossible_2',
#   'release_year': 2000,
#   'directors': ['John Woo'],
#   'box_office': '$546.3 million',
#   'countries': ['United States', 'Germany']},
#  {'title': 'Independence Day',
#   'link': '/wiki/Independence_Day_(1996_film)',
#   'release_year': 1996,
#   'directors': ['Roland Emmerich'],
#   'box_office': '$817.4 million',
#   'country': 'United States'},
#  {'title': 'Rain Man',
#   'link': '/wiki/Rain_Man',
#   'release_year': 1988,
#   'directors': ['Barry Levinson'],
#   'box_office': '$354.8',
#   'country': 'United States'},
#  {'title': 'Ghost',
#   'link': '/wiki/Ghost_(1990_film)',
#   'release_year': 1990,
#   'directors': ['Jerry Zucker'],
#   'box_office': '$505.7 million',
#   'country': 'United States'},
#  {'title': 'Indiana Jones and the Last Crusade',
#   'link': '/wiki/Indiana_Jones_and_the_Last_Crusade',
#   'release_year': 1989,
#   'directors': ['Steven Spielberg'],
#   'box_office': '$474.2 million',
#   'country': 'United States'},
#  {'title': 'Toy Story',
#   'link': '/wiki/Toy_Story',
#   'release_year': 1995,
#   'directors': ['John Lasseter'],
#   'box_office': '$394.4 million',
#   'country': 'United States'},
#  {'title': 'Frozen 2',
#   'link': '/wiki/Frozen_2',
#   'release_year': 2019,
#   'directors': ['Chris Buck', 'Jennifer Lee'],
#   'box_office': '$1.453',
#   'country': 'United States'},
#  {'title': 'Fatal Attraction',
#   'link': '/wiki/Fatal_Attraction',
#   'release_year': 1987,
#   'directors': ['Adrian Lyne'],
#   'box_office': '$320.1 million',
#   'country': 'United States'},
#  {'title': 'Terminator 2: Judgment Day',
#   'link': '/wiki/Terminator_2:_Judgment_Day',
#   'release_year': 1991,
#   'directors': ['James Cameron'],
#   'box_office': '$519–520.9',
#   'country': 'United States'},
#  {'title': 'Top Gun',
#   'link': '/wiki/Top_Gun',
#   'release_year': 1986,
#   'directors': ['Tony Scott'],
#   'box_office': '$357.3 million',
#   'country': 'United States'},
#  {'title': 'Back to the Future',
#   'link': '/wiki/Back_to_the_Future',
#   'release_year': 1985,
#   'directors': ['Robert Zemeckis'],
#   'box_office': '$388.8 million',
#   'country': 'United States'},
#  {'title': 'Rocky II',
#   'link': '/wiki/Rocky_II',
#   'release_year': 1979,
#   'directors': ['Sylvester Stallone'],
#   'box_office': '$200.1 million',
#   'country': 'United States'},
#  {'title': 'Ghostbusters',
#   'link': '/wiki/Ghostbusters',
#   'release_year': 1984,
#   'directors': ['Ivan Reitman'],
#   'box_office': '$370 million',
#   'country': 'United States'},
#  {'title': 'Moonraker',
#   'link': '/wiki/Moonraker_(film)',
#   'release_year': 1979,
#   'directors': ['Lewis Gilbert'],
#   'box_office': '$210.3 million',
#   'countries': []},
#  {'title': 'Return of the Jedi',
#   'link': '/wiki/Return_of_the_Jedi',
#   'release_year': 1983,
#   'directors': ['Richard Marquand'],
#   'box_office': '$482 million',
#   'country': 'United States'},
#  {'title': 'Grease',
#   'link': '/wiki/Grease_(film)',
#   'release_year': 1978,
#   'directors': ['Randal Kleiser'],
#   'box_office': '$396.3 million',
#   'country': 'United States'},
#  {'title': 'The Empire Strikes Back',
#   'link': '/wiki/The_Empire_Strikes_Back',
#   'release_year': 1980,
#   'directors': ['Irvin Kershner'],
#   'box_office': '$538–549',
#   'country': 'United States'},
#  {'title': 'Raiders of the Lost Ark',
#   'link': '/wiki/Raiders_of_the_Lost_Ark',
#   'release_year': 1981,
#   'directors': ['Steven Spielberg'],
#   'box_office': '$389.9',
#   'country': 'United States'},
#  {'title': 'The Towering Inferno',
#   'link': '/wiki/The_Towering_Inferno',
#   'release_year': 1974,
#   'directors': ['John Guillermin', 'Irwin Allen'],
#   'box_office': '$203.3 million',
#   'country': 'United States'},
#  {'title': 'The Sting',
#   'link': '/wiki/The_Sting',
#   'release_year': 1973,
#   'directors': ['George Roy Hill'],
#   'box_office': '$257 million',
#   'country': 'United States'},
#  {'title': 'Jaws',
#   'link': '/wiki/Jaws_(film)',
#   'release_year': 1975,
#   'directors': ['Steven Spielberg'],
#   'box_office': '$476.5 million',
#   'country': 'United States'},
#  {'title': 'Rocky',
#   'link': '/wiki/Rocky',
#   'release_year': 1976,
#   'directors': ['John G. Avildsen'],
#   'box_office': '$225 million',
#   'country': 'United States'},
#  {'title': 'Fiddler on the Roof',
#   'link': '/wiki/Fiddler_on_the_Roof_(film)',
#   'release_year': 1971,
#   'directors': ['Norman Jewison'],
#   'box_office': '$83.3 million',
#   'country': 'United States'},
#  {'title': 'The French Connection',
#   'link': '/wiki/The_French_Connection_(film)',
#   'release_year': 1971,
#   'directors': ['William Friedkin'],
#   'box_office': '$75 million (worldwide',
#   'country': 'United States'},
#  {'title': 'Diamonds Are Forever',
#   'link': '/wiki/Diamonds_Are_Forever_(film)',
#   'release_year': 1971,
#   'directors': ['Guy Hamilton'],
#   'box_office': '$116 million',
#   'countries': []},
#  {'title': 'The Exorcist',
#   'link': '/wiki/The_Exorcist',
#   'release_year': 1973,
#   'directors': ['William Friedkin'],
#   'box_office': '$441.3 million',
#   'country': 'United States'},
#  {'title': 'The Godfather',
#   'link': '/wiki/The_Godfather',
#   'release_year': 1972,
#   'directors': ['Francis Ford Coppola'],
#   'box_office': '$250–291 million',
#   'country': 'United States'},
#  {'title': 'Love Story',
#   'link': '/wiki/Love_Story_(1970_film)',
#   'release_year': 1970,
#   'directors': ['Arthur Hiller'],
#   'box_office': '$173.4 million',
#   'country': 'United States'},
#  {'title': 'Funny Girl',
#   'link': '/wiki/Funny_Girl_(film)',
#   'release_year': 1968,
#   'directors': ['William Wyler'],
#   'box_office': '$58.5 million',
#   'country': 'United States'},
#  {'title': 'Butch Cassidy and the Sundance Kid',
#   'link': '/wiki/Butch_Cassidy_and_the_Sundance_Kid',
#   'release_year': 1969,
#   'directors': ['George Roy Hill'],
#   'box_office': '$102.3 million',
#   'country': 'United States'},
#  {'title': 'The Graduate',
#   'link': '/wiki/The_Graduate',
#   'release_year': 1967,
#   'directors': ['Mike Nichols'],
#   'box_office': '$104.9 million (North America)',
#   'country': 'United States'},
#  {'title': 'The Jungle Book',
#   'link': '/wiki/The_Jungle_Book_(1967_film)',
#   'release_year': 1967,
#   'directors': ['Wolfgang Reitherman'],
#   'box_office': '$378 million',
#   'country': 'United States'},
#  {'title': "Who's Afraid of Virginia Woolf?",
#   'link': '/wiki/Who%27s_Afraid_of_Virginia_Woolf%3F_(film)',
#   'release_year': 1966,
#   'directors': ['Mike Nichols'],
#   'box_office': '$33.7 million',
#   'country': 'United States'},
#  {'title': 'Hawaii',
#   'link': '/wiki/Hawaii_(1966_film)',
#   'release_year': 1966,
#   'directors': ['George Roy Hill'],
#   'box_office': '$34.5 million',
#   'country': 'United States'},
#  {'title': 'The Bible: In the Beginning',
#   'link': '/wiki/The_Bible:_In_the_Beginning',
#   'release_year': 1966,
#   'directors': ['John Huston'],
#   'box_office': '$34.9 million',
#   'countries': []},
#  {'title': '2001: A Space Odyssey',
#   'link': '/wiki/2001:_A_Space_Odyssey',
#   'release_year': 1968,
#   'directors': ['Stanley Kubrick'],
#   'box_office': '$146 million',
#   'countries': ['United Kingdom', 'United States']},
#  {'title': 'Mary Poppins',
#   'link': '/wiki/Mary_Poppins_(film)',
#   'release_year': 1964,
#   'directors': ['Robert Stevenson'],
#   'box_office': '$103.1 million (US/Canada)',
#   'country': 'United States'},
#  {'title': 'From Russia with Love',
#   'link': '/wiki/From_Russia_with_Love_(film)',
#   'release_year': 1963,
#   'directors': ['Terence Young'],
#   'box_office': '$79 million',
#   'countries': []},
#  {'title': 'How the West Was Won',
#   'link': '/wiki/How_the_West_Was_Won_(film)',
#   'release_year': 1962,
#   'directors': ['Henry Hathaway', 'John Ford', 'George Marshall'],
#   'box_office': '$50 million',
#   'country': 'United States'},
#  {'title': 'The Longest Day',
#   'link': '/wiki/The_Longest_Day_(film)',
#   'release_year': 1962,
#   'directors': ['Ken Annakin', 'Andrew Marton', 'Bernhard Wicki'],
#   'box_office': '$50.1 million',
#   'country': 'United States'},
#  {'title': 'Goldfinger',
#   'link': '/wiki/Goldfinger_(film)',
#   'release_year': 1964,
#   'directors': ['Guy Hamilton'],
#   'box_office': '$125 million',
#   'countries': []},
#  {'title': 'Lawrence of Arabia',
#   'link': '/wiki/Lawrence_of_Arabia_(film)',
#   'release_year': 1962,
#   'directors': ['David Lean'],
#   'box_office': '$70 million',
#   'countries': []},
#  {'title': 'My Fair Lady',
#   'link': '/wiki/My_Fair_Lady_(film)',
#   'release_year': 1964,
#   'directors': ['George Cukor'],
#   'box_office': '$72.7 million',
#   'country': 'United States'},
#  {'title': 'Demon Slayer: Mugen Train',
#   'link': '/wiki/Demon_Slayer:_Mugen_Train',
#   'release_year': 2020,
#   'directors': ['Haruo Sotozaki'],
#   'box_office': '$507.1 million',
#   'country': 'Japan'},
#  {'title': 'One Hundred and One Dalmatians',
#   'link': '/wiki/One_Hundred_and_One_Dalmatians',
#   'release_year': 1961,
#   'directors': ['Wolfgang Reitherman', 'Hamilton Luske', 'Clyde Geronimi'],
#   'box_office': '$303 million',
#   'country': 'United States'},
#  {'title': 'Psycho',
#   'link': '/wiki/Psycho_(1960_film)',
#   'release_year': 1960,
#   'directors': ['Alfred Hitchcock'],
#   'box_office': '$50 million',
#   'country': 'United States'},
#  {'title': 'West Side Story',
#   'link': '/wiki/West_Side_Story_(1961_film)',
#   'release_year': 1961,
#   'directors': ['Robert Wise', 'Jerome Robbins'],
#   'box_office': '$44.1 million',
#   'country': 'United States'},
#  {'title': 'South Pacific',
#   'link': '/wiki/South_Pacific_(1958_film)',
#   'release_year': 1958,
#   'directors': ['Joshua Logan'],
#   'box_office': '$17.5 million',
#   'country': 'United States'},
#  {'title': 'Swiss Family Robinson',
#   'link': '/wiki/Swiss_Family_Robinson_(1960_film)',
#   'release_year': 1960,
#   'directors': ['Ken Annakin'],
#   'box_office': '$40 million',
#   'country': 'United States'},
#  {'title': 'Mister Roberts',
#   'link': '/wiki/Mister_Roberts_(1955_film)',
#   'release_year': 1955,
#   'directors': ['John Ford', 'Mervyn LeRoy', 'Joshua Logan'],
#   'box_office': '$21.2 million',
#   'country': 'United States'},
#  {'title': 'Spartacus',
#   'link': '/wiki/Spartacus_(film)',
#   'release_year': 1960,
#   'directors': ['Stanley Kubrick'],
#   'box_office': '$60 million (initial release)',
#   'country': 'United States'},
#  {'title': 'The Bridge on the River Kwai',
#   'link': '/wiki/The_Bridge_on_the_River_Kwai',
#   'release_year': 1957,
#   'directors': ['David Lean'],
#   'box_office': '$30.6 million',
#   'countries': []},
#  {'title': 'The Robe',
#   'link': '/wiki/The_Robe_(film)',
#   'release_year': 1953,
#   'directors': ['Henry Koster'],
#   'box_office': '$36 million (United States)',
#   'country': 'United States'},
#  {'title': 'Cinerama Holiday',
#   'link': '/wiki/Cinerama_Holiday',
#   'release_year': 1955,
#   'directors': ['Robert L. Bendick', 'Philippe De Lacy'],
#   'box_office': '$29.6 million',
#   'country': 'United States'},
#  {'title': '20,000 Leagues Under the Sea',
#   'link': '/wiki/20,000_Leagues_Under_the_Sea_(1954_film)',
#   'release_year': 1954,
#   'directors': ['Richard Fleischer'],
#   'box_office': '$28.2 million',
#   'country': 'United States'},
#  {'title': 'White Christmas',
#   'link': '/wiki/White_Christmas_(film)',
#   'release_year': 1954,
#   'directors': ['Michael Curtiz'],
#   'box_office': '$30 million',
#   'country': 'United States'},
#  {'title': 'Rear Window',
#   'link': '/wiki/Rear_Window',
#   'release_year': 1954,
#   'directors': ['Alfred Hitchcock'],
#   'box_office': '$37 million',
#   'country': 'United States'},
#  {'title': 'The Greatest Show on Earth',
#   'link': '/wiki/The_Greatest_Show_on_Earth_(film)',
#   'release_year': 1952,
#   'directors': ['Cecil B. DeMille'],
#   'box_office': '$36 million',
#   'country': 'United States'},
#  {'title': 'Peter Pan',
#   'link': '/wiki/Peter_Pan_(1953_film)',
#   'release_year': 1953,
#   'directors': ['Hamilton Luske', 'Clyde Geronimi', 'Wilfred Jackson'],
#   'box_office': '$87.4 million (United States and Canada)',
#   'country': 'United States'},
#  {'title': 'Lady and the Tramp',
#   'link': '/wiki/Lady_and_the_Tramp',
#   'release_year': 1955,
#   'directors': ['Hamilton Luske', 'Clyde Geronimi', 'Wilfred Jackson'],
#   'box_office': '$187 million',
#   'country': 'United States'},
#  {'title': 'This Is Cinerama',
#   'link': '/wiki/This_Is_Cinerama',
#   'release_year': 1952,
#   'directors': ['Mike Todd', 'Michael Todd, Jr.'],
#   'box_office': '$41.6 million',
#   'country': 'United States'},
#  {'title': 'Quo Vadis',
#   'link': '/wiki/Quo_Vadis_(1951_film)',
#   'release_year': 1951,
#   'directors': ['Mervyn LeRoy'],
#   'box_office': '$21 million',
#   'country': 'United States'},
#  {'title': "King Solomon's Mines",
#   'link': '/wiki/King_Solomon%27s_Mines_(1950_film)',
#   'release_year': 1950,
#   'directors': ['Compton Bennett', 'Andrew Marton'],
#   'box_office': '$15.1 million',
#   'country': 'United States'},
#  {'title': 'Samson and Delilah',
#   'link': '/wiki/Samson_and_Delilah_(1949_film)',
#   'release_year': 1949,
#   'directors': ['Cecil B. DeMille'],
#   'box_office': '$25.6 million',
#   'country': 'United States'},
#  {'title': 'The Snake Pit',
#   'link': '/wiki/The_Snake_Pit',
#   'release_year': 1948,
#   'directors': ['Anatole Litvak'],
#   'box_office': '$10 million (Worldwide)',
#   'country': 'United States'},
#  {'title': 'Cinderella',
#   'link': '/wiki/Cinderella_(1950_film)',
#   'release_year': 1950,
#   'directors': ['Wilfred Jackson', 'Hamilton Luske', 'Clyde Geronimi'],
#   'box_office': '$182 million',
#   'country': 'United States'},
#  {'title': 'Unconquered',
#   'link': '/wiki/Unconquered_(1947_film)',
#   'release_year': 1947,
#   'directors': ['Cecil B. DeMille'],
#   'box_office': '$6,665,592',
#   'country': 'United States'},
#  {'title': 'Forever Amber',
#   'link': '/wiki/Forever_Amber_(film)',
#   'release_year': 1947,
#   'directors': ['Otto Preminger', 'John M. Stahl'],
#   'box_office': '$5 million (est. US/ Canada rentals)',
#   'country': 'United States'},
#  {'title': 'Easter Parade',
#   'link': '/wiki/Easter_Parade_(film)',
#   'release_year': 1948,
#   'directors': ['Charles Walters'],
#   'box_office': '$6.8 million',
#   'country': 'United States'},
#  {'title': 'The Red Shoes',
#   'link': '/wiki/The_Red_Shoes_(1948_film)',
#   'release_year': 1948,
#   'directors': ['Michael Powell', 'Emeric Pressburger'],
#   'box_office': '$5 million (U.S. and Canada rentals)',
#   'country': 'United Kingdom'},
#  {'title': 'Duel in the Sun',
#   'link': '/wiki/Duel_in_the_Sun_(film)',
#   'release_year': 1946,
#   'directors': ['King Vidor'],
#   'box_office': '$20.4 million',
#   'country': 'United States'},
#  {'title': 'The Best Years of Our Lives',
#   'link': '/wiki/The_Best_Years_of_Our_Lives',
#   'release_year': 1946,
#   'directors': ['William Wyler'],
#   'box_office': '$23.7 million',
#   'country': 'United States'},
#  {'title': 'Song of the South',
#   'link': '/wiki/Song_of_the_South',
#   'release_year': 1946,
#   'directors': ['Wilfred Jackson'],
#   'box_office': '$65 million',
#   'country': 'United States'},
#  {'title': 'Mom and Dad',
#   'link': '/wiki/Mom_and_Dad_(1945_film)',
#   'release_year': 1945,
#   'directors': ['William Beaudine'],
#   'box_office': '$40–100 million (estimated)',
#   'country': 'United States'},
#  {'title': 'Going My Way',
#   'link': '/wiki/Going_My_Way',
#   'release_year': 1944,
#   'directors': ['Leo McCarey'],
#   'box_office': '$6.5 million (US/Canada rentals)',
#   'country': 'United States'},
#  {'title': 'This Is the Army',
#   'link': '/wiki/This_Is_the_Army',
#   'release_year': 1943,
#   'directors': ['Michael Curtiz', '1'],
#   'box_office': '$10,445,000',
#   'country': 'United States'},
#  {'title': 'For Whom the Bell Tolls',
#   'link': '/wiki/For_Whom_the_Bell_Tolls_(film)',
#   'release_year': 1943,
#   'directors': ['Sam Wood'],
#   'box_office': '$17.8 million (worldwide)',
#   'country': 'United States'},
#  {'title': 'Mrs. Miniver',
#   'link': '/wiki/Mrs._Miniver',
#   'release_year': 1942,
#   'directors': ['William Wyler'],
#   'box_office': '$8.9 million',
#   'country': 'United States'},
#  {'title': "The Bells of St. Mary's",
#   'link': '/wiki/The_Bells_of_St._Mary%27s',
#   'release_year': 1945,
#   'directors': ['Leo McCarey'],
#   'box_office': '$21.3 million (United States)',
#   'country': 'United States'},
#  {'title': 'Bambi',
#   'link': '/wiki/Bambi',
#   'release_year': 1942,
#   'directors': ['David D. Hand', 'James Algar'],
#   'box_office': '$267.4 million',
#   'country': 'United States'},
#  {'title': "You Can't Take It with You",
#   'link': '/wiki/You_Can%27t_Take_It_with_You_(film)',
#   'release_year': 1938,
#   'directors': ['Frank Capra'],
#   'box_office': 'US$2,137,575',
#   'country': 'United States'},
#  {'title': 'Boom Town',
#   'link': '/wiki/Boom_Town_(film)',
#   'release_year': 1940,
#   'directors': ['Jack Conway'],
#   'box_office': '$5 million',
#   'country': 'United States'},
#  {'title': 'San Francisco',
#   'link': '/wiki/San_Francisco_(1936_film)',
#   'release_year': 1936,
#   'directors': ['W. S. Van Dyke'],
#   'box_office': '$5.3 million',
#   'country': 'United States'},
#  {'title': 'Mutiny on the Bounty',
#   'link': '/wiki/Mutiny_on_the_Bounty_(1935_film)',
#   'release_year': 1935,
#   'directors': ['Frank Lloyd'],
#   'box_office': '$4,460,000',
#   'country': 'United States'},
#  {'title': 'Sergeant York',
#   'link': '/wiki/Sergeant_York_(film)',
#   'release_year': 1941,
#   'directors': ['Howard Hawks'],
#   'box_office': '$8.3 million',
#   'country': 'United States'},
#  {'title': 'Pinocchio',
#   'link': '/wiki/Pinocchio_(1940_film)',
#   'release_year': 1940,
#   'directors': ['Ben Sharpsteen',
#    'Hamilton Luske',
#    'Norman Ferguson',
#    'Jack Kinney',
#    'Wilfred Jackson',
#    'T. Hee'],
#   'box_office': '$164 million',
#   'country': 'United States'},
#  {'title': 'Snow White and the Seven Dwarfs',
#   'link': '/wiki/Snow_White_and_the_Seven_Dwarfs_(1937_film)',
#   'release_year': 1937,
#   'directors': ['David Hand',
#    'Perce Pearce',
#    'Larry Morey',
#    'Wilfred Jackson',
#    'Ben Sharpsteen'],
#   'box_office': '$418 million',
#   'country': 'United States'},
#  {'title': 'The Merry Widow',
#   'link': '/wiki/The_Merry_Widow_(1934_film)',
#   'release_year': 1934,
#   'directors': ['Ernst Lubitsch'],
#   'box_office': '$2.8 million (worldwide rentals)',
#   'country': 'United States'},
#  {'title': 'She Done Him Wrong',
#   'link': '/wiki/She_Done_Him_Wrong',
#   'release_year': 1933,
#   'directors': ['Lowell Sherman'],
#   'box_office': '$2.2 million',
#   'country': 'United States'},
#  {'title': 'Cavalcade',
#   'link': '/wiki/Cavalcade_(1933_film)',
#   'release_year': 1933,
#   'directors': ['Frank Lloyd'],
#   'box_office': '$1,004,000 (domestic rentals)',
#   'country': 'United States'},
#  {'title': 'It Happened One Night',
#   'link': '/wiki/It_Happened_One_Night',
#   'release_year': 1934,
#   'directors': ['Frank Capra'],
#   'box_office': '$2.5 million (worldwide rentals)',
#   'country': 'United States'},
#  {'title': "I'm No Angel",
#   'link': '/wiki/I%27m_No_Angel',
#   'release_year': 1933,
#   'directors': ['Wesley Ruggles'],
#   'box_office': '$2,250,000 (rentals)',
#   'country': 'United States'},
#  {'title': 'Frankenstein',
#   'link': '/wiki/Frankenstein_(1931_film)',
#   'release_year': 1931,
#   'directors': ['James Whale'],
#   'box_office': '$12 million',
#   'country': 'United States'},
#  {'title': 'The Sign of the Cross',
#   'link': '/wiki/The_Sign_of_the_Cross_(1932_film)',
#   'release_year': 1932,
#   'directors': ['Cecil B. DeMille'],
#   'box_office': '$2,738,993',
#   'country': 'United States'},
#  {'title': 'All Quiet on the Western Front',
#   'link': '/wiki/All_Quiet_on_the_Western_Front_(1930_film)',
#   'release_year': 1930,
#   'directors': ['Lewis Milestone'],
#   'box_office': '$3 million',
#   'country': 'United States'},
#  {'title': 'The Broadway Melody',
#   'link': '/wiki/The_Broadway_Melody',
#   'release_year': 1929,
#   'directors': ['Harry Beaumont'],
#   'box_office': '$4.4 million',
#   'country': 'United States'},
#  {'title': 'City Lights',
#   'link': '/wiki/City_Lights',
#   'release_year': 1931,
#   'directors': ['Charlie Chaplin'],
#   'box_office': '$4.25 million (worldwide rentals)',
#   'country': 'United States'},
#  {'title': 'Sunny Side Up',
#   'link': '/wiki/Sunny_Side_Up_(1929_film)',
#   'release_year': 1929,
#   'directors': ['David Butler'],
#   'box_office': '$2.19 million (U.S. and Canada rentals)',
#   'country': 'United States'},
#  {'title': 'The Singing Fool',
#   'link': '/wiki/The_Singing_Fool',
#   'release_year': 1928,
#   'directors': ['Lloyd Bacon'],
#   'box_office': '$5,916,000',
#   'country': 'United States'},
#  {'title': 'King Kong',
#   'link': '/wiki/King_Kong_(1933_film)',
#   'release_year': 1933,
#   'directors': ['Merian C. Cooper', 'Ernest B. Schoedsack'],
#   'box_office': '$5.3 million',
#   'country': 'United States'},
#  {'title': "For Heaven's Sake",
#   'link': '/wiki/For_Heaven%27s_Sake_(1926_film)',
#   'release_year': 1926,
#   'directors': ['Sam Taylor'],
#   'box_office': '$2.6 million',
#   'country': 'United States'},
#  {'title': 'The Big Parade',
#   'link': '/wiki/The_Big_Parade',
#   'release_year': 1925,
#   'directors': ['King Vidor'],
#   'box_office': '$18–22 million',
#   'country': 'United States'},
#  {'title': 'The Sea Hawk',
#   'link': '/wiki/The_Sea_Hawk_(1924_film)',
#   'release_year': 1924,
#   'directors': ['Frank Lloyd'],
#   'box_office': '$2 million',
#   'country': 'United States'},
#  {'title': 'Douglas Fairbanks in Robin Hood',
#   'link': '/wiki/Douglas_Fairbanks_in_Robin_Hood',
#   'release_year': 1922,
#   'directors': ['Allan Dwan'],
#   'box_office': '$2,500,000 (US/Canada)',
#   'country': 'United States'},
#  {'title': 'The Covered Wagon',
#   'link': '/wiki/The_Covered_Wagon',
#   'release_year': 1923,
#   'directors': ['James Cruze'],
#   'box_office': '$4 million (U.S. and Canada rentals)',
#   'country': 'United States'},
#  {'title': 'The Four Horsemen of the Apocalypse',
#   'link': '/wiki/The_Four_Horsemen_of_the_Apocalypse_(film)',
#   'release_year': 1921,
#   'directors': ['Rex Ingram'],
#   'box_office': '$9.2 million',
#   'country': 'United States'},
#  {'title': 'Wings',
#   'link': '/wiki/Wings_(1927_film)',
#   'release_year': 1927,
#   'directors': ['William A. Wellman'],
#   'box_office': '$3.8 million (US and Canada rentals)',
#   'country': 'United States'},
#  {'title': 'Mickey',
#   'link': '/wiki/Mickey_(1918_film)',
#   'release_year': 1918,
#   'directors': ['F. Richard Jones', 'James Young'],
#   'box_office': '$16,450,000',
#   'country': 'United States'},
#  {'title': 'Way Down East',
#   'link': '/wiki/Way_Down_East',
#   'release_year': 1920,
#   'directors': ['D. W. Griffith'],
#   'box_office': '$7,500,000',
#   'country': 'United States'},
#  {'title': 'Intolerance',
#   'link': '/wiki/Intolerance_(film)',
#   'release_year': 1916,
#   'directors': ['D. W. Griffith'],
#   'box_office': '$1.75 million',
#   'country': 'United States'},
#  {'title': 'The Miracle Man',
#   'link': '/wiki/The_Miracle_Man_(1919_film)',
#   'release_year': 1919,
#   'directors': ['George Loane Tucker'],
#   'box_office': '$1 million (rentals)',
#   'country': 'United States'},
#  {'title': 'Cleopatra',
#   'link': '/wiki/Cleopatra_(1917_film)',
#   'release_year': 1917,
#   'directors': ['J. Gordon Edwards'],
#   'box_office': '$1 million',
#   'country': 'United States'},
#  {'title': 'The Birth of a Nation',
#   'link': '/wiki/The_Birth_of_a_Nation',
#   'release_year': 1915,
#   'directors': ['D. W. Griffith'],
#   'box_office': '$50–100 million',
#   'country': 'United States'},
#  {'title': 'Doctor Zhivago',
#   'link': '/wiki/Doctor_Zhivago_(film)',
#   'release_year': 1965,
#   'directors': ['David Lean'],
#   'box_office': '$111.7 million (US/Canada)',
#   'countries': ['United Kingdom', 'Italy', 'United States']},
#  {'title': 'The Ten Commandments',
#   'link': '/wiki/The_Ten_Commandments_(1956_film)',
#   'release_year': 1956,
#   'directors': ['Cecil B. DeMille'],
#   'box_office': '$122.7 million',
#   'country': 'United States'},
#  {'title': 'E.T. the Extra-Terrestrial',
#   'link': '/wiki/E.T._the_Extra-Terrestrial',
#   'release_year': 1982,
#   'directors': ['Steven Spielberg'],
#   'box_office': '$797.3 million',
#   'country': 'United States'},
#  {'title': 'The Sound of Music',
#   'link': '/wiki/The_Sound_of_Music_(film)',
#   'release_year': 1965,
#   'directors': ['Robert Wise'],
#   'box_office': '$286.2 million',
#   'country': 'United States'},
#  {'title': 'Despicable Me 3',
#   'link': '/wiki/Despicable_Me_3',
#   'release_year': 2017,
#   'directors': ['Pierre Coffin', 'Kyle Balda'],
#   'box_office': '$1.035',
#   'country': 'United States'},
#  {'title': 'Gone with the Wind',
#   'link': '/wiki/Gone_with_the_Wind_(film)',
#   'release_year': 1939,
#   'directors': ['Victor Fleming'],
#   'box_office': '>$390 million',
#   'country': 'United States'},
#  {'title': 'Star Wars',
#   'link': '/wiki/Star_Wars_(film)',
#   'release_year': 1977,
#   'directors': ['George Lucas'],
#   'box_office': '$775.4 million',
#   'country': 'United States'},
#  {'title': 'Pirates of the Caribbean: On Stranger Tides',
#   'link': '/wiki/Pirates_of_the_Caribbean:_On_Stranger_Tides',
#   'release_year': 2011,
#   'directors': ['Rob Marshall'],
#   'box_office': '$1.046 billion',
#   'country': 'United States'},
#  {'title': 'Jurassic Park',
#   'link': '/wiki/Jurassic_Park_(film)',
#   'release_year': 1993,
#   'directors': ['Steven Spielberg'],
#   'box_office': '$1.058 billion',
#   'country': 'United States'},
#  {'title': 'Moana 2',
#   'link': '/wiki/Moana_2',
#   'release_year': 2024,
#   'directors': ['David Derrick Jr.', '1', '1', '1'],
#   'box_office': '$1.05 billion',
#   'country': 'United States'},
#  {'title': 'Star Wars: Episode I – The Phantom Menace',
#   'link': '/wiki/Star_Wars:_Episode_I_%E2%80%93_The_Phantom_Menace',
#   'release_year': 1999,
#   'directors': ['George Lucas'],
#   'box_office': '$1.047 billion',
#   'country': 'United States'},
#  {'title': 'Aladdin',
#   'link': '/wiki/Aladdin_(2019_film)',
#   'release_year': 2019,
#   'directors': ['Guy Ritchie'],
#   'box_office': '$1.054 billion',
#   'country': 'United States'},
#  {'title': 'Ben-Hur',
#   'link': '/wiki/Ben-Hur_(1925_film)',
#   'release_year': 1925,
#   'directors': ['Fred Niblo', 'Charles Brabin'],
#   'box_office': '$10.7 million',
#   'country': 'United States'},
#  {'title': "Pirates of the Caribbean: Dead Man's Chest",
#   'link': '/wiki/Pirates_of_the_Caribbean:_Dead_Man%27s_Chest',
#   'release_year': 2006,
#   'directors': ['Gore Verbinski'],
#   'box_office': '$1.066 billion',
#   'country': 'United States'},
#  {'title': 'Rogue One: A Star Wars Story',
#   'link': '/wiki/Rogue_One:_A_Star_Wars_Story',
#   'release_year': 2016,
#   'directors': ['Gareth Edwards'],
#   'box_office': '$1.059 billion',
#   'country': 'United States'},
#  {'title': 'Toy Story 3',
#   'link': '/wiki/Toy_Story_3',
#   'release_year': 2010,
#   'directors': ['Lee Unkrich'],
#   'box_office': '$1.067 billion',
#   'country': 'United States'},
#  {'title': 'Toy Story 4',
#   'link': '/wiki/Toy_Story_4',
#   'release_year': 2019,
#   'directors': ['Josh Cooley'],
#   'box_office': '$1.074 billion',
#   'country': 'United States'},
#  {'title': 'Star Wars: The Rise of Skywalker',
#   'link': '/wiki/Star_Wars:_The_Rise_of_Skywalker',
#   'release_year': 2019,
#   'directors': ['J. J. Abrams'],
#   'box_office': '$1.077 billion',
#   'country': 'United States'},
#  {'title': 'Transformers: Age of Extinction',
#   'link': '/wiki/Transformers:_Age_of_Extinction',
#   'release_year': 2014,
#   'directors': ['Michael Bay'],
#   'box_office': '$1.104 billion',
#   'country': 'United States'},
#  {'title': 'Skyfall',
#   'link': '/wiki/Skyfall',
#   'release_year': 2012,
#   'directors': ['Sam Mendes'],
#   'box_office': '$1.109 billion',
#   'countries': ['United Kingdom', 'United States']},
#  {'title': 'Transformers: Dark of the Moon',
#   'link': '/wiki/Transformers:_Dark_of_the_Moon',
#   'release_year': 2011,
#   'directors': ['Michael Bay'],
#   'box_office': '$1.124 billion',
#   'country': 'United States'},
#  {'title': 'Spider-Man: Far From Home',
#   'link': '/wiki/Spider-Man:_Far_From_Home',
#   'release_year': 2019,
#   'directors': ['Jon Watts'],
#   'box_office': '$1.133 billion',
#   'country': 'United States'},
#  {'title': 'The Dark Knight Rises',
#   'link': '/wiki/The_Dark_Knight_Rises',
#   'release_year': 2012,
#   'directors': ['Christopher Nolan'],
#   'box_office': '$1.115 billion',
#   'countries': ['United States', 'United Kingdom']},
#  {'title': 'Joker',
#   'link': '/wiki/Joker_(2019_film)',
#   'release_year': 2019,
#   'directors': ['Todd Phillips'],
#   'box_office': '$1.079 billion',
#   'country': 'United States'},
#  {'title': 'Captain Marvel',
#   'link': '/wiki/Captain_Marvel_(film)',
#   'release_year': 2019,
#   'directors': ['Anna Boden', 'Ryan Fleck'],
#   'box_office': '$1.131 billion',
#   'country': 'United States'},
#  {'title': 'Captain America: Civil War',
#   'link': '/wiki/Captain_America:_Civil_War',
#   'release_year': 2016,
#   'directors': None,
#   'box_office': '$1.155',
#   'country': 'United States'},
#  {'title': 'Aquaman',
#   'link': '/wiki/Aquaman_(film)',
#   'release_year': 2018,
#   'directors': ['James Wan'],
#   'box_office': '$1.152 billion',
#   'country': 'United States'},
#  {'title': 'Top Gun: Maverick',
#   'link': '/wiki/Top_Gun:_Maverick',
#   'release_year': 2022,
#   'directors': ['Joseph Kosinski'],
#   'box_office': '$1.496 billion',
#   'country': 'United States'},
#  {'title': 'The Lord of the Rings: The Return of the King',
#   'link': '/wiki/The_Lord_of_the_Rings:_The_Return_of_the_King',
#   'release_year': 2003,
#   'directors': ['Peter Jackson'],
#   'box_office': '$1.151 billion',
#   'countries': ['New Zealand', 'Germany', 'United States']},
#  {'title': 'The Lion King',
#   'link': '/wiki/The_Lion_King_(2019_film)',
#   'release_year': 2019,
#   'directors': ['Jon Favreau'],
#   'box_office': '$1.657 billion',
#   'country': 'United States'},
#  {'title': 'Jurassic World',
#   'link': '/wiki/Jurassic_World',
#   'release_year': 2015,
#   'directors': ['Colin Trevorrow'],
#   'box_office': '$1.671 billion',
#   'country': 'United States'},
#  {'title': 'Furious 7',
#   'link': '/wiki/Furious_7',
#   'release_year': 2015,
#   'directors': ['James Wan'],
#   'box_office': '$1.515 billion',
#   'countries': []},
#  {'title': 'The Avengers',
#   'link': '/wiki/The_Avengers_(2012_film)',
#   'release_year': 2012,
#   'directors': ['Joss Whedon'],
#   'box_office': '$1.521 billion',
#   'country': 'United States'},
#  {'title': 'Ne Zha 2',
#   'link': '/wiki/Ne_Zha_2',
#   'release_year': 2025,
#   'directors': ['Jiaozi'],
#   'box_office': '$1.87 billion',
#   'country': 'China'},
#  {'title': 'Inside Out 2',
#   'link': '/wiki/Inside_Out_2',
#   'release_year': 2024,
#   'directors': ['Kelsey Mann'],
#   'box_office': '$1.699 billion',
#   'country': 'United States'},
#  {'title': 'Spider-Man: No Way Home',
#   'link': '/wiki/Spider-Man:_No_Way_Home',
#   'release_year': 2021,
#   'directors': ['Jon Watts'],
#   'box_office': '$1.953 billion',
#   'country': 'United States'},
#  {'title': 'Avengers: Endgame',
#   'link': '/wiki/Avengers:_Endgame',
#   'release_year': 2019,
#   'directors': None,
#   'box_office': '$2.799',
#   'country': 'United States'},
#  {'title': 'Avengers: Infinity War',
#   'link': '/wiki/Avengers:_Infinity_War',
#   'release_year': 2018,
#   'directors': None,
#   'box_office': '$2.052 billion',
#   'country': 'United States'},
#  {'title': 'Star Wars: The Force Awakens',
#   'link': '/wiki/Star_Wars:_The_Force_Awakens',
#   'release_year': 2015,
#   'directors': ['J. J. Abrams'],
#   'box_office': '$2.07',
#   'country': 'United States'},
#  {'title': 'Titanic',
#   'link': '/wiki/Titanic_(1997_film)',
#   'release_year': 1997,
#   'directors': ['James Cameron'],
#   'box_office': '$2.264 billion',
#   'country': 'United States'},
#  {'title': 'Avatar: The Way of Water',
#   'link': '/wiki/Avatar:_The_Way_of_Water',
#   'release_year': 2022,
#   'directors': ['James Cameron'],
#   'box_office': '$2.320 billion',
#   'country': 'United States'}]

# %% [markdown]
# Now check for missing values

# %%
def validate_entries(entries):
    valid_entries = []
    invalid_entries = []

    for entry in entries:
        if (
            'title' in entry and entry['title'] and
            'release_year' in entry and entry['release_year'] and
            'directors' in entry and entry['directors'] and entry['directors'] != [] and
            'box_office' in entry and entry['box_office'] and
            ('countries' in entry and entry['countries'] and entry['countries'] != [] or
             'country' in entry and entry['country'])
        ):
            valid_entries.append(entry)
        else:
            invalid_entries.append(entry)

    return valid_entries, invalid_entries

# %%
valid_entries, invalid_entries = validate_entries(films_data)

# %%
with open('invalid_entries.json', 'w', encoding='utf-8') as f:
    json.dump(invalid_entries, f, ensure_ascii=False, indent=4)

print(f"Valid entries: {len(valid_entries)}")
# Out:
# Valid entries: 166

# %%
len(invalid_entries)
# Out:
# 11

# %%
invalid_entries
# Out:
# [{'title': 'Moonraker',
#   'link': '/wiki/Moonraker_(film)',
#   'release_year': 1979,
#   'directors': ['Lewis Gilbert'],
#   'box_office': '$210.3 million',
#   'countries': []},
#  {'title': 'Diamonds Are Forever',
#   'link': '/wiki/Diamonds_Are_Forever_(film)',
#   'release_year': 1971,
#   'directors': ['Guy Hamilton'],
#   'box_office': '$116 million',
#   'countries': []},
#  {'title': 'The Bible: In the Beginning',
#   'link': '/wiki/The_Bible:_In_the_Beginning',
#   'release_year': 1966,
#   'directors': ['John Huston'],
#   'box_office': '$34.9 million',
#   'countries': []},
#  {'title': 'From Russia with Love',
#   'link': '/wiki/From_Russia_with_Love_(film)',
#   'release_year': 1963,
#   'directors': ['Terence Young'],
#   'box_office': '$79 million',
#   'countries': []},
#  {'title': 'Goldfinger',
#   'link': '/wiki/Goldfinger_(film)',
#   'release_year': 1964,
#   'directors': ['Guy Hamilton'],
#   'box_office': '$125 million',
#   'countries': []},
#  {'title': 'Lawrence of Arabia',
#   'link': '/wiki/Lawrence_of_Arabia_(film)',
#   'release_year': 1962,
#   'directors': ['David Lean'],
#   'box_office': '$70 million',
#   'countries': []},
#  {'title': 'The Bridge on the River Kwai',
#   'link': '/wiki/The_Bridge_on_the_River_Kwai',
#   'release_year': 1957,
#   'directors': ['David Lean'],
#   'box_office': '$30.6 million',
#   'countries': []},
#  {'title': 'Captain America: Civil War',
#   'link': '/wiki/Captain_America:_Civil_War',
#   'release_year': 2016,
#   'directors': None,
#   'box_office': '$1.155',
#   'country': 'United States'},
#  {'title': 'Furious 7',
#   'link': '/wiki/Furious_7',
#   'release_year': 2015,
#   'directors': ['James Wan'],
#   'box_office': '$1.515 billion',
#   'countries': []},
#  {'title': 'Avengers: Endgame',
#   'link': '/wiki/Avengers:_Endgame',
#   'release_year': 2019,
#   'directors': None,
#   'box_office': '$2.799',
#   'country': 'United States'},
#  {'title': 'Avengers: Infinity War',
#   'link': '/wiki/Avengers:_Infinity_War',
#   'release_year': 2018,
#   'directors': None,
#   'box_office': '$2.052 billion',
#   'country': 'United States'}]

# %% [markdown]
# Since there are very little amount of invalid entries, i will their data by hand (3 minutes)

# %%
with open('invalid_entries_filled.json', 'r') as f:
    invalid_entries_filled = json.load(f)

invalid_entries_filled
# Out:
# [{'title': 'Moonraker',
#   'link': '/wiki/Moonraker_(film)',
#   'release_year': 1979,
#   'directors': ['Lewis Gilbert'],
#   'box_office': '$210.3 million',
#   'countries': ['United Kingdom', 'United States', 'France']},
#  {'title': 'Diamonds Are Forever',
#   'link': '/wiki/Diamonds_Are_Forever_(film)',
#   'release_year': 1971,
#   'directors': ['Guy Hamilton'],
#   'box_office': '$116 million',
#   'countries': ['United Kingdom', 'United States']},
#  {'title': 'The Bible: In the Beginning',
#   'link': '/wiki/The_Bible:_In_the_Beginning',
#   'release_year': 1966,
#   'directors': ['John Huston'],
#   'box_office': '$34.9 million',
#   'countries': ['Italy', 'United States']},
#  {'title': 'From Russia with Love',
#   'link': '/wiki/From_Russia_with_Love_(film)',
#   'release_year': 1963,
#   'directors': ['Terence Young'],
#   'box_office': '$79 million',
#   'countries': ['United Kingdom', 'United States']},
#  {'title': 'Goldfinger',
#   'link': '/wiki/Goldfinger_(film)',
#   'release_year': 1964,
#   'directors': ['Guy Hamilton'],
#   'box_office': '$125 million',
#   'countries': ['United Kingdom', 'United States']},
#  {'title': 'Lawrence of Arabia',
#   'link': '/wiki/Lawrence_of_Arabia_(film)',
#   'release_year': 1962,
#   'directors': ['David Lean'],
#   'box_office': '$70 million',
#   'countries': ['United Kingdom', 'United States']},
#  {'title': 'The Bridge on the River Kwai',
#   'link': '/wiki/The_Bridge_on_the_River_Kwai',
#   'release_year': 1957,
#   'directors': ['David Lean'],
#   'box_office': '$30.6 million',
#   'countries': ['United Kingdom', 'United States']},
#  {'title': 'Captain America: Civil War',
#   'link': '/wiki/Captain_America:_Civil_War',
#   'release_year': 2016,
#   'directors': ['Anthony Russo', 'Joe Russo'],
#   'box_office': '$1.155',
#   'country': 'United States'},
#  {'title': 'Furious 7',
#   'link': '/wiki/Furious_7',
#   'release_year': 2015,
#   'directors': ['James Wan'],
#   'box_office': '$1.515 billion',
#   'countries': ['United States', 'China']},
#  {'title': 'Avengers: Endgame',
#   'link': '/wiki/Avengers:_Endgame',
#   'release_year': 2019,
#   'directors': ['Anthony Russo', 'Joe Russo'],
#   'box_office': '$2.799',
#   'country': 'United States'},
#  {'title': 'Avengers: Infinity War',
#   'link': '/wiki/Avengers:_Infinity_War',
#   'release_year': 2018,
#   'directors': ['Anthony Russo', 'Joe Russo'],
#   'box_office': '$2.052 billion',
#   'country': 'United States'}]

# %%
all_entries = valid_entries + invalid_entries_filled

# %%
all_entries
# Out:
# [{'title': 'Avatar',
#   'link': '/wiki/Avatar_(2009_film)',
#   'release_year': 2009,
#   'directors': ['James Cameron'],
#   'box_office': '$2.923 billion',
#   'countries': ['United Kingdom', 'United States']},
#  {'title': 'Star Wars: The Last Jedi',
#   'link': '/wiki/Star_Wars:_The_Last_Jedi',
#   'release_year': 2017,
#   'directors': ['Rian Johnson'],
#   'box_office': '$1.334',
#   'country': 'United States'},
#  {'title': 'Deadpool & Wolverine',
#   'link': '/wiki/Deadpool_%26_Wolverine',
#   'release_year': 2024,
#   'directors': ['Shawn Levy'],
#   'box_office': '$1.338 billion',
#   'country': 'United States'},
#  {'title': 'Harry Potter and the Deathly Hallows – Part 2',
#   'link': '/wiki/Harry_Potter_and_the_Deathly_Hallows_%E2%80%93_Part_2',
#   'release_year': 2011,
#   'directors': ['David Yates'],
#   'box_office': '$1.342 billion',
#   'countries': ['United Kingdom', 'United States']},
#  {'title': 'Black Panther',
#   'link': '/wiki/Black_Panther_(film)',
#   'release_year': 2018,
#   'directors': ['Ryan Coogler'],
#   'box_office': '$1.35 billion',
#   'country': 'United States'},
#  {'title': 'The Fate of the Furious',
#   'link': '/wiki/The_Fate_of_the_Furious',
#   'release_year': 2017,
#   'directors': ['F. Gary Gray'],
#   'box_office': '$1.236 billion',
#   'countries': ['United States', 'China']},
#  {'title': 'Incredibles 2',
#   'link': '/wiki/Incredibles_2',
#   'release_year': 2018,
#   'directors': ['Brad Bird'],
#   'box_office': '$1.243 billion',
#   'country': 'United States'},
#  {'title': 'Minions',
#   'link': '/wiki/Minions_(film)',
#   'release_year': 2015,
#   'directors': ['Pierre Coffin', 'Kyle Balda'],
#   'box_office': '$1.159 billion',
#   'country': 'United States'},
#  {'title': 'Jurassic World: Fallen Kingdom',
#   'link': '/wiki/Jurassic_World:_Fallen_Kingdom',
#   'release_year': 2018,
#   'directors': ['J. A. Bayona'],
#   'box_office': '$1.31 billion',
#   'countries': ['China', 'United States']},
#  {'title': 'Iron Man 3',
#   'link': '/wiki/Iron_Man_3',
#   'release_year': 2013,
#   'directors': ['Shane Black'],
#   'box_office': '$1.266 billion',
#   'country': 'United States'},
#  {'title': 'Frozen',
#   'link': '/wiki/Frozen_(2013_film)',
#   'release_year': 2013,
#   'directors': ['Chris Buck', 'Jennifer Lee'],
#   'box_office': '$1.280 billion',
#   'country': 'United States'},
#  {'title': 'Beauty and the Beast',
#   'link': '/wiki/Beauty_and_the_Beast_(2017_film)',
#   'release_year': 2017,
#   'directors': ['Bill Condon'],
#   'box_office': '$1.266',
#   'country': 'United States'},
#  {'title': 'The Super Mario Bros. Movie',
#   'link': '/wiki/The_Super_Mario_Bros._Movie',
#   'release_year': 2023,
#   'directors': ['Aaron Horvath', 'Michael Jelenic'],
#   'box_office': '$1.360 billion',
#   'country': 'United States'},
#  {'title': 'Harry Potter and the Goblet of Fire',
#   'link': '/wiki/Harry_Potter_and_the_Goblet_of_Fire_(film)',
#   'release_year': 2005,
#   'directors': ['Mike Newell'],
#   'box_office': '$897.5 million',
#   'countries': ['United Kingdom', 'United States']},
#  {'title': "Pirates of the Caribbean: At World's End",
#   'link': '/wiki/Pirates_of_the_Caribbean:_At_World%27s_End',
#   'release_year': 2007,
#   'directors': ['Gore Verbinski'],
#   'box_office': '$963.4 million',
#   'country': 'United States'},
#  {'title': 'Avengers: Age of Ultron',
#   'link': '/wiki/Avengers:_Age_of_Ultron',
#   'release_year': 2015,
#   'directors': ['Joss Whedon'],
#   'box_office': '$1.405 billion',
#   'country': 'United States'},
#  {'title': 'Barbie',
#   'link': '/wiki/Barbie_(film)',
#   'release_year': 2023,
#   'directors': ['Greta Gerwig'],
#   'box_office': '$1.446 billion',
#   'countries': ['United States', 'United Kingdom']},
#  {'title': 'The Dark Knight',
#   'link': '/wiki/The_Dark_Knight',
#   'release_year': 2008,
#   'directors': ['Christopher Nolan'],
#   'box_office': '$1.006',
#   'countries': ['United States', 'United Kingdom']},
#  {'title': 'Shrek 2',
#   'link': '/wiki/Shrek_2',
#   'release_year': 2004,
#   'directors': ['Andrew Adamson', 'Kelly Asbury', 'Conrad Vernon'],
#   'box_office': '$935.5 million',
#   'country': 'United States'},
#  {'title': 'Armageddon',
#   'link': '/wiki/Armageddon_(1998_film)',
#   'release_year': 1998,
#   'directors': ['Michael Bay'],
#   'box_office': '$553.7 million',
#   'country': 'United States'},
#  {'title': "Harry Potter and the Philosopher's Stone",
#   'link': '/wiki/Harry_Potter_and_the_Philosopher%27s_Stone_(film)',
#   'release_year': 2001,
#   'directors': ['Chris Columbus'],
#   'box_office': '$1.026 billion',
#   'countries': ['United Kingdom', 'United States']},
#  {'title': 'The Lord of the Rings: The Two Towers',
#   'link': '/wiki/The_Lord_of_the_Rings:_The_Two_Towers',
#   'release_year': 2002,
#   'directors': ['Peter Jackson'],
#   'box_office': '$951.6 million',
#   'countries': ['New Zealand', 'United States']},
#  {'title': 'Die Hard with a Vengeance',
#   'link': '/wiki/Die_Hard_with_a_Vengeance',
#   'release_year': 1995,
#   'directors': ['John McTiernan'],
#   'box_office': '$366.1 million',
#   'country': 'United States'},
#  {'title': 'Mission: Impossible 2',
#   'link': '/wiki/Mission:_Impossible_2',
#   'release_year': 2000,
#   'directors': ['John Woo'],
#   'box_office': '$546.3 million',
#   'countries': ['United States', 'Germany']},
#  {'title': 'Independence Day',
#   'link': '/wiki/Independence_Day_(1996_film)',
#   'release_year': 1996,
#   'directors': ['Roland Emmerich'],
#   'box_office': '$817.4 million',
#   'country': 'United States'},
#  {'title': 'Rain Man',
#   'link': '/wiki/Rain_Man',
#   'release_year': 1988,
#   'directors': ['Barry Levinson'],
#   'box_office': '$354.8',
#   'country': 'United States'},
#  {'title': 'Ghost',
#   'link': '/wiki/Ghost_(1990_film)',
#   'release_year': 1990,
#   'directors': ['Jerry Zucker'],
#   'box_office': '$505.7 million',
#   'country': 'United States'},
#  {'title': 'Indiana Jones and the Last Crusade',
#   'link': '/wiki/Indiana_Jones_and_the_Last_Crusade',
#   'release_year': 1989,
#   'directors': ['Steven Spielberg'],
#   'box_office': '$474.2 million',
#   'country': 'United States'},
#  {'title': 'Toy Story',
#   'link': '/wiki/Toy_Story',
#   'release_year': 1995,
#   'directors': ['John Lasseter'],
#   'box_office': '$394.4 million',
#   'country': 'United States'},
#  {'title': 'Frozen 2',
#   'link': '/wiki/Frozen_2',
#   'release_year': 2019,
#   'directors': ['Chris Buck', 'Jennifer Lee'],
#   'box_office': '$1.453',
#   'country': 'United States'},
#  {'title': 'Fatal Attraction',
#   'link': '/wiki/Fatal_Attraction',
#   'release_year': 1987,
#   'directors': ['Adrian Lyne'],
#   'box_office': '$320.1 million',
#   'country': 'United States'},
#  {'title': 'Terminator 2: Judgment Day',
#   'link': '/wiki/Terminator_2:_Judgment_Day',
#   'release_year': 1991,
#   'directors': ['James Cameron'],
#   'box_office': '$519–520.9',
#   'country': 'United States'},
#  {'title': 'Top Gun',
#   'link': '/wiki/Top_Gun',
#   'release_year': 1986,
#   'directors': ['Tony Scott'],
#   'box_office': '$357.3 million',
#   'country': 'United States'},
#  {'title': 'Back to the Future',
#   'link': '/wiki/Back_to_the_Future',
#   'release_year': 1985,
#   'directors': ['Robert Zemeckis'],
#   'box_office': '$388.8 million',
#   'country': 'United States'},
#  {'title': 'Rocky II',
#   'link': '/wiki/Rocky_II',
#   'release_year': 1979,
#   'directors': ['Sylvester Stallone'],
#   'box_office': '$200.1 million',
#   'country': 'United States'},
#  {'title': 'Ghostbusters',
#   'link': '/wiki/Ghostbusters',
#   'release_year': 1984,
#   'directors': ['Ivan Reitman'],
#   'box_office': '$370 million',
#   'country': 'United States'},
#  {'title': 'Return of the Jedi',
#   'link': '/wiki/Return_of_the_Jedi',
#   'release_year': 1983,
#   'directors': ['Richard Marquand'],
#   'box_office': '$482 million',
#   'country': 'United States'},
#  {'title': 'Grease',
#   'link': '/wiki/Grease_(film)',
#   'release_year': 1978,
#   'directors': ['Randal Kleiser'],
#   'box_office': '$396.3 million',
#   'country': 'United States'},
#  {'title': 'The Empire Strikes Back',
#   'link': '/wiki/The_Empire_Strikes_Back',
#   'release_year': 1980,
#   'directors': ['Irvin Kershner'],
#   'box_office': '$538–549',
#   'country': 'United States'},
#  {'title': 'Raiders of the Lost Ark',
#   'link': '/wiki/Raiders_of_the_Lost_Ark',
#   'release_year': 1981,
#   'directors': ['Steven Spielberg'],
#   'box_office': '$389.9',
#   'country': 'United States'},
#  {'title': 'The Towering Inferno',
#   'link': '/wiki/The_Towering_Inferno',
#   'release_year': 1974,
#   'directors': ['John Guillermin', 'Irwin Allen'],
#   'box_office': '$203.3 million',
#   'country': 'United States'},
#  {'title': 'The Sting',
#   'link': '/wiki/The_Sting',
#   'release_year': 1973,
#   'directors': ['George Roy Hill'],
#   'box_office': '$257 million',
#   'country': 'United States'},
#  {'title': 'Jaws',
#   'link': '/wiki/Jaws_(film)',
#   'release_year': 1975,
#   'directors': ['Steven Spielberg'],
#   'box_office': '$476.5 million',
#   'country': 'United States'},
#  {'title': 'Rocky',
#   'link': '/wiki/Rocky',
#   'release_year': 1976,
#   'directors': ['John G. Avildsen'],
#   'box_office': '$225 million',
#   'country': 'United States'},
#  {'title': 'Fiddler on the Roof',
#   'link': '/wiki/Fiddler_on_the_Roof_(film)',
#   'release_year': 1971,
#   'directors': ['Norman Jewison'],
#   'box_office': '$83.3 million',
#   'country': 'United States'},
#  {'title': 'The French Connection',
#   'link': '/wiki/The_French_Connection_(film)',
#   'release_year': 1971,
#   'directors': ['William Friedkin'],
#   'box_office': '$75 million (worldwide',
#   'country': 'United States'},
#  {'title': 'The Exorcist',
#   'link': '/wiki/The_Exorcist',
#   'release_year': 1973,
#   'directors': ['William Friedkin'],
#   'box_office': '$441.3 million',
#   'country': 'United States'},
#  {'title': 'The Godfather',
#   'link': '/wiki/The_Godfather',
#   'release_year': 1972,
#   'directors': ['Francis Ford Coppola'],
#   'box_office': '$250–291 million',
#   'country': 'United States'},
#  {'title': 'Love Story',
#   'link': '/wiki/Love_Story_(1970_film)',
#   'release_year': 1970,
#   'directors': ['Arthur Hiller'],
#   'box_office': '$173.4 million',
#   'country': 'United States'},
#  {'title': 'Funny Girl',
#   'link': '/wiki/Funny_Girl_(film)',
#   'release_year': 1968,
#   'directors': ['William Wyler'],
#   'box_office': '$58.5 million',
#   'country': 'United States'},
#  {'title': 'Butch Cassidy and the Sundance Kid',
#   'link': '/wiki/Butch_Cassidy_and_the_Sundance_Kid',
#   'release_year': 1969,
#   'directors': ['George Roy Hill'],
#   'box_office': '$102.3 million',
#   'country': 'United States'},
#  {'title': 'The Graduate',
#   'link': '/wiki/The_Graduate',
#   'release_year': 1967,
#   'directors': ['Mike Nichols'],
#   'box_office': '$104.9 million (North America)',
#   'country': 'United States'},
#  {'title': 'The Jungle Book',
#   'link': '/wiki/The_Jungle_Book_(1967_film)',
#   'release_year': 1967,
#   'directors': ['Wolfgang Reitherman'],
#   'box_office': '$378 million',
#   'country': 'United States'},
#  {'title': "Who's Afraid of Virginia Woolf?",
#   'link': '/wiki/Who%27s_Afraid_of_Virginia_Woolf%3F_(film)',
#   'release_year': 1966,
#   'directors': ['Mike Nichols'],
#   'box_office': '$33.7 million',
#   'country': 'United States'},
#  {'title': 'Hawaii',
#   'link': '/wiki/Hawaii_(1966_film)',
#   'release_year': 1966,
#   'directors': ['George Roy Hill'],
#   'box_office': '$34.5 million',
#   'country': 'United States'},
#  {'title': '2001: A Space Odyssey',
#   'link': '/wiki/2001:_A_Space_Odyssey',
#   'release_year': 1968,
#   'directors': ['Stanley Kubrick'],
#   'box_office': '$146 million',
#   'countries': ['United Kingdom', 'United States']},
#  {'title': 'Mary Poppins',
#   'link': '/wiki/Mary_Poppins_(film)',
#   'release_year': 1964,
#   'directors': ['Robert Stevenson'],
#   'box_office': '$103.1 million (US/Canada)',
#   'country': 'United States'},
#  {'title': 'How the West Was Won',
#   'link': '/wiki/How_the_West_Was_Won_(film)',
#   'release_year': 1962,
#   'directors': ['Henry Hathaway', 'John Ford', 'George Marshall'],
#   'box_office': '$50 million',
#   'country': 'United States'},
#  {'title': 'The Longest Day',
#   'link': '/wiki/The_Longest_Day_(film)',
#   'release_year': 1962,
#   'directors': ['Ken Annakin', 'Andrew Marton', 'Bernhard Wicki'],
#   'box_office': '$50.1 million',
#   'country': 'United States'},
#  {'title': 'My Fair Lady',
#   'link': '/wiki/My_Fair_Lady_(film)',
#   'release_year': 1964,
#   'directors': ['George Cukor'],
#   'box_office': '$72.7 million',
#   'country': 'United States'},
#  {'title': 'Demon Slayer: Mugen Train',
#   'link': '/wiki/Demon_Slayer:_Mugen_Train',
#   'release_year': 2020,
#   'directors': ['Haruo Sotozaki'],
#   'box_office': '$507.1 million',
#   'country': 'Japan'},
#  {'title': 'One Hundred and One Dalmatians',
#   'link': '/wiki/One_Hundred_and_One_Dalmatians',
#   'release_year': 1961,
#   'directors': ['Wolfgang Reitherman', 'Hamilton Luske', 'Clyde Geronimi'],
#   'box_office': '$303 million',
#   'country': 'United States'},
#  {'title': 'Psycho',
#   'link': '/wiki/Psycho_(1960_film)',
#   'release_year': 1960,
#   'directors': ['Alfred Hitchcock'],
#   'box_office': '$50 million',
#   'country': 'United States'},
#  {'title': 'West Side Story',
#   'link': '/wiki/West_Side_Story_(1961_film)',
#   'release_year': 1961,
#   'directors': ['Robert Wise', 'Jerome Robbins'],
#   'box_office': '$44.1 million',
#   'country': 'United States'},
#  {'title': 'South Pacific',
#   'link': '/wiki/South_Pacific_(1958_film)',
#   'release_year': 1958,
#   'directors': ['Joshua Logan'],
#   'box_office': '$17.5 million',
#   'country': 'United States'},
#  {'title': 'Swiss Family Robinson',
#   'link': '/wiki/Swiss_Family_Robinson_(1960_film)',
#   'release_year': 1960,
#   'directors': ['Ken Annakin'],
#   'box_office': '$40 million',
#   'country': 'United States'},
#  {'title': 'Mister Roberts',
#   'link': '/wiki/Mister_Roberts_(1955_film)',
#   'release_year': 1955,
#   'directors': ['John Ford', 'Mervyn LeRoy', 'Joshua Logan'],
#   'box_office': '$21.2 million',
#   'country': 'United States'},
#  {'title': 'Spartacus',
#   'link': '/wiki/Spartacus_(film)',
#   'release_year': 1960,
#   'directors': ['Stanley Kubrick'],
#   'box_office': '$60 million (initial release)',
#   'country': 'United States'},
#  {'title': 'The Robe',
#   'link': '/wiki/The_Robe_(film)',
#   'release_year': 1953,
#   'directors': ['Henry Koster'],
#   'box_office': '$36 million (United States)',
#   'country': 'United States'},
#  {'title': 'Cinerama Holiday',
#   'link': '/wiki/Cinerama_Holiday',
#   'release_year': 1955,
#   'directors': ['Robert L. Bendick', 'Philippe De Lacy'],
#   'box_office': '$29.6 million',
#   'country': 'United States'},
#  {'title': '20,000 Leagues Under the Sea',
#   'link': '/wiki/20,000_Leagues_Under_the_Sea_(1954_film)',
#   'release_year': 1954,
#   'directors': ['Richard Fleischer'],
#   'box_office': '$28.2 million',
#   'country': 'United States'},
#  {'title': 'White Christmas',
#   'link': '/wiki/White_Christmas_(film)',
#   'release_year': 1954,
#   'directors': ['Michael Curtiz'],
#   'box_office': '$30 million',
#   'country': 'United States'},
#  {'title': 'Rear Window',
#   'link': '/wiki/Rear_Window',
#   'release_year': 1954,
#   'directors': ['Alfred Hitchcock'],
#   'box_office': '$37 million',
#   'country': 'United States'},
#  {'title': 'The Greatest Show on Earth',
#   'link': '/wiki/The_Greatest_Show_on_Earth_(film)',
#   'release_year': 1952,
#   'directors': ['Cecil B. DeMille'],
#   'box_office': '$36 million',
#   'country': 'United States'},
#  {'title': 'Peter Pan',
#   'link': '/wiki/Peter_Pan_(1953_film)',
#   'release_year': 1953,
#   'directors': ['Hamilton Luske', 'Clyde Geronimi', 'Wilfred Jackson'],
#   'box_office': '$87.4 million (United States and Canada)',
#   'country': 'United States'},
#  {'title': 'Lady and the Tramp',
#   'link': '/wiki/Lady_and_the_Tramp',
#   'release_year': 1955,
#   'directors': ['Hamilton Luske', 'Clyde Geronimi', 'Wilfred Jackson'],
#   'box_office': '$187 million',
#   'country': 'United States'},
#  {'title': 'This Is Cinerama',
#   'link': '/wiki/This_Is_Cinerama',
#   'release_year': 1952,
#   'directors': ['Mike Todd', 'Michael Todd, Jr.'],
#   'box_office': '$41.6 million',
#   'country': 'United States'},
#  {'title': 'Quo Vadis',
#   'link': '/wiki/Quo_Vadis_(1951_film)',
#   'release_year': 1951,
#   'directors': ['Mervyn LeRoy'],
#   'box_office': '$21 million',
#   'country': 'United States'},
#  {'title': "King Solomon's Mines",
#   'link': '/wiki/King_Solomon%27s_Mines_(1950_film)',
#   'release_year': 1950,
#   'directors': ['Compton Bennett', 'Andrew Marton'],
#   'box_office': '$15.1 million',
#   'country': 'United States'},
#  {'title': 'Samson and Delilah',
#   'link': '/wiki/Samson_and_Delilah_(1949_film)',
#   'release_year': 1949,
#   'directors': ['Cecil B. DeMille'],
#   'box_office': '$25.6 million',
#   'country': 'United States'},
#  {'title': 'The Snake Pit',
#   'link': '/wiki/The_Snake_Pit',
#   'release_year': 1948,
#   'directors': ['Anatole Litvak'],
#   'box_office': '$10 million (Worldwide)',
#   'country': 'United States'},
#  {'title': 'Cinderella',
#   'link': '/wiki/Cinderella_(1950_film)',
#   'release_year': 1950,
#   'directors': ['Wilfred Jackson', 'Hamilton Luske', 'Clyde Geronimi'],
#   'box_office': '$182 million',
#   'country': 'United States'},
#  {'title': 'Unconquered',
#   'link': '/wiki/Unconquered_(1947_film)',
#   'release_year': 1947,
#   'directors': ['Cecil B. DeMille'],
#   'box_office': '$6,665,592',
#   'country': 'United States'},
#  {'title': 'Forever Amber',
#   'link': '/wiki/Forever_Amber_(film)',
#   'release_year': 1947,
#   'directors': ['Otto Preminger', 'John M. Stahl'],
#   'box_office': '$5 million (est. US/ Canada rentals)',
#   'country': 'United States'},
#  {'title': 'Easter Parade',
#   'link': '/wiki/Easter_Parade_(film)',
#   'release_year': 1948,
#   'directors': ['Charles Walters'],
#   'box_office': '$6.8 million',
#   'country': 'United States'},
#  {'title': 'The Red Shoes',
#   'link': '/wiki/The_Red_Shoes_(1948_film)',
#   'release_year': 1948,
#   'directors': ['Michael Powell', 'Emeric Pressburger'],
#   'box_office': '$5 million (U.S. and Canada rentals)',
#   'country': 'United Kingdom'},
#  {'title': 'Duel in the Sun',
#   'link': '/wiki/Duel_in_the_Sun_(film)',
#   'release_year': 1946,
#   'directors': ['King Vidor'],
#   'box_office': '$20.4 million',
#   'country': 'United States'},
#  {'title': 'The Best Years of Our Lives',
#   'link': '/wiki/The_Best_Years_of_Our_Lives',
#   'release_year': 1946,
#   'directors': ['William Wyler'],
#   'box_office': '$23.7 million',
#   'country': 'United States'},
#  {'title': 'Song of the South',
#   'link': '/wiki/Song_of_the_South',
#   'release_year': 1946,
#   'directors': ['Wilfred Jackson'],
#   'box_office': '$65 million',
#   'country': 'United States'},
#  {'title': 'Mom and Dad',
#   'link': '/wiki/Mom_and_Dad_(1945_film)',
#   'release_year': 1945,
#   'directors': ['William Beaudine'],
#   'box_office': '$40–100 million (estimated)',
#   'country': 'United States'},
#  {'title': 'Going My Way',
#   'link': '/wiki/Going_My_Way',
#   'release_year': 1944,
#   'directors': ['Leo McCarey'],
#   'box_office': '$6.5 million (US/Canada rentals)',
#   'country': 'United States'},
#  {'title': 'This Is the Army',
#   'link': '/wiki/This_Is_the_Army',
#   'release_year': 1943,
#   'directors': ['Michael Curtiz', '1'],
#   'box_office': '$10,445,000',
#   'country': 'United States'},
#  {'title': 'For Whom the Bell Tolls',
#   'link': '/wiki/For_Whom_the_Bell_Tolls_(film)',
#   'release_year': 1943,
#   'directors': ['Sam Wood'],
#   'box_office': '$17.8 million (worldwide)',
#   'country': 'United States'},
#  {'title': 'Mrs. Miniver',
#   'link': '/wiki/Mrs._Miniver',
#   'release_year': 1942,
#   'directors': ['William Wyler'],
#   'box_office': '$8.9 million',
#   'country': 'United States'},
#  {'title': "The Bells of St. Mary's",
#   'link': '/wiki/The_Bells_of_St._Mary%27s',
#   'release_year': 1945,
#   'directors': ['Leo McCarey'],
#   'box_office': '$21.3 million (United States)',
#   'country': 'United States'},
#  {'title': 'Bambi',
#   'link': '/wiki/Bambi',
#   'release_year': 1942,
#   'directors': ['David D. Hand', 'James Algar'],
#   'box_office': '$267.4 million',
#   'country': 'United States'},
#  {'title': "You Can't Take It with You",
#   'link': '/wiki/You_Can%27t_Take_It_with_You_(film)',
#   'release_year': 1938,
#   'directors': ['Frank Capra'],
#   'box_office': 'US$2,137,575',
#   'country': 'United States'},
#  {'title': 'Boom Town',
#   'link': '/wiki/Boom_Town_(film)',
#   'release_year': 1940,
#   'directors': ['Jack Conway'],
#   'box_office': '$5 million',
#   'country': 'United States'},
#  {'title': 'San Francisco',
#   'link': '/wiki/San_Francisco_(1936_film)',
#   'release_year': 1936,
#   'directors': ['W. S. Van Dyke'],
#   'box_office': '$5.3 million',
#   'country': 'United States'},
#  {'title': 'Mutiny on the Bounty',
#   'link': '/wiki/Mutiny_on_the_Bounty_(1935_film)',
#   'release_year': 1935,
#   'directors': ['Frank Lloyd'],
#   'box_office': '$4,460,000',
#   'country': 'United States'},
#  {'title': 'Sergeant York',
#   'link': '/wiki/Sergeant_York_(film)',
#   'release_year': 1941,
#   'directors': ['Howard Hawks'],
#   'box_office': '$8.3 million',
#   'country': 'United States'},
#  {'title': 'Pinocchio',
#   'link': '/wiki/Pinocchio_(1940_film)',
#   'release_year': 1940,
#   'directors': ['Ben Sharpsteen',
#    'Hamilton Luske',
#    'Norman Ferguson',
#    'Jack Kinney',
#    'Wilfred Jackson',
#    'T. Hee'],
#   'box_office': '$164 million',
#   'country': 'United States'},
#  {'title': 'Snow White and the Seven Dwarfs',
#   'link': '/wiki/Snow_White_and_the_Seven_Dwarfs_(1937_film)',
#   'release_year': 1937,
#   'directors': ['David Hand',
#    'Perce Pearce',
#    'Larry Morey',
#    'Wilfred Jackson',
#    'Ben Sharpsteen'],
#   'box_office': '$418 million',
#   'country': 'United States'},
#  {'title': 'The Merry Widow',
#   'link': '/wiki/The_Merry_Widow_(1934_film)',
#   'release_year': 1934,
#   'directors': ['Ernst Lubitsch'],
#   'box_office': '$2.8 million (worldwide rentals)',
#   'country': 'United States'},
#  {'title': 'She Done Him Wrong',
#   'link': '/wiki/She_Done_Him_Wrong',
#   'release_year': 1933,
#   'directors': ['Lowell Sherman'],
#   'box_office': '$2.2 million',
#   'country': 'United States'},
#  {'title': 'Cavalcade',
#   'link': '/wiki/Cavalcade_(1933_film)',
#   'release_year': 1933,
#   'directors': ['Frank Lloyd'],
#   'box_office': '$1,004,000 (domestic rentals)',
#   'country': 'United States'},
#  {'title': 'It Happened One Night',
#   'link': '/wiki/It_Happened_One_Night',
#   'release_year': 1934,
#   'directors': ['Frank Capra'],
#   'box_office': '$2.5 million (worldwide rentals)',
#   'country': 'United States'},
#  {'title': "I'm No Angel",
#   'link': '/wiki/I%27m_No_Angel',
#   'release_year': 1933,
#   'directors': ['Wesley Ruggles'],
#   'box_office': '$2,250,000 (rentals)',
#   'country': 'United States'},
#  {'title': 'Frankenstein',
#   'link': '/wiki/Frankenstein_(1931_film)',
#   'release_year': 1931,
#   'directors': ['James Whale'],
#   'box_office': '$12 million',
#   'country': 'United States'},
#  {'title': 'The Sign of the Cross',
#   'link': '/wiki/The_Sign_of_the_Cross_(1932_film)',
#   'release_year': 1932,
#   'directors': ['Cecil B. DeMille'],
#   'box_office': '$2,738,993',
#   'country': 'United States'},
#  {'title': 'All Quiet on the Western Front',
#   'link': '/wiki/All_Quiet_on_the_Western_Front_(1930_film)',
#   'release_year': 1930,
#   'directors': ['Lewis Milestone'],
#   'box_office': '$3 million',
#   'country': 'United States'},
#  {'title': 'The Broadway Melody',
#   'link': '/wiki/The_Broadway_Melody',
#   'release_year': 1929,
#   'directors': ['Harry Beaumont'],
#   'box_office': '$4.4 million',
#   'country': 'United States'},
#  {'title': 'City Lights',
#   'link': '/wiki/City_Lights',
#   'release_year': 1931,
#   'directors': ['Charlie Chaplin'],
#   'box_office': '$4.25 million (worldwide rentals)',
#   'country': 'United States'},
#  {'title': 'Sunny Side Up',
#   'link': '/wiki/Sunny_Side_Up_(1929_film)',
#   'release_year': 1929,
#   'directors': ['David Butler'],
#   'box_office': '$2.19 million (U.S. and Canada rentals)',
#   'country': 'United States'},
#  {'title': 'The Singing Fool',
#   'link': '/wiki/The_Singing_Fool',
#   'release_year': 1928,
#   'directors': ['Lloyd Bacon'],
#   'box_office': '$5,916,000',
#   'country': 'United States'},
#  {'title': 'King Kong',
#   'link': '/wiki/King_Kong_(1933_film)',
#   'release_year': 1933,
#   'directors': ['Merian C. Cooper', 'Ernest B. Schoedsack'],
#   'box_office': '$5.3 million',
#   'country': 'United States'},
#  {'title': "For Heaven's Sake",
#   'link': '/wiki/For_Heaven%27s_Sake_(1926_film)',
#   'release_year': 1926,
#   'directors': ['Sam Taylor'],
#   'box_office': '$2.6 million',
#   'country': 'United States'},
#  {'title': 'The Big Parade',
#   'link': '/wiki/The_Big_Parade',
#   'release_year': 1925,
#   'directors': ['King Vidor'],
#   'box_office': '$18–22 million',
#   'country': 'United States'},
#  {'title': 'The Sea Hawk',
#   'link': '/wiki/The_Sea_Hawk_(1924_film)',
#   'release_year': 1924,
#   'directors': ['Frank Lloyd'],
#   'box_office': '$2 million',
#   'country': 'United States'},
#  {'title': 'Douglas Fairbanks in Robin Hood',
#   'link': '/wiki/Douglas_Fairbanks_in_Robin_Hood',
#   'release_year': 1922,
#   'directors': ['Allan Dwan'],
#   'box_office': '$2,500,000 (US/Canada)',
#   'country': 'United States'},
#  {'title': 'The Covered Wagon',
#   'link': '/wiki/The_Covered_Wagon',
#   'release_year': 1923,
#   'directors': ['James Cruze'],
#   'box_office': '$4 million (U.S. and Canada rentals)',
#   'country': 'United States'},
#  {'title': 'The Four Horsemen of the Apocalypse',
#   'link': '/wiki/The_Four_Horsemen_of_the_Apocalypse_(film)',
#   'release_year': 1921,
#   'directors': ['Rex Ingram'],
#   'box_office': '$9.2 million',
#   'country': 'United States'},
#  {'title': 'Wings',
#   'link': '/wiki/Wings_(1927_film)',
#   'release_year': 1927,
#   'directors': ['William A. Wellman'],
#   'box_office': '$3.8 million (US and Canada rentals)',
#   'country': 'United States'},
#  {'title': 'Mickey',
#   'link': '/wiki/Mickey_(1918_film)',
#   'release_year': 1918,
#   'directors': ['F. Richard Jones', 'James Young'],
#   'box_office': '$16,450,000',
#   'country': 'United States'},
#  {'title': 'Way Down East',
#   'link': '/wiki/Way_Down_East',
#   'release_year': 1920,
#   'directors': ['D. W. Griffith'],
#   'box_office': '$7,500,000',
#   'country': 'United States'},
#  {'title': 'Intolerance',
#   'link': '/wiki/Intolerance_(film)',
#   'release_year': 1916,
#   'directors': ['D. W. Griffith'],
#   'box_office': '$1.75 million',
#   'country': 'United States'},
#  {'title': 'The Miracle Man',
#   'link': '/wiki/The_Miracle_Man_(1919_film)',
#   'release_year': 1919,
#   'directors': ['George Loane Tucker'],
#   'box_office': '$1 million (rentals)',
#   'country': 'United States'},
#  {'title': 'Cleopatra',
#   'link': '/wiki/Cleopatra_(1917_film)',
#   'release_year': 1917,
#   'directors': ['J. Gordon Edwards'],
#   'box_office': '$1 million',
#   'country': 'United States'},
#  {'title': 'The Birth of a Nation',
#   'link': '/wiki/The_Birth_of_a_Nation',
#   'release_year': 1915,
#   'directors': ['D. W. Griffith'],
#   'box_office': '$50–100 million',
#   'country': 'United States'},
#  {'title': 'Doctor Zhivago',
#   'link': '/wiki/Doctor_Zhivago_(film)',
#   'release_year': 1965,
#   'directors': ['David Lean'],
#   'box_office': '$111.7 million (US/Canada)',
#   'countries': ['United Kingdom', 'Italy', 'United States']},
#  {'title': 'The Ten Commandments',
#   'link': '/wiki/The_Ten_Commandments_(1956_film)',
#   'release_year': 1956,
#   'directors': ['Cecil B. DeMille'],
#   'box_office': '$122.7 million',
#   'country': 'United States'},
#  {'title': 'E.T. the Extra-Terrestrial',
#   'link': '/wiki/E.T._the_Extra-Terrestrial',
#   'release_year': 1982,
#   'directors': ['Steven Spielberg'],
#   'box_office': '$797.3 million',
#   'country': 'United States'},
#  {'title': 'The Sound of Music',
#   'link': '/wiki/The_Sound_of_Music_(film)',
#   'release_year': 1965,
#   'directors': ['Robert Wise'],
#   'box_office': '$286.2 million',
#   'country': 'United States'},
#  {'title': 'Despicable Me 3',
#   'link': '/wiki/Despicable_Me_3',
#   'release_year': 2017,
#   'directors': ['Pierre Coffin', 'Kyle Balda'],
#   'box_office': '$1.035',
#   'country': 'United States'},
#  {'title': 'Gone with the Wind',
#   'link': '/wiki/Gone_with_the_Wind_(film)',
#   'release_year': 1939,
#   'directors': ['Victor Fleming'],
#   'box_office': '>$390 million',
#   'country': 'United States'},
#  {'title': 'Star Wars',
#   'link': '/wiki/Star_Wars_(film)',
#   'release_year': 1977,
#   'directors': ['George Lucas'],
#   'box_office': '$775.4 million',
#   'country': 'United States'},
#  {'title': 'Pirates of the Caribbean: On Stranger Tides',
#   'link': '/wiki/Pirates_of_the_Caribbean:_On_Stranger_Tides',
#   'release_year': 2011,
#   'directors': ['Rob Marshall'],
#   'box_office': '$1.046 billion',
#   'country': 'United States'},
#  {'title': 'Jurassic Park',
#   'link': '/wiki/Jurassic_Park_(film)',
#   'release_year': 1993,
#   'directors': ['Steven Spielberg'],
#   'box_office': '$1.058 billion',
#   'country': 'United States'},
#  {'title': 'Moana 2',
#   'link': '/wiki/Moana_2',
#   'release_year': 2024,
#   'directors': ['David Derrick Jr.', '1', '1', '1'],
#   'box_office': '$1.05 billion',
#   'country': 'United States'},
#  {'title': 'Star Wars: Episode I – The Phantom Menace',
#   'link': '/wiki/Star_Wars:_Episode_I_%E2%80%93_The_Phantom_Menace',
#   'release_year': 1999,
#   'directors': ['George Lucas'],
#   'box_office': '$1.047 billion',
#   'country': 'United States'},
#  {'title': 'Aladdin',
#   'link': '/wiki/Aladdin_(2019_film)',
#   'release_year': 2019,
#   'directors': ['Guy Ritchie'],
#   'box_office': '$1.054 billion',
#   'country': 'United States'},
#  {'title': 'Ben-Hur',
#   'link': '/wiki/Ben-Hur_(1925_film)',
#   'release_year': 1925,
#   'directors': ['Fred Niblo', 'Charles Brabin'],
#   'box_office': '$10.7 million',
#   'country': 'United States'},
#  {'title': "Pirates of the Caribbean: Dead Man's Chest",
#   'link': '/wiki/Pirates_of_the_Caribbean:_Dead_Man%27s_Chest',
#   'release_year': 2006,
#   'directors': ['Gore Verbinski'],
#   'box_office': '$1.066 billion',
#   'country': 'United States'},
#  {'title': 'Rogue One: A Star Wars Story',
#   'link': '/wiki/Rogue_One:_A_Star_Wars_Story',
#   'release_year': 2016,
#   'directors': ['Gareth Edwards'],
#   'box_office': '$1.059 billion',
#   'country': 'United States'},
#  {'title': 'Toy Story 3',
#   'link': '/wiki/Toy_Story_3',
#   'release_year': 2010,
#   'directors': ['Lee Unkrich'],
#   'box_office': '$1.067 billion',
#   'country': 'United States'},
#  {'title': 'Toy Story 4',
#   'link': '/wiki/Toy_Story_4',
#   'release_year': 2019,
#   'directors': ['Josh Cooley'],
#   'box_office': '$1.074 billion',
#   'country': 'United States'},
#  {'title': 'Star Wars: The Rise of Skywalker',
#   'link': '/wiki/Star_Wars:_The_Rise_of_Skywalker',
#   'release_year': 2019,
#   'directors': ['J. J. Abrams'],
#   'box_office': '$1.077 billion',
#   'country': 'United States'},
#  {'title': 'Transformers: Age of Extinction',
#   'link': '/wiki/Transformers:_Age_of_Extinction',
#   'release_year': 2014,
#   'directors': ['Michael Bay'],
#   'box_office': '$1.104 billion',
#   'country': 'United States'},
#  {'title': 'Skyfall',
#   'link': '/wiki/Skyfall',
#   'release_year': 2012,
#   'directors': ['Sam Mendes'],
#   'box_office': '$1.109 billion',
#   'countries': ['United Kingdom', 'United States']},
#  {'title': 'Transformers: Dark of the Moon',
#   'link': '/wiki/Transformers:_Dark_of_the_Moon',
#   'release_year': 2011,
#   'directors': ['Michael Bay'],
#   'box_office': '$1.124 billion',
#   'country': 'United States'},
#  {'title': 'Spider-Man: Far From Home',
#   'link': '/wiki/Spider-Man:_Far_From_Home',
#   'release_year': 2019,
#   'directors': ['Jon Watts'],
#   'box_office': '$1.133 billion',
#   'country': 'United States'},
#  {'title': 'The Dark Knight Rises',
#   'link': '/wiki/The_Dark_Knight_Rises',
#   'release_year': 2012,
#   'directors': ['Christopher Nolan'],
#   'box_office': '$1.115 billion',
#   'countries': ['United States', 'United Kingdom']},
#  {'title': 'Joker',
#   'link': '/wiki/Joker_(2019_film)',
#   'release_year': 2019,
#   'directors': ['Todd Phillips'],
#   'box_office': '$1.079 billion',
#   'country': 'United States'},
#  {'title': 'Captain Marvel',
#   'link': '/wiki/Captain_Marvel_(film)',
#   'release_year': 2019,
#   'directors': ['Anna Boden', 'Ryan Fleck'],
#   'box_office': '$1.131 billion',
#   'country': 'United States'},
#  {'title': 'Aquaman',
#   'link': '/wiki/Aquaman_(film)',
#   'release_year': 2018,
#   'directors': ['James Wan'],
#   'box_office': '$1.152 billion',
#   'country': 'United States'},
#  {'title': 'Top Gun: Maverick',
#   'link': '/wiki/Top_Gun:_Maverick',
#   'release_year': 2022,
#   'directors': ['Joseph Kosinski'],
#   'box_office': '$1.496 billion',
#   'country': 'United States'},
#  {'title': 'The Lord of the Rings: The Return of the King',
#   'link': '/wiki/The_Lord_of_the_Rings:_The_Return_of_the_King',
#   'release_year': 2003,
#   'directors': ['Peter Jackson'],
#   'box_office': '$1.151 billion',
#   'countries': ['New Zealand', 'Germany', 'United States']},
#  {'title': 'The Lion King',
#   'link': '/wiki/The_Lion_King_(2019_film)',
#   'release_year': 2019,
#   'directors': ['Jon Favreau'],
#   'box_office': '$1.657 billion',
#   'country': 'United States'},
#  {'title': 'Jurassic World',
#   'link': '/wiki/Jurassic_World',
#   'release_year': 2015,
#   'directors': ['Colin Trevorrow'],
#   'box_office': '$1.671 billion',
#   'country': 'United States'},
#  {'title': 'The Avengers',
#   'link': '/wiki/The_Avengers_(2012_film)',
#   'release_year': 2012,
#   'directors': ['Joss Whedon'],
#   'box_office': '$1.521 billion',
#   'country': 'United States'},
#  {'title': 'Ne Zha 2',
#   'link': '/wiki/Ne_Zha_2',
#   'release_year': 2025,
#   'directors': ['Jiaozi'],
#   'box_office': '$1.87 billion',
#   'country': 'China'},
#  {'title': 'Inside Out 2',
#   'link': '/wiki/Inside_Out_2',
#   'release_year': 2024,
#   'directors': ['Kelsey Mann'],
#   'box_office': '$1.699 billion',
#   'country': 'United States'},
#  {'title': 'Spider-Man: No Way Home',
#   'link': '/wiki/Spider-Man:_No_Way_Home',
#   'release_year': 2021,
#   'directors': ['Jon Watts'],
#   'box_office': '$1.953 billion',
#   'country': 'United States'},
#  {'title': 'Star Wars: The Force Awakens',
#   'link': '/wiki/Star_Wars:_The_Force_Awakens',
#   'release_year': 2015,
#   'directors': ['J. J. Abrams'],
#   'box_office': '$2.07',
#   'country': 'United States'},
#  {'title': 'Titanic',
#   'link': '/wiki/Titanic_(1997_film)',
#   'release_year': 1997,
#   'directors': ['James Cameron'],
#   'box_office': '$2.264 billion',
#   'country': 'United States'},
#  {'title': 'Avatar: The Way of Water',
#   'link': '/wiki/Avatar:_The_Way_of_Water',
#   'release_year': 2022,
#   'directors': ['James Cameron'],
#   'box_office': '$2.320 billion',
#   'country': 'United States'},
#  {'title': 'Moonraker',
#   'link': '/wiki/Moonraker_(film)',
#   'release_year': 1979,
#   'directors': ['Lewis Gilbert'],
#   'box_office': '$210.3 million',
#   'countries': ['United Kingdom', 'United States', 'France']},
#  {'title': 'Diamonds Are Forever',
#   'link': '/wiki/Diamonds_Are_Forever_(film)',
#   'release_year': 1971,
#   'directors': ['Guy Hamilton'],
#   'box_office': '$116 million',
#   'countries': ['United Kingdom', 'United States']},
#  {'title': 'The Bible: In the Beginning',
#   'link': '/wiki/The_Bible:_In_the_Beginning',
#   'release_year': 1966,
#   'directors': ['John Huston'],
#   'box_office': '$34.9 million',
#   'countries': ['Italy', 'United States']},
#  {'title': 'From Russia with Love',
#   'link': '/wiki/From_Russia_with_Love_(film)',
#   'release_year': 1963,
#   'directors': ['Terence Young'],
#   'box_office': '$79 million',
#   'countries': ['United Kingdom', 'United States']},
#  {'title': 'Goldfinger',
#   'link': '/wiki/Goldfinger_(film)',
#   'release_year': 1964,
#   'directors': ['Guy Hamilton'],
#   'box_office': '$125 million',
#   'countries': ['United Kingdom', 'United States']},
#  {'title': 'Lawrence of Arabia',
#   'link': '/wiki/Lawrence_of_Arabia_(film)',
#   'release_year': 1962,
#   'directors': ['David Lean'],
#   'box_office': '$70 million',
#   'countries': ['United Kingdom', 'United States']},
#  {'title': 'The Bridge on the River Kwai',
#   'link': '/wiki/The_Bridge_on_the_River_Kwai',
#   'release_year': 1957,
#   'directors': ['David Lean'],
#   'box_office': '$30.6 million',
#   'countries': ['United Kingdom', 'United States']},
#  {'title': 'Captain America: Civil War',
#   'link': '/wiki/Captain_America:_Civil_War',
#   'release_year': 2016,
#   'directors': ['Anthony Russo', 'Joe Russo'],
#   'box_office': '$1.155',
#   'country': 'United States'},
#  {'title': 'Furious 7',
#   'link': '/wiki/Furious_7',
#   'release_year': 2015,
#   'directors': ['James Wan'],
#   'box_office': '$1.515 billion',
#   'countries': ['United States', 'China']},
#  {'title': 'Avengers: Endgame',
#   'link': '/wiki/Avengers:_Endgame',
#   'release_year': 2019,
#   'directors': ['Anthony Russo', 'Joe Russo'],
#   'box_office': '$2.799',
#   'country': 'United States'},
#  {'title': 'Avengers: Infinity War',
#   'link': '/wiki/Avengers:_Infinity_War',
#   'release_year': 2018,
#   'directors': ['Anthony Russo', 'Joe Russo'],
#   'box_office': '$2.052 billion',
#   'country': 'United States'}]

# %%
len(all_entries)
# Out:
# 177

# %% [markdown]
# # Cleaning

# %%
box_oficces = []

count = 0
for entry in all_entries:
    box_oficces.append(entry['box_office'])
    count += 1

box_oficces
# Out:
# ['$2.923 billion',
#  '$1.334',
#  '$1.338 billion',
#  '$1.342 billion',
#  '$1.35 billion',
#  '$1.236 billion',
#  '$1.243 billion',
#  '$1.159 billion',
#  '$1.31 billion',
#  '$1.266 billion',
#  '$1.280 billion',
#  '$1.266',
#  '$1.360 billion',
#  '$897.5 million',
#  '$963.4 million',
#  '$1.405 billion',
#  '$1.446 billion',
#  '$1.006',
#  '$935.5 million',
#  '$553.7 million',
#  '$1.026 billion',
#  '$951.6 million',
#  '$366.1 million',
#  '$546.3 million',
#  '$817.4 million',
#  '$354.8',
#  '$505.7 million',
#  '$474.2 million',
#  '$394.4 million',
#  '$1.453',
#  '$320.1 million',
#  '$519–520.9',
#  '$357.3 million',
#  '$388.8 million',
#  '$200.1 million',
#  '$370 million',
#  '$482 million',
#  '$396.3 million',
#  '$538–549',
#  '$389.9',
#  '$203.3 million',
#  '$257 million',
#  '$476.5 million',
#  '$225 million',
#  '$83.3 million',
#  '$75 million (worldwide',
#  '$441.3 million',
#  '$250–291 million',
#  '$173.4 million',
#  '$58.5 million',
#  '$102.3 million',
#  '$104.9 million (North America)',
#  '$378 million',
#  '$33.7 million',
#  '$34.5 million',
#  '$146 million',
#  '$103.1 million (US/Canada)',
#  '$50 million',
#  '$50.1 million',
#  '$72.7 million',
#  '$507.1 million',
#  '$303 million',
#  '$50 million',
#  '$44.1 million',
#  '$17.5 million',
#  '$40 million',
#  '$21.2 million',
#  '$60 million (initial release)',
#  '$36 million (United States)',
#  '$29.6 million',
#  '$28.2 million',
#  '$30 million',
#  '$37 million',
#  '$36 million',
#  '$87.4 million (United States and Canada)',
#  '$187 million',
#  '$41.6 million',
#  '$21 million',
#  '$15.1 million',
#  '$25.6 million',
#  '$10 million (Worldwide)',
#  '$182 million',
#  '$6,665,592',
#  '$5 million (est. US/ Canada rentals)',
#  '$6.8 million',
#  '$5 million (U.S. and Canada rentals)',
#  '$20.4 million',
#  '$23.7 million',
#  '$65 million',
#  '$40–100 million (estimated)',
#  '$6.5 million (US/Canada rentals)',
#  '$10,445,000',
#  '$17.8 million (worldwide)',
#  '$8.9 million',
#  '$21.3 million (United States)',
#  '$267.4 million',
#  'US$2,137,575',
#  '$5 million',
#  '$5.3 million',
#  '$4,460,000',
#  '$8.3 million',
#  '$164 million',
#  '$418 million',
#  '$2.8 million (worldwide rentals)',
#  '$2.2 million',
#  '$1,004,000 (domestic rentals)',
#  '$2.5 million (worldwide rentals)',
#  '$2,250,000 (rentals)',
#  '$12 million',
#  '$2,738,993',
#  '$3 million',
#  '$4.4 million',
#  '$4.25 million (worldwide rentals)',
#  '$2.19 million (U.S. and Canada rentals)',
#  '$5,916,000',
#  '$5.3 million',
#  '$2.6 million',
#  '$18–22 million',
#  '$2 million',
#  '$2,500,000 (US/Canada)',
#  '$4 million (U.S. and Canada rentals)',
#  '$9.2 million',
#  '$3.8 million (US and Canada rentals)',
#  '$16,450,000',
#  '$7,500,000',
#  '$1.75 million',
#  '$1 million (rentals)',
#  '$1 million',
#  '$50–100 million',
#  '$111.7 million (US/Canada)',
#  '$122.7 million',
#  '$797.3 million',
#  '$286.2 million',
#  '$1.035',
#  '>$390 million',
#  '$775.4 million',
#  '$1.046 billion',
#  '$1.058 billion',
#  '$1.05 billion',
#  '$1.047 billion',
#  '$1.054 billion',
#  '$10.7 million',
#  '$1.066 billion',
#  '$1.059 billion',
#  '$1.067 billion',
#  '$1.074 billion',
#  '$1.077 billion',
#  '$1.104 billion',
#  '$1.109 billion',
#  '$1.124 billion',
#  '$1.133 billion',
#  '$1.115 billion',
#  '$1.079 billion',
#  '$1.131 billion',
#  '$1.152 billion',
#  '$1.496 billion',
#  '$1.151 billion',
#  '$1.657 billion',
#  '$1.671 billion',
#  '$1.521 billion',
#  '$1.87 billion',
#  '$1.699 billion',
#  '$1.953 billion',
#  '$2.07',
#  '$2.264 billion',
#  '$2.320 billion',
#  '$210.3 million',
#  '$116 million',
#  '$34.9 million',
#  '$79 million',
#  '$125 million',
#  '$70 million',
#  '$30.6 million',
#  '$1.155',
#  '$1.515 billion',
#  '$2.799',
#  '$2.052 billion']

# %%
import re

def clean_box_office(box_office_str):
    box_office_str = box_office_str.replace('$', '').replace('US', '').replace('>', '').replace('<', '').strip()
    box_office_str = box_office_str.replace('$', '').replace('US', '').strip()
    box_office_str = re.sub(r'\(.*', '', box_office_str).strip()
    
    if '–' in box_office_str:
        box_office_str = box_office_str.split('–')[1].strip()
    
    if 'billion' not in box_office_str and 'million' not in box_office_str:
        if re.match(r'^\d{1,3}(,\d{3})+$', box_office_str):
            # Handle values with commas, e.g., '6,665,592'
            box_office_str = box_office_str.replace(',', '')
            if int(box_office_str) >= 1_000_000_000:
                box_office_str = str(int(box_office_str) / 1_000_000_000) + ' billion'
            else:
                box_office_str = str(int(box_office_str) / 1_000_000) + ' million'
        else:
            if '.' in box_office_str:
                whole_part = box_office_str.split('.')[0]
            else:
                whole_part = box_office_str
            if whole_part.isdigit() and int(whole_part) < 10:
                box_office_str += ' billion'
            else:
                box_office_str += ' million'
    
    box_office_str += ' $'
    
    return box_office_str

def convert_to_numeric(box_office_str):
    value = box_office_str.replace(' $', '')
    if 'billion' in value:
        return float(value.replace(' billion', '')) * 1_000_000_000
    elif 'million' in value:
        return float(value.replace(' million', '')) * 1_000_000
    return 0

# %%
def clean_entries(entries):
    cleaned_entries = []
    for index, entry in enumerate(entries, start=1):
        entry['link'] = 'https://en.wikipedia.org' + entry['link']
        
        if 'country' in entry:
            if 'countries' not in entry:
                entry['countries'] = [entry['country']]
            del entry['country']
        
        
        box_office_str = entry['box_office']
        box_office_str = clean_box_office(box_office_str)
        num_val = convert_to_numeric(box_office_str)
        entry['box_office'] = box_office_str
        entry['num_val_box_office'] = num_val
        
        entry['id'] = index
        
        cleaned_entries.append(entry)
    return cleaned_entries

# %%
cleaned_entries = all_entries
cleaned_entries = clean_entries(cleaned_entries)

# %%
for entry in cleaned_entries:
    print(entry['box_office'])
# Out:
# 2.923 billion $
# 1.334 billion $
# 1.338 billion $
# 1.342 billion $
# 1.35 billion $
# 1.236 billion $
# 1.243 billion $
# 1.159 billion $
# 1.31 billion $
# 1.266 billion $
# 1.280 billion $
# 1.266 billion $
# 1.360 billion $
# 897.5 million $
# 963.4 million $
# 1.405 billion $
# 1.446 billion $
# 1.006 billion $
# 935.5 million $
# 553.7 million $
# 1.026 billion $
# 951.6 million $
# 366.1 million $
# 546.3 million $
# 817.4 million $
# 354.8 million $
# 505.7 million $
# 474.2 million $
# 394.4 million $
# 1.453 billion $
# 320.1 million $
# 520.9 million $
# 357.3 million $
# 388.8 million $
# 200.1 million $
# 370 million $
# 482 million $
# 396.3 million $
# 549 million $
# 389.9 million $
# 203.3 million $
# 257 million $
# 476.5 million $
# 225 million $
# 83.3 million $
# 75 million $
# 441.3 million $
# 291 million $
# 173.4 million $
# 58.5 million $
# 102.3 million $
# 104.9 million $
# 378 million $
# 33.7 million $
# 34.5 million $
# 146 million $
# 103.1 million $
# 50 million $
# 50.1 million $
# 72.7 million $
# 507.1 million $
# 303 million $
# 50 million $
# 44.1 million $
# 17.5 million $
# 40 million $
# 21.2 million $
# 60 million $
# 36 million $
# 29.6 million $
# 28.2 million $
# 30 million $
# 37 million $
# 36 million $
# 87.4 million $
# 187 million $
# 41.6 million $
# 21 million $
# 15.1 million $
# 25.6 million $
# 10 million $
# 182 million $
# 6.665592 million $
# 5 million $
# 6.8 million $
# 5 million $
# 20.4 million $
# 23.7 million $
# 65 million $
# 100 million $
# 6.5 million $
# 10.445 million $
# 17.8 million $
# 8.9 million $
# 21.3 million $
# 267.4 million $
# 2.137575 million $
# 5 million $
# 5.3 million $
# 4.46 million $
# 8.3 million $
# 164 million $
# 418 million $
# 2.8 million $
# 2.2 million $
# 1.004 million $
# 2.5 million $
# 2.25 million $
# 12 million $
# 2.738993 million $
# 3 million $
# 4.4 million $
# 4.25 million $
# 2.19 million $
# 5.916 million $
# 5.3 million $
# 2.6 million $
# 22 million $
# 2 million $
# 2.5 million $
# 4 million $
# 9.2 million $
# 3.8 million $
# 16.45 million $
# 7.5 million $
# 1.75 million $
# 1 million $
# 1 million $
# 100 million $
# 111.7 million $
# 122.7 million $
# 797.3 million $
# 286.2 million $
# 1.035 billion $
# 390 million $
# 775.4 million $
# 1.046 billion $
# 1.058 billion $
# 1.05 billion $
# 1.047 billion $
# 1.054 billion $
# 10.7 million $
# 1.066 billion $
# 1.059 billion $
# 1.067 billion $
# 1.074 billion $
# 1.077 billion $
# 1.104 billion $
# 1.109 billion $
# 1.124 billion $
# 1.133 billion $
# 1.115 billion $
# 1.079 billion $
# 1.131 billion $
# 1.152 billion $
# 1.496 billion $
# 1.151 billion $
# 1.657 billion $
# 1.671 billion $
# 1.521 billion $
# 1.87 billion $
# 1.699 billion $
# 1.953 billion $
# 2.07 billion $
# 2.264 billion $
# 2.320 billion $
# 210.3 million $
# 116 million $
# 34.9 million $
# 79 million $
# 125 million $
# 70 million $
# 30.6 million $
# 1.155 billion $
# 1.515 billion $
# 2.799 billion $
# 2.052 billion $

# %%
cleaned_entries
# Out:
# [{'title': 'Avatar',
#   'link': 'https://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.org/wiki/Avatar_(2009_film)',
#   'release_year': 2009,
#   'directors': ['James Cameron'],
#   'box_office': '2.923 billion $',
#   'countries': ['United Kingdom', 'United States'],
#   'num_val_box_office': 2923000000.0,
#   '_id': ObjectId('67bc98e135a9409ecd46d034'),
#   'id': 1},
#  {'title': 'Star Wars: The Last Jedi',
#   'link': 'https://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.org/wiki/Star_Wars:_The_Last_Jedi',
#   'release_year': 2017,
#   'directors': ['Rian Johnson'],
#   'box_office': '1.334 billion $',
#   'countries': ['United States'],
#   'num_val_box_office': 1334000000.0,
#   '_id': ObjectId('67bc98e135a9409ecd46d035'),
#   'id': 2},
#  {'title': 'Deadpool & Wolverine',
#   'link': 'https://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.org/wiki/Deadpool_%26_Wolverine',
#   'release_year': 2024,
#   'directors': ['Shawn Levy'],
#   'box_office': '1.338 billion $',
#   'countries': ['United States'],
#   'num_val_box_office': 1338000000.0,
#   '_id': ObjectId('67bc98e135a9409ecd46d036'),
#   'id': 3},
#  {'title': 'Harry Potter and the Deathly Hallows – Part 2',
#   'link': 'https://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.org/wiki/Harry_Potter_and_the_Deathly_Hallows_%E2%80%93_Part_2',
#   'release_year': 2011,
#   'directors': ['David Yates'],
#   'box_office': '1.342 billion $',
#   'countries': ['United Kingdom', 'United States'],
#   'num_val_box_office': 1342000000.0,
#   '_id': ObjectId('67bc98e135a9409ecd46d037'),
#   'id': 4},
#  {'title': 'Black Panther',
#   'link': 'https://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.org/wiki/Black_Panther_(film)',
#   'release_year': 2018,
#   'directors': ['Ryan Coogler'],
#   'box_office': '1.35 billion $',
#   'countries': ['United States'],
#   'num_val_box_office': 1350000000.0,
#   '_id': ObjectId('67bc98e135a9409ecd46d038'),
#   'id': 5},
#  {'title': 'The Fate of the Furious',
#   'link': 'https://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.org/wiki/The_Fate_of_the_Furious',
#   'release_year': 2017,
#   'directors': ['F. Gary Gray'],
#   'box_office': '1.236 billion $',
#   'countries': ['United States', 'China'],
#   'num_val_box_office': 1236000000.0,
#   '_id': ObjectId('67bc98e135a9409ecd46d039'),
#   'id': 6},
#  {'title': 'Incredibles 2',
#   'link': 'https://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.org/wiki/Incredibles_2',
#   'release_year': 2018,
#   'directors': ['Brad Bird'],
#   'box_office': '1.243 billion $',
#   'countries': ['United States'],
#   'num_val_box_office': 1243000000.0,
#   '_id': ObjectId('67bc98e135a9409ecd46d03a'),
#   'id': 7},
#  {'title': 'Minions',
#   'link': 'https://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.org/wiki/Minions_(film)',
#   'release_year': 2015,
#   'directors': ['Pierre Coffin', 'Kyle Balda'],
#   'box_office': '1.159 billion $',
#   'countries': ['United States'],
#   'num_val_box_office': 1159000000.0,
#   '_id': ObjectId('67bc98e135a9409ecd46d03b'),
#   'id': 8},
#  {'title': 'Jurassic World: Fallen Kingdom',
#   'link': 'https://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.org/wiki/Jurassic_World:_Fallen_Kingdom',
#   'release_year': 2018,
#   'directors': ['J. A. Bayona'],
#   'box_office': '1.31 billion $',
#   'countries': ['China', 'United States'],
#   'num_val_box_office': 1310000000.0,
#   '_id': ObjectId('67bc98e135a9409ecd46d03c'),
#   'id': 9},
#  {'title': 'Iron Man 3',
#   'link': 'https://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.org/wiki/Iron_Man_3',
#   'release_year': 2013,
#   'directors': ['Shane Black'],
#   'box_office': '1.266 billion $',
#   'countries': ['United States'],
#   'num_val_box_office': 1266000000.0,
#   '_id': ObjectId('67bc98e135a9409ecd46d03d'),
#   'id': 10},
#  {'title': 'Frozen',
#   'link': 'https://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.org/wiki/Frozen_(2013_film)',
#   'release_year': 2013,
#   'directors': ['Chris Buck', 'Jennifer Lee'],
#   'box_office': '1.280 billion $',
#   'countries': ['United States'],
#   'num_val_box_office': 1280000000.0,
#   '_id': ObjectId('67bc98e135a9409ecd46d03e'),
#   'id': 11},
#  {'title': 'Beauty and the Beast',
#   'link': 'https://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.org/wiki/Beauty_and_the_Beast_(2017_film)',
#   'release_year': 2017,
#   'directors': ['Bill Condon'],
#   'box_office': '1.266 billion $',
#   'countries': ['United States'],
#   'num_val_box_office': 1266000000.0,
#   '_id': ObjectId('67bc98e135a9409ecd46d03f'),
#   'id': 12},
#  {'title': 'The Super Mario Bros. Movie',
#   'link': 'https://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.org/wiki/The_Super_Mario_Bros._Movie',
#   'release_year': 2023,
#   'directors': ['Aaron Horvath', 'Michael Jelenic'],
#   'box_office': '1.360 billion $',
#   'countries': ['United States'],
#   'num_val_box_office': 1360000000.0,
#   '_id': ObjectId('67bc98e135a9409ecd46d040'),
#   'id': 13},
#  {'title': 'Harry Potter and the Goblet of Fire',
#   'link': 'https://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.org/wiki/Harry_Potter_and_the_Goblet_of_Fire_(film)',
#   'release_year': 2005,
#   'directors': ['Mike Newell'],
#   'box_office': '897.5 million $',
#   'countries': ['United Kingdom', 'United States'],
#   'num_val_box_office': 897500000.0,
#   '_id': ObjectId('67bc98e135a9409ecd46d041'),
#   'id': 14},
#  {'title': "Pirates of the Caribbean: At World's End",
#   'link': 'https://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.org/wiki/Pirates_of_the_Caribbean:_At_World%27s_End',
#   'release_year': 2007,
#   'directors': ['Gore Verbinski'],
#   'box_office': '963.4 million $',
#   'countries': ['United States'],
#   'num_val_box_office': 963400000.0,
#   '_id': ObjectId('67bc98e135a9409ecd46d042'),
#   'id': 15},
#  {'title': 'Avengers: Age of Ultron',
#   'link': 'https://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.org/wiki/Avengers:_Age_of_Ultron',
#   'release_year': 2015,
#   'directors': ['Joss Whedon'],
#   'box_office': '1.405 billion $',
#   'countries': ['United States'],
#   'num_val_box_office': 1405000000.0,
#   '_id': ObjectId('67bc98e135a9409ecd46d043'),
#   'id': 16},
#  {'title': 'Barbie',
#   'link': 'https://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.org/wiki/Barbie_(film)',
#   'release_year': 2023,
#   'directors': ['Greta Gerwig'],
#   'box_office': '1.446 billion $',
#   'countries': ['United States', 'United Kingdom'],
#   'num_val_box_office': 1446000000.0,
#   '_id': ObjectId('67bc98e135a9409ecd46d044'),
#   'id': 17},
#  {'title': 'The Dark Knight',
#   'link': 'https://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.org/wiki/The_Dark_Knight',
#   'release_year': 2008,
#   'directors': ['Christopher Nolan'],
#   'box_office': '1.006 billion $',
#   'countries': ['United States', 'United Kingdom'],
#   'num_val_box_office': 1006000000.0,
#   '_id': ObjectId('67bc98e135a9409ecd46d045'),
#   'id': 18},
#  {'title': 'Shrek 2',
#   'link': 'https://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.org/wiki/Shrek_2',
#   'release_year': 2004,
#   'directors': ['Andrew Adamson', 'Kelly Asbury', 'Conrad Vernon'],
#   'box_office': '935.5 million $',
#   'countries': ['United States'],
#   'num_val_box_office': 935500000.0,
#   '_id': ObjectId('67bc98e135a9409ecd46d046'),
#   'id': 19},
#  {'title': 'Armageddon',
#   'link': 'https://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.org/wiki/Armageddon_(1998_film)',
#   'release_year': 1998,
#   'directors': ['Michael Bay'],
#   'box_office': '553.7 million $',
#   'countries': ['United States'],
#   'num_val_box_office': 553700000.0,
#   '_id': ObjectId('67bc98e135a9409ecd46d047'),
#   'id': 20},
#  {'title': "Harry Potter and the Philosopher's Stone",
#   'link': 'https://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.org/wiki/Harry_Potter_and_the_Philosopher%27s_Stone_(film)',
#   'release_year': 2001,
#   'directors': ['Chris Columbus'],
#   'box_office': '1.026 billion $',
#   'countries': ['United Kingdom', 'United States'],
#   'num_val_box_office': 1026000000.0,
#   '_id': ObjectId('67bc98e135a9409ecd46d048'),
#   'id': 21},
#  {'title': 'The Lord of the Rings: The Two Towers',
#   'link': 'https://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.org/wiki/The_Lord_of_the_Rings:_The_Two_Towers',
#   'release_year': 2002,
#   'directors': ['Peter Jackson'],
#   'box_office': '951.6 million $',
#   'countries': ['New Zealand', 'United States'],
#   'num_val_box_office': 951600000.0,
#   '_id': ObjectId('67bc98e135a9409ecd46d049'),
#   'id': 22},
#  {'title': 'Die Hard with a Vengeance',
#   'link': 'https://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.org/wiki/Die_Hard_with_a_Vengeance',
#   'release_year': 1995,
#   'directors': ['John McTiernan'],
#   'box_office': '366.1 million $',
#   'countries': ['United States'],
#   'num_val_box_office': 366100000.0,
#   '_id': ObjectId('67bc98e135a9409ecd46d04a'),
#   'id': 23},
#  {'title': 'Mission: Impossible 2',
#   'link': 'https://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.org/wiki/Mission:_Impossible_2',
#   'release_year': 2000,
#   'directors': ['John Woo'],
#   'box_office': '546.3 million $',
#   'countries': ['United States', 'Germany'],
#   'num_val_box_office': 546300000.0,
#   '_id': ObjectId('67bc98e135a9409ecd46d04b'),
#   'id': 24},
#  {'title': 'Independence Day',
#   'link': 'https://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.org/wiki/Independence_Day_(1996_film)',
#   'release_year': 1996,
#   'directors': ['Roland Emmerich'],
#   'box_office': '817.4 million $',
#   'countries': ['United States'],
#   'num_val_box_office': 817400000.0,
#   '_id': ObjectId('67bc98e135a9409ecd46d04c'),
#   'id': 25},
#  {'title': 'Rain Man',
#   'link': 'https://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.org/wiki/Rain_Man',
#   'release_year': 1988,
#   'directors': ['Barry Levinson'],
#   'box_office': '354.8 million $',
#   'countries': ['United States'],
#   'num_val_box_office': 354800000.0,
#   '_id': ObjectId('67bc98e135a9409ecd46d04d'),
#   'id': 26},
#  {'title': 'Ghost',
#   'link': 'https://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.org/wiki/Ghost_(1990_film)',
#   'release_year': 1990,
#   'directors': ['Jerry Zucker'],
#   'box_office': '505.7 million $',
#   'countries': ['United States'],
#   'num_val_box_office': 505700000.0,
#   '_id': ObjectId('67bc98e135a9409ecd46d04e'),
#   'id': 27},
#  {'title': 'Indiana Jones and the Last Crusade',
#   'link': 'https://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.org/wiki/Indiana_Jones_and_the_Last_Crusade',
#   'release_year': 1989,
#   'directors': ['Steven Spielberg'],
#   'box_office': '474.2 million $',
#   'countries': ['United States'],
#   'num_val_box_office': 474200000.0,
#   '_id': ObjectId('67bc98e135a9409ecd46d04f'),
#   'id': 28},
#  {'title': 'Toy Story',
#   'link': 'https://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.org/wiki/Toy_Story',
#   'release_year': 1995,
#   'directors': ['John Lasseter'],
#   'box_office': '394.4 million $',
#   'countries': ['United States'],
#   'num_val_box_office': 394400000.0,
#   '_id': ObjectId('67bc98e135a9409ecd46d050'),
#   'id': 29},
#  {'title': 'Frozen 2',
#   'link': 'https://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.org/wiki/Frozen_2',
#   'release_year': 2019,
#   'directors': ['Chris Buck', 'Jennifer Lee'],
#   'box_office': '1.453 billion $',
#   'countries': ['United States'],
#   'num_val_box_office': 1453000000.0,
#   '_id': ObjectId('67bc98e135a9409ecd46d051'),
#   'id': 30},
#  {'title': 'Fatal Attraction',
#   'link': 'https://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.org/wiki/Fatal_Attraction',
#   'release_year': 1987,
#   'directors': ['Adrian Lyne'],
#   'box_office': '320.1 million $',
#   'countries': ['United States'],
#   'num_val_box_office': 320100000.0,
#   '_id': ObjectId('67bc98e135a9409ecd46d052'),
#   'id': 31},
#  {'title': 'Terminator 2: Judgment Day',
#   'link': 'https://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.org/wiki/Terminator_2:_Judgment_Day',
#   'release_year': 1991,
#   'directors': ['James Cameron'],
#   'box_office': '520.9 million $',
#   'countries': ['United States'],
#   'num_val_box_office': 520900000.0,
#   '_id': ObjectId('67bc98e135a9409ecd46d053'),
#   'id': 32},
#  {'title': 'Top Gun',
#   'link': 'https://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.org/wiki/Top_Gun',
#   'release_year': 1986,
#   'directors': ['Tony Scott'],
#   'box_office': '357.3 million $',
#   'countries': ['United States'],
#   'num_val_box_office': 357300000.0,
#   '_id': ObjectId('67bc98e135a9409ecd46d054'),
#   'id': 33},
#  {'title': 'Back to the Future',
#   'link': 'https://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.org/wiki/Back_to_the_Future',
#   'release_year': 1985,
#   'directors': ['Robert Zemeckis'],
#   'box_office': '388.8 million $',
#   'countries': ['United States'],
#   'num_val_box_office': 388800000.0,
#   '_id': ObjectId('67bc98e135a9409ecd46d055'),
#   'id': 34},
#  {'title': 'Rocky II',
#   'link': 'https://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.org/wiki/Rocky_II',
#   'release_year': 1979,
#   'directors': ['Sylvester Stallone'],
#   'box_office': '200.1 million $',
#   'countries': ['United States'],
#   'num_val_box_office': 200100000.0,
#   '_id': ObjectId('67bc98e135a9409ecd46d056'),
#   'id': 35},
#  {'title': 'Ghostbusters',
#   'link': 'https://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.org/wiki/Ghostbusters',
#   'release_year': 1984,
#   'directors': ['Ivan Reitman'],
#   'box_office': '370 million $',
#   'countries': ['United States'],
#   'num_val_box_office': 370000000.0,
#   '_id': ObjectId('67bc98e135a9409ecd46d057'),
#   'id': 36},
#  {'title': 'Return of the Jedi',
#   'link': 'https://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.org/wiki/Return_of_the_Jedi',
#   'release_year': 1983,
#   'directors': ['Richard Marquand'],
#   'box_office': '482 million $',
#   'countries': ['United States'],
#   'num_val_box_office': 482000000.0,
#   '_id': ObjectId('67bc98e135a9409ecd46d058'),
#   'id': 37},
#  {'title': 'Grease',
#   'link': 'https://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.org/wiki/Grease_(film)',
#   'release_year': 1978,
#   'directors': ['Randal Kleiser'],
#   'box_office': '396.3 million $',
#   'countries': ['United States'],
#   'num_val_box_office': 396300000.0,
#   '_id': ObjectId('67bc98e135a9409ecd46d059'),
#   'id': 38},
#  {'title': 'The Empire Strikes Back',
#   'link': 'https://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.org/wiki/The_Empire_Strikes_Back',
#   'release_year': 1980,
#   'directors': ['Irvin Kershner'],
#   'box_office': '549 million $',
#   'countries': ['United States'],
#   'num_val_box_office': 549000000.0,
#   '_id': ObjectId('67bc98e135a9409ecd46d05a'),
#   'id': 39},
#  {'title': 'Raiders of the Lost Ark',
#   'link': 'https://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.org/wiki/Raiders_of_the_Lost_Ark',
#   'release_year': 1981,
#   'directors': ['Steven Spielberg'],
#   'box_office': '389.9 million $',
#   'countries': ['United States'],
#   'num_val_box_office': 389900000.0,
#   '_id': ObjectId('67bc98e135a9409ecd46d05b'),
#   'id': 40},
#  {'title': 'The Towering Inferno',
#   'link': 'https://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.org/wiki/The_Towering_Inferno',
#   'release_year': 1974,
#   'directors': ['John Guillermin', 'Irwin Allen'],
#   'box_office': '203.3 million $',
#   'countries': ['United States'],
#   'num_val_box_office': 203300000.0,
#   '_id': ObjectId('67bc98e135a9409ecd46d05c'),
#   'id': 41},
#  {'title': 'The Sting',
#   'link': 'https://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.org/wiki/The_Sting',
#   'release_year': 1973,
#   'directors': ['George Roy Hill'],
#   'box_office': '257 million $',
#   'countries': ['United States'],
#   'num_val_box_office': 257000000.0,
#   '_id': ObjectId('67bc98e135a9409ecd46d05d'),
#   'id': 42},
#  {'title': 'Jaws',
#   'link': 'https://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.org/wiki/Jaws_(film)',
#   'release_year': 1975,
#   'directors': ['Steven Spielberg'],
#   'box_office': '476.5 million $',
#   'countries': ['United States'],
#   'num_val_box_office': 476500000.0,
#   '_id': ObjectId('67bc98e135a9409ecd46d05e'),
#   'id': 43},
#  {'title': 'Rocky',
#   'link': 'https://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.org/wiki/Rocky',
#   'release_year': 1976,
#   'directors': ['John G. Avildsen'],
#   'box_office': '225 million $',
#   'countries': ['United States'],
#   'num_val_box_office': 225000000.0,
#   '_id': ObjectId('67bc98e135a9409ecd46d05f'),
#   'id': 44},
#  {'title': 'Fiddler on the Roof',
#   'link': 'https://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.org/wiki/Fiddler_on_the_Roof_(film)',
#   'release_year': 1971,
#   'directors': ['Norman Jewison'],
#   'box_office': '83.3 million $',
#   'countries': ['United States'],
#   'num_val_box_office': 83300000.0,
#   '_id': ObjectId('67bc98e135a9409ecd46d060'),
#   'id': 45},
#  {'title': 'The French Connection',
#   'link': 'https://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.org/wiki/The_French_Connection_(film)',
#   'release_year': 1971,
#   'directors': ['William Friedkin'],
#   'box_office': '75 million $',
#   'countries': ['United States'],
#   'num_val_box_office': 75000000.0,
#   '_id': ObjectId('67bc98e135a9409ecd46d061'),
#   'id': 46},
#  {'title': 'The Exorcist',
#   'link': 'https://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.org/wiki/The_Exorcist',
#   'release_year': 1973,
#   'directors': ['William Friedkin'],
#   'box_office': '441.3 million $',
#   'countries': ['United States'],
#   'num_val_box_office': 441300000.0,
#   '_id': ObjectId('67bc98e135a9409ecd46d062'),
#   'id': 47},
#  {'title': 'The Godfather',
#   'link': 'https://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.org/wiki/The_Godfather',
#   'release_year': 1972,
#   'directors': ['Francis Ford Coppola'],
#   'box_office': '291 million $',
#   'countries': ['United States'],
#   'num_val_box_office': 291000000.0,
#   '_id': ObjectId('67bc98e135a9409ecd46d063'),
#   'id': 48},
#  {'title': 'Love Story',
#   'link': 'https://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.org/wiki/Love_Story_(1970_film)',
#   'release_year': 1970,
#   'directors': ['Arthur Hiller'],
#   'box_office': '173.4 million $',
#   'countries': ['United States'],
#   'num_val_box_office': 173400000.0,
#   '_id': ObjectId('67bc98e135a9409ecd46d064'),
#   'id': 49},
#  {'title': 'Funny Girl',
#   'link': 'https://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.org/wiki/Funny_Girl_(film)',
#   'release_year': 1968,
#   'directors': ['William Wyler'],
#   'box_office': '58.5 million $',
#   'countries': ['United States'],
#   'num_val_box_office': 58500000.0,
#   '_id': ObjectId('67bc98e135a9409ecd46d065'),
#   'id': 50},
#  {'title': 'Butch Cassidy and the Sundance Kid',
#   'link': 'https://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.org/wiki/Butch_Cassidy_and_the_Sundance_Kid',
#   'release_year': 1969,
#   'directors': ['George Roy Hill'],
#   'box_office': '102.3 million $',
#   'countries': ['United States'],
#   'num_val_box_office': 102300000.0,
#   '_id': ObjectId('67bc98e135a9409ecd46d066'),
#   'id': 51},
#  {'title': 'The Graduate',
#   'link': 'https://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.org/wiki/The_Graduate',
#   'release_year': 1967,
#   'directors': ['Mike Nichols'],
#   'box_office': '104.9 million $',
#   'countries': ['United States'],
#   'num_val_box_office': 104900000.0,
#   '_id': ObjectId('67bc98e135a9409ecd46d067'),
#   'id': 52},
#  {'title': 'The Jungle Book',
#   'link': 'https://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.org/wiki/The_Jungle_Book_(1967_film)',
#   'release_year': 1967,
#   'directors': ['Wolfgang Reitherman'],
#   'box_office': '378 million $',
#   'countries': ['United States'],
#   'num_val_box_office': 378000000.0,
#   '_id': ObjectId('67bc98e135a9409ecd46d068'),
#   'id': 53},
#  {'title': "Who's Afraid of Virginia Woolf?",
#   'link': 'https://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.org/wiki/Who%27s_Afraid_of_Virginia_Woolf%3F_(film)',
#   'release_year': 1966,
#   'directors': ['Mike Nichols'],
#   'box_office': '33.7 million $',
#   'countries': ['United States'],
#   'num_val_box_office': 33700000.0,
#   '_id': ObjectId('67bc98e135a9409ecd46d069'),
#   'id': 54},
#  {'title': 'Hawaii',
#   'link': 'https://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.org/wiki/Hawaii_(1966_film)',
#   'release_year': 1966,
#   'directors': ['George Roy Hill'],
#   'box_office': '34.5 million $',
#   'countries': ['United States'],
#   'num_val_box_office': 34500000.0,
#   '_id': ObjectId('67bc98e135a9409ecd46d06a'),
#   'id': 55},
#  {'title': '2001: A Space Odyssey',
#   'link': 'https://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.org/wiki/2001:_A_Space_Odyssey',
#   'release_year': 1968,
#   'directors': ['Stanley Kubrick'],
#   'box_office': '146 million $',
#   'countries': ['United Kingdom', 'United States'],
#   'num_val_box_office': 146000000.0,
#   '_id': ObjectId('67bc98e135a9409ecd46d06b'),
#   'id': 56},
#  {'title': 'Mary Poppins',
#   'link': 'https://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.org/wiki/Mary_Poppins_(film)',
#   'release_year': 1964,
#   'directors': ['Robert Stevenson'],
#   'box_office': '103.1 million $',
#   'countries': ['United States'],
#   'num_val_box_office': 103100000.0,
#   '_id': ObjectId('67bc98e135a9409ecd46d06c'),
#   'id': 57},
#  {'title': 'How the West Was Won',
#   'link': 'https://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.org/wiki/How_the_West_Was_Won_(film)',
#   'release_year': 1962,
#   'directors': ['Henry Hathaway', 'John Ford', 'George Marshall'],
#   'box_office': '50 million $',
#   'countries': ['United States'],
#   'num_val_box_office': 50000000.0,
#   '_id': ObjectId('67bc98e135a9409ecd46d06d'),
#   'id': 58},
#  {'title': 'The Longest Day',
#   'link': 'https://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.org/wiki/The_Longest_Day_(film)',
#   'release_year': 1962,
#   'directors': ['Ken Annakin', 'Andrew Marton', 'Bernhard Wicki'],
#   'box_office': '50.1 million $',
#   'countries': ['United States'],
#   'num_val_box_office': 50100000.0,
#   '_id': ObjectId('67bc98e135a9409ecd46d06e'),
#   'id': 59},
#  {'title': 'My Fair Lady',
#   'link': 'https://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.org/wiki/My_Fair_Lady_(film)',
#   'release_year': 1964,
#   'directors': ['George Cukor'],
#   'box_office': '72.7 million $',
#   'countries': ['United States'],
#   'num_val_box_office': 72700000.0,
#   '_id': ObjectId('67bc98e135a9409ecd46d06f'),
#   'id': 60},
#  {'title': 'Demon Slayer: Mugen Train',
#   'link': 'https://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.org/wiki/Demon_Slayer:_Mugen_Train',
#   'release_year': 2020,
#   'directors': ['Haruo Sotozaki'],
#   'box_office': '507.1 million $',
#   'countries': ['Japan'],
#   'num_val_box_office': 507100000.0,
#   '_id': ObjectId('67bc98e135a9409ecd46d070'),
#   'id': 61},
#  {'title': 'One Hundred and One Dalmatians',
#   'link': 'https://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.org/wiki/One_Hundred_and_One_Dalmatians',
#   'release_year': 1961,
#   'directors': ['Wolfgang Reitherman', 'Hamilton Luske', 'Clyde Geronimi'],
#   'box_office': '303 million $',
#   'countries': ['United States'],
#   'num_val_box_office': 303000000.0,
#   '_id': ObjectId('67bc98e135a9409ecd46d071'),
#   'id': 62},
#  {'title': 'Psycho',
#   'link': 'https://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.org/wiki/Psycho_(1960_film)',
#   'release_year': 1960,
#   'directors': ['Alfred Hitchcock'],
#   'box_office': '50 million $',
#   'countries': ['United States'],
#   'num_val_box_office': 50000000.0,
#   '_id': ObjectId('67bc98e135a9409ecd46d072'),
#   'id': 63},
#  {'title': 'West Side Story',
#   'link': 'https://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.org/wiki/West_Side_Story_(1961_film)',
#   'release_year': 1961,
#   'directors': ['Robert Wise', 'Jerome Robbins'],
#   'box_office': '44.1 million $',
#   'countries': ['United States'],
#   'num_val_box_office': 44100000.0,
#   '_id': ObjectId('67bc98e135a9409ecd46d073'),
#   'id': 64},
#  {'title': 'South Pacific',
#   'link': 'https://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.org/wiki/South_Pacific_(1958_film)',
#   'release_year': 1958,
#   'directors': ['Joshua Logan'],
#   'box_office': '17.5 million $',
#   'countries': ['United States'],
#   'num_val_box_office': 17500000.0,
#   '_id': ObjectId('67bc98e135a9409ecd46d074'),
#   'id': 65},
#  {'title': 'Swiss Family Robinson',
#   'link': 'https://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.org/wiki/Swiss_Family_Robinson_(1960_film)',
#   'release_year': 1960,
#   'directors': ['Ken Annakin'],
#   'box_office': '40 million $',
#   'countries': ['United States'],
#   'num_val_box_office': 40000000.0,
#   '_id': ObjectId('67bc98e135a9409ecd46d075'),
#   'id': 66},
#  {'title': 'Mister Roberts',
#   'link': 'https://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.org/wiki/Mister_Roberts_(1955_film)',
#   'release_year': 1955,
#   'directors': ['John Ford', 'Mervyn LeRoy', 'Joshua Logan'],
#   'box_office': '21.2 million $',
#   'countries': ['United States'],
#   'num_val_box_office': 21200000.0,
#   '_id': ObjectId('67bc98e135a9409ecd46d076'),
#   'id': 67},
#  {'title': 'Spartacus',
#   'link': 'https://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.org/wiki/Spartacus_(film)',
#   'release_year': 1960,
#   'directors': ['Stanley Kubrick'],
#   'box_office': '60 million $',
#   'countries': ['United States'],
#   'num_val_box_office': 60000000.0,
#   '_id': ObjectId('67bc98e135a9409ecd46d077'),
#   'id': 68},
#  {'title': 'The Robe',
#   'link': 'https://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.org/wiki/The_Robe_(film)',
#   'release_year': 1953,
#   'directors': ['Henry Koster'],
#   'box_office': '36 million $',
#   'countries': ['United States'],
#   'num_val_box_office': 36000000.0,
#   '_id': ObjectId('67bc98e135a9409ecd46d078'),
#   'id': 69},
#  {'title': 'Cinerama Holiday',
#   'link': 'https://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.org/wiki/Cinerama_Holiday',
#   'release_year': 1955,
#   'directors': ['Robert L. Bendick', 'Philippe De Lacy'],
#   'box_office': '29.6 million $',
#   'countries': ['United States'],
#   'num_val_box_office': 29600000.0,
#   '_id': ObjectId('67bc98e135a9409ecd46d079'),
#   'id': 70},
#  {'title': '20,000 Leagues Under the Sea',
#   'link': 'https://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.org/wiki/20,000_Leagues_Under_the_Sea_(1954_film)',
#   'release_year': 1954,
#   'directors': ['Richard Fleischer'],
#   'box_office': '28.2 million $',
#   'countries': ['United States'],
#   'num_val_box_office': 28200000.0,
#   '_id': ObjectId('67bc98e135a9409ecd46d07a'),
#   'id': 71},
#  {'title': 'White Christmas',
#   'link': 'https://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.org/wiki/White_Christmas_(film)',
#   'release_year': 1954,
#   'directors': ['Michael Curtiz'],
#   'box_office': '30 million $',
#   'countries': ['United States'],
#   'num_val_box_office': 30000000.0,
#   '_id': ObjectId('67bc98e135a9409ecd46d07b'),
#   'id': 72},
#  {'title': 'Rear Window',
#   'link': 'https://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.org/wiki/Rear_Window',
#   'release_year': 1954,
#   'directors': ['Alfred Hitchcock'],
#   'box_office': '37 million $',
#   'countries': ['United States'],
#   'num_val_box_office': 37000000.0,
#   '_id': ObjectId('67bc98e135a9409ecd46d07c'),
#   'id': 73},
#  {'title': 'The Greatest Show on Earth',
#   'link': 'https://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.org/wiki/The_Greatest_Show_on_Earth_(film)',
#   'release_year': 1952,
#   'directors': ['Cecil B. DeMille'],
#   'box_office': '36 million $',
#   'countries': ['United States'],
#   'num_val_box_office': 36000000.0,
#   '_id': ObjectId('67bc98e135a9409ecd46d07d'),
#   'id': 74},
#  {'title': 'Peter Pan',
#   'link': 'https://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.org/wiki/Peter_Pan_(1953_film)',
#   'release_year': 1953,
#   'directors': ['Hamilton Luske', 'Clyde Geronimi', 'Wilfred Jackson'],
#   'box_office': '87.4 million $',
#   'countries': ['United States'],
#   'num_val_box_office': 87400000.0,
#   '_id': ObjectId('67bc98e135a9409ecd46d07e'),
#   'id': 75},
#  {'title': 'Lady and the Tramp',
#   'link': 'https://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.org/wiki/Lady_and_the_Tramp',
#   'release_year': 1955,
#   'directors': ['Hamilton Luske', 'Clyde Geronimi', 'Wilfred Jackson'],
#   'box_office': '187 million $',
#   'countries': ['United States'],
#   'num_val_box_office': 187000000.0,
#   '_id': ObjectId('67bc98e135a9409ecd46d07f'),
#   'id': 76},
#  {'title': 'This Is Cinerama',
#   'link': 'https://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.org/wiki/This_Is_Cinerama',
#   'release_year': 1952,
#   'directors': ['Mike Todd', 'Michael Todd, Jr.'],
#   'box_office': '41.6 million $',
#   'countries': ['United States'],
#   'num_val_box_office': 41600000.0,
#   '_id': ObjectId('67bc98e135a9409ecd46d080'),
#   'id': 77},
#  {'title': 'Quo Vadis',
#   'link': 'https://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.org/wiki/Quo_Vadis_(1951_film)',
#   'release_year': 1951,
#   'directors': ['Mervyn LeRoy'],
#   'box_office': '21 million $',
#   'countries': ['United States'],
#   'num_val_box_office': 21000000.0,
#   '_id': ObjectId('67bc98e135a9409ecd46d081'),
#   'id': 78},
#  {'title': "King Solomon's Mines",
#   'link': 'https://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.org/wiki/King_Solomon%27s_Mines_(1950_film)',
#   'release_year': 1950,
#   'directors': ['Compton Bennett', 'Andrew Marton'],
#   'box_office': '15.1 million $',
#   'countries': ['United States'],
#   'num_val_box_office': 15100000.0,
#   '_id': ObjectId('67bc98e135a9409ecd46d082'),
#   'id': 79},
#  {'title': 'Samson and Delilah',
#   'link': 'https://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.org/wiki/Samson_and_Delilah_(1949_film)',
#   'release_year': 1949,
#   'directors': ['Cecil B. DeMille'],
#   'box_office': '25.6 million $',
#   'countries': ['United States'],
#   'num_val_box_office': 25600000.0,
#   '_id': ObjectId('67bc98e135a9409ecd46d083'),
#   'id': 80},
#  {'title': 'The Snake Pit',
#   'link': 'https://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.org/wiki/The_Snake_Pit',
#   'release_year': 1948,
#   'directors': ['Anatole Litvak'],
#   'box_office': '10 million $',
#   'countries': ['United States'],
#   'num_val_box_office': 10000000.0,
#   '_id': ObjectId('67bc98e135a9409ecd46d084'),
#   'id': 81},
#  {'title': 'Cinderella',
#   'link': 'https://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.org/wiki/Cinderella_(1950_film)',
#   'release_year': 1950,
#   'directors': ['Wilfred Jackson', 'Hamilton Luske', 'Clyde Geronimi'],
#   'box_office': '182 million $',
#   'countries': ['United States'],
#   'num_val_box_office': 182000000.0,
#   '_id': ObjectId('67bc98e135a9409ecd46d085'),
#   'id': 82},
#  {'title': 'Unconquered',
#   'link': 'https://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.org/wiki/Unconquered_(1947_film)',
#   'release_year': 1947,
#   'directors': ['Cecil B. DeMille'],
#   'box_office': '6.665592 million $',
#   'countries': ['United States'],
#   'num_val_box_office': 6665592.0,
#   '_id': ObjectId('67bc98e135a9409ecd46d086'),
#   'id': 83},
#  {'title': 'Forever Amber',
#   'link': 'https://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.org/wiki/Forever_Amber_(film)',
#   'release_year': 1947,
#   'directors': ['Otto Preminger', 'John M. Stahl'],
#   'box_office': '5 million $',
#   'countries': ['United States'],
#   'num_val_box_office': 5000000.0,
#   '_id': ObjectId('67bc98e135a9409ecd46d087'),
#   'id': 84},
#  {'title': 'Easter Parade',
#   'link': 'https://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.org/wiki/Easter_Parade_(film)',
#   'release_year': 1948,
#   'directors': ['Charles Walters'],
#   'box_office': '6.8 million $',
#   'countries': ['United States'],
#   'num_val_box_office': 6800000.0,
#   '_id': ObjectId('67bc98e135a9409ecd46d088'),
#   'id': 85},
#  {'title': 'The Red Shoes',
#   'link': 'https://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.org/wiki/The_Red_Shoes_(1948_film)',
#   'release_year': 1948,
#   'directors': ['Michael Powell', 'Emeric Pressburger'],
#   'box_office': '5 million $',
#   'countries': ['United Kingdom'],
#   'num_val_box_office': 5000000.0,
#   '_id': ObjectId('67bc98e135a9409ecd46d089'),
#   'id': 86},
#  {'title': 'Duel in the Sun',
#   'link': 'https://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.org/wiki/Duel_in_the_Sun_(film)',
#   'release_year': 1946,
#   'directors': ['King Vidor'],
#   'box_office': '20.4 million $',
#   'countries': ['United States'],
#   'num_val_box_office': 20400000.0,
#   '_id': ObjectId('67bc98e135a9409ecd46d08a'),
#   'id': 87},
#  {'title': 'The Best Years of Our Lives',
#   'link': 'https://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.org/wiki/The_Best_Years_of_Our_Lives',
#   'release_year': 1946,
#   'directors': ['William Wyler'],
#   'box_office': '23.7 million $',
#   'countries': ['United States'],
#   'num_val_box_office': 23700000.0,
#   '_id': ObjectId('67bc98e135a9409ecd46d08b'),
#   'id': 88},
#  {'title': 'Song of the South',
#   'link': 'https://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.org/wiki/Song_of_the_South',
#   'release_year': 1946,
#   'directors': ['Wilfred Jackson'],
#   'box_office': '65 million $',
#   'countries': ['United States'],
#   'num_val_box_office': 65000000.0,
#   '_id': ObjectId('67bc98e135a9409ecd46d08c'),
#   'id': 89},
#  {'title': 'Mom and Dad',
#   'link': 'https://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.org/wiki/Mom_and_Dad_(1945_film)',
#   'release_year': 1945,
#   'directors': ['William Beaudine'],
#   'box_office': '100 million $',
#   'countries': ['United States'],
#   'num_val_box_office': 100000000.0,
#   '_id': ObjectId('67bc98e135a9409ecd46d08d'),
#   'id': 90},
#  {'title': 'Going My Way',
#   'link': 'https://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.org/wiki/Going_My_Way',
#   'release_year': 1944,
#   'directors': ['Leo McCarey'],
#   'box_office': '6.5 million $',
#   'countries': ['United States'],
#   'num_val_box_office': 6500000.0,
#   '_id': ObjectId('67bc98e135a9409ecd46d08e'),
#   'id': 91},
#  {'title': 'This Is the Army',
#   'link': 'https://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.org/wiki/This_Is_the_Army',
#   'release_year': 1943,
#   'directors': ['Michael Curtiz', '1'],
#   'box_office': '10.445 million $',
#   'countries': ['United States'],
#   'num_val_box_office': 10445000.0,
#   '_id': ObjectId('67bc98e135a9409ecd46d08f'),
#   'id': 92},
#  {'title': 'For Whom the Bell Tolls',
#   'link': 'https://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.org/wiki/For_Whom_the_Bell_Tolls_(film)',
#   'release_year': 1943,
#   'directors': ['Sam Wood'],
#   'box_office': '17.8 million $',
#   'countries': ['United States'],
#   'num_val_box_office': 17800000.0,
#   '_id': ObjectId('67bc98e135a9409ecd46d090'),
#   'id': 93},
#  {'title': 'Mrs. Miniver',
#   'link': 'https://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.org/wiki/Mrs._Miniver',
#   'release_year': 1942,
#   'directors': ['William Wyler'],
#   'box_office': '8.9 million $',
#   'countries': ['United States'],
#   'num_val_box_office': 8900000.0,
#   '_id': ObjectId('67bc98e135a9409ecd46d091'),
#   'id': 94},
#  {'title': "The Bells of St. Mary's",
#   'link': 'https://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.org/wiki/The_Bells_of_St._Mary%27s',
#   'release_year': 1945,
#   'directors': ['Leo McCarey'],
#   'box_office': '21.3 million $',
#   'countries': ['United States'],
#   'num_val_box_office': 21300000.0,
#   '_id': ObjectId('67bc98e135a9409ecd46d092'),
#   'id': 95},
#  {'title': 'Bambi',
# ...
#   'directors': ['George Lucas'],
#   'box_office': '1.047 billion $',
#   'countries': ['United States'],
#   'num_val_box_office': 1046999999.9999999,
#   '_id': ObjectId('67bc98e135a9409ecd46d0bf'),
#   'id': 140},
#  {'title': 'Aladdin',
#   'link': 'https://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.org/wiki/Aladdin_(2019_film)',
#   'release_year': 2019,
#   'directors': ['Guy Ritchie'],
#   'box_office': '1.054 billion $',
#   'countries': ['United States'],
#   'num_val_box_office': 1054000000.0,
#   '_id': ObjectId('67bc98e135a9409ecd46d0c0'),
#   'id': 141},
#  {'title': 'Ben-Hur',
#   'link': 'https://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.org/wiki/Ben-Hur_(1925_film)',
#   'release_year': 1925,
#   'directors': ['Fred Niblo', 'Charles Brabin'],
#   'box_office': '10.7 million $',
#   'countries': ['United States'],
#   'num_val_box_office': 10700000.0,
#   '_id': ObjectId('67bc98e135a9409ecd46d0c1'),
#   'id': 142},
#  {'title': "Pirates of the Caribbean: Dead Man's Chest",
#   'link': 'https://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.org/wiki/Pirates_of_the_Caribbean:_Dead_Man%27s_Chest',
#   'release_year': 2006,
#   'directors': ['Gore Verbinski'],
#   'box_office': '1.066 billion $',
#   'countries': ['United States'],
#   'num_val_box_office': 1066000000.0,
#   '_id': ObjectId('67bc98e135a9409ecd46d0c2'),
#   'id': 143},
#  {'title': 'Rogue One: A Star Wars Story',
#   'link': 'https://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.org/wiki/Rogue_One:_A_Star_Wars_Story',
#   'release_year': 2016,
#   'directors': ['Gareth Edwards'],
#   'box_office': '1.059 billion $',
#   'countries': ['United States'],
#   'num_val_box_office': 1059000000.0,
#   '_id': ObjectId('67bc98e135a9409ecd46d0c3'),
#   'id': 144},
#  {'title': 'Toy Story 3',
#   'link': 'https://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.org/wiki/Toy_Story_3',
#   'release_year': 2010,
#   'directors': ['Lee Unkrich'],
#   'box_office': '1.067 billion $',
#   'countries': ['United States'],
#   'num_val_box_office': 1067000000.0,
#   '_id': ObjectId('67bc98e135a9409ecd46d0c4'),
#   'id': 145},
#  {'title': 'Toy Story 4',
#   'link': 'https://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.org/wiki/Toy_Story_4',
#   'release_year': 2019,
#   'directors': ['Josh Cooley'],
#   'box_office': '1.074 billion $',
#   'countries': ['United States'],
#   'num_val_box_office': 1074000000.0,
#   '_id': ObjectId('67bc98e135a9409ecd46d0c5'),
#   'id': 146},
#  {'title': 'Star Wars: The Rise of Skywalker',
#   'link': 'https://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.org/wiki/Star_Wars:_The_Rise_of_Skywalker',
#   'release_year': 2019,
#   'directors': ['J. J. Abrams'],
#   'box_office': '1.077 billion $',
#   'countries': ['United States'],
#   'num_val_box_office': 1077000000.0,
#   '_id': ObjectId('67bc98e135a9409ecd46d0c6'),
#   'id': 147},
#  {'title': 'Transformers: Age of Extinction',
#   'link': 'https://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.org/wiki/Transformers:_Age_of_Extinction',
#   'release_year': 2014,
#   'directors': ['Michael Bay'],
#   'box_office': '1.104 billion $',
#   'countries': ['United States'],
#   'num_val_box_office': 1104000000.0,
#   '_id': ObjectId('67bc98e135a9409ecd46d0c7'),
#   'id': 148},
#  {'title': 'Skyfall',
#   'link': 'https://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.org/wiki/Skyfall',
#   'release_year': 2012,
#   'directors': ['Sam Mendes'],
#   'box_office': '1.109 billion $',
#   'countries': ['United Kingdom', 'United States'],
#   'num_val_box_office': 1109000000.0,
#   '_id': ObjectId('67bc98e135a9409ecd46d0c8'),
#   'id': 149},
#  {'title': 'Transformers: Dark of the Moon',
#   'link': 'https://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.org/wiki/Transformers:_Dark_of_the_Moon',
#   'release_year': 2011,
#   'directors': ['Michael Bay'],
#   'box_office': '1.124 billion $',
#   'countries': ['United States'],
#   'num_val_box_office': 1124000000.0,
#   '_id': ObjectId('67bc98e135a9409ecd46d0c9'),
#   'id': 150},
#  {'title': 'Spider-Man: Far From Home',
#   'link': 'https://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.org/wiki/Spider-Man:_Far_From_Home',
#   'release_year': 2019,
#   'directors': ['Jon Watts'],
#   'box_office': '1.133 billion $',
#   'countries': ['United States'],
#   'num_val_box_office': 1133000000.0,
#   '_id': ObjectId('67bc98e135a9409ecd46d0ca'),
#   'id': 151},
#  {'title': 'The Dark Knight Rises',
#   'link': 'https://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.org/wiki/The_Dark_Knight_Rises',
#   'release_year': 2012,
#   'directors': ['Christopher Nolan'],
#   'box_office': '1.115 billion $',
#   'countries': ['United States', 'United Kingdom'],
#   'num_val_box_office': 1115000000.0,
#   '_id': ObjectId('67bc98e135a9409ecd46d0cb'),
#   'id': 152},
#  {'title': 'Joker',
#   'link': 'https://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.org/wiki/Joker_(2019_film)',
#   'release_year': 2019,
#   'directors': ['Todd Phillips'],
#   'box_office': '1.079 billion $',
#   'countries': ['United States'],
#   'num_val_box_office': 1079000000.0,
#   '_id': ObjectId('67bc98e135a9409ecd46d0cc'),
#   'id': 153},
#  {'title': 'Captain Marvel',
#   'link': 'https://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.org/wiki/Captain_Marvel_(film)',
#   'release_year': 2019,
#   'directors': ['Anna Boden', 'Ryan Fleck'],
#   'box_office': '1.131 billion $',
#   'countries': ['United States'],
#   'num_val_box_office': 1131000000.0,
#   '_id': ObjectId('67bc98e135a9409ecd46d0cd'),
#   'id': 154},
#  {'title': 'Aquaman',
#   'link': 'https://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.org/wiki/Aquaman_(film)',
#   'release_year': 2018,
#   'directors': ['James Wan'],
#   'box_office': '1.152 billion $',
#   'countries': ['United States'],
#   'num_val_box_office': 1152000000.0,
#   '_id': ObjectId('67bc98e135a9409ecd46d0ce'),
#   'id': 155},
#  {'title': 'Top Gun: Maverick',
#   'link': 'https://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.org/wiki/Top_Gun:_Maverick',
#   'release_year': 2022,
#   'directors': ['Joseph Kosinski'],
#   'box_office': '1.496 billion $',
#   'countries': ['United States'],
#   'num_val_box_office': 1496000000.0,
#   '_id': ObjectId('67bc98e135a9409ecd46d0cf'),
#   'id': 156},
#  {'title': 'The Lord of the Rings: The Return of the King',
#   'link': 'https://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.org/wiki/The_Lord_of_the_Rings:_The_Return_of_the_King',
#   'release_year': 2003,
#   'directors': ['Peter Jackson'],
#   'box_office': '1.151 billion $',
#   'countries': ['New Zealand', 'Germany', 'United States'],
#   'num_val_box_office': 1151000000.0,
#   '_id': ObjectId('67bc98e135a9409ecd46d0d0'),
#   'id': 157},
#  {'title': 'The Lion King',
#   'link': 'https://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.org/wiki/The_Lion_King_(2019_film)',
#   'release_year': 2019,
#   'directors': ['Jon Favreau'],
#   'box_office': '1.657 billion $',
#   'countries': ['United States'],
#   'num_val_box_office': 1657000000.0,
#   '_id': ObjectId('67bc98e135a9409ecd46d0d1'),
#   'id': 158},
#  {'title': 'Jurassic World',
#   'link': 'https://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.org/wiki/Jurassic_World',
#   'release_year': 2015,
#   'directors': ['Colin Trevorrow'],
#   'box_office': '1.671 billion $',
#   'countries': ['United States'],
#   'num_val_box_office': 1671000000.0,
#   '_id': ObjectId('67bc98e135a9409ecd46d0d2'),
#   'id': 159},
#  {'title': 'The Avengers',
#   'link': 'https://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.org/wiki/The_Avengers_(2012_film)',
#   'release_year': 2012,
#   'directors': ['Joss Whedon'],
#   'box_office': '1.521 billion $',
#   'countries': ['United States'],
#   'num_val_box_office': 1521000000.0,
#   '_id': ObjectId('67bc98e135a9409ecd46d0d3'),
#   'id': 160},
#  {'title': 'Ne Zha 2',
#   'link': 'https://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.org/wiki/Ne_Zha_2',
#   'release_year': 2025,
#   'directors': ['Jiaozi'],
#   'box_office': '1.87 billion $',
#   'countries': ['China'],
#   'num_val_box_office': 1870000000.0,
#   '_id': ObjectId('67bc98e135a9409ecd46d0d4'),
#   'id': 161},
#  {'title': 'Inside Out 2',
#   'link': 'https://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.org/wiki/Inside_Out_2',
#   'release_year': 2024,
#   'directors': ['Kelsey Mann'],
#   'box_office': '1.699 billion $',
#   'countries': ['United States'],
#   'num_val_box_office': 1699000000.0,
#   '_id': ObjectId('67bc98e135a9409ecd46d0d5'),
#   'id': 162},
#  {'title': 'Spider-Man: No Way Home',
#   'link': 'https://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.org/wiki/Spider-Man:_No_Way_Home',
#   'release_year': 2021,
#   'directors': ['Jon Watts'],
#   'box_office': '1.953 billion $',
#   'countries': ['United States'],
#   'num_val_box_office': 1953000000.0,
#   '_id': ObjectId('67bc98e135a9409ecd46d0d6'),
#   'id': 163},
#  {'title': 'Star Wars: The Force Awakens',
#   'link': 'https://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.org/wiki/Star_Wars:_The_Force_Awakens',
#   'release_year': 2015,
#   'directors': ['J. J. Abrams'],
#   'box_office': '2.07 billion $',
#   'countries': ['United States'],
#   'num_val_box_office': 2069999999.9999998,
#   '_id': ObjectId('67bc98e135a9409ecd46d0d7'),
#   'id': 164},
#  {'title': 'Titanic',
#   'link': 'https://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.org/wiki/Titanic_(1997_film)',
#   'release_year': 1997,
#   'directors': ['James Cameron'],
#   'box_office': '2.264 billion $',
#   'countries': ['United States'],
#   'num_val_box_office': 2264000000.0,
#   '_id': ObjectId('67bc98e135a9409ecd46d0d8'),
#   'id': 165},
#  {'title': 'Avatar: The Way of Water',
#   'link': 'https://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.org/wiki/Avatar:_The_Way_of_Water',
#   'release_year': 2022,
#   'directors': ['James Cameron'],
#   'box_office': '2.320 billion $',
#   'countries': ['United States'],
#   'num_val_box_office': 2320000000.0,
#   '_id': ObjectId('67bc98e135a9409ecd46d0d9'),
#   'id': 166},
#  {'title': 'Moonraker',
#   'link': 'https://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.org/wiki/Moonraker_(film)',
#   'release_year': 1979,
#   'directors': ['Lewis Gilbert'],
#   'box_office': '210.3 million $',
#   'countries': ['United Kingdom', 'United States', 'France'],
#   'num_val_box_office': 210300000.0,
#   '_id': ObjectId('67bc98e135a9409ecd46d0da'),
#   'id': 167},
#  {'title': 'Diamonds Are Forever',
#   'link': 'https://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.org/wiki/Diamonds_Are_Forever_(film)',
#   'release_year': 1971,
#   'directors': ['Guy Hamilton'],
#   'box_office': '116 million $',
#   'countries': ['United Kingdom', 'United States'],
#   'num_val_box_office': 116000000.0,
#   '_id': ObjectId('67bc98e135a9409ecd46d0db'),
#   'id': 168},
#  {'title': 'The Bible: In the Beginning',
#   'link': 'https://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.org/wiki/The_Bible:_In_the_Beginning',
#   'release_year': 1966,
#   'directors': ['John Huston'],
#   'box_office': '34.9 million $',
#   'countries': ['Italy', 'United States'],
#   'num_val_box_office': 34900000.0,
#   '_id': ObjectId('67bc98e135a9409ecd46d0dc'),
#   'id': 169},
#  {'title': 'From Russia with Love',
#   'link': 'https://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.org/wiki/From_Russia_with_Love_(film)',
#   'release_year': 1963,
#   'directors': ['Terence Young'],
#   'box_office': '79 million $',
#   'countries': ['United Kingdom', 'United States'],
#   'num_val_box_office': 79000000.0,
#   '_id': ObjectId('67bc98e135a9409ecd46d0dd'),
#   'id': 170},
#  {'title': 'Goldfinger',
#   'link': 'https://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.org/wiki/Goldfinger_(film)',
#   'release_year': 1964,
#   'directors': ['Guy Hamilton'],
#   'box_office': '125 million $',
#   'countries': ['United Kingdom', 'United States'],
#   'num_val_box_office': 125000000.0,
#   '_id': ObjectId('67bc98e135a9409ecd46d0de'),
#   'id': 171},
#  {'title': 'Lawrence of Arabia',
#   'link': 'https://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.org/wiki/Lawrence_of_Arabia_(film)',
#   'release_year': 1962,
#   'directors': ['David Lean'],
#   'box_office': '70 million $',
#   'countries': ['United Kingdom', 'United States'],
#   'num_val_box_office': 70000000.0,
#   '_id': ObjectId('67bc98e135a9409ecd46d0df'),
#   'id': 172},
#  {'title': 'The Bridge on the River Kwai',
#   'link': 'https://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.org/wiki/The_Bridge_on_the_River_Kwai',
#   'release_year': 1957,
#   'directors': ['David Lean'],
#   'box_office': '30.6 million $',
#   'countries': ['United Kingdom', 'United States'],
#   'num_val_box_office': 30600000.0,
#   '_id': ObjectId('67bc98e135a9409ecd46d0e0'),
#   'id': 173},
#  {'title': 'Captain America: Civil War',
#   'link': 'https://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.org/wiki/Captain_America:_Civil_War',
#   'release_year': 2016,
#   'directors': ['Anthony Russo', 'Joe Russo'],
#   'box_office': '1.155 billion $',
#   'countries': ['United States'],
#   'num_val_box_office': 1155000000.0,
#   '_id': ObjectId('67bc98e135a9409ecd46d0e1'),
#   'id': 174},
#  {'title': 'Furious 7',
#   'link': 'https://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.org/wiki/Furious_7',
#   'release_year': 2015,
#   'directors': ['James Wan'],
#   'box_office': '1.515 billion $',
#   'countries': ['United States', 'China'],
#   'num_val_box_office': 1515000000.0,
#   '_id': ObjectId('67bc98e135a9409ecd46d0e2'),
#   'id': 175},
#  {'title': 'Avengers: Endgame',
#   'link': 'https://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.org/wiki/Avengers:_Endgame',
#   'release_year': 2019,
#   'directors': ['Anthony Russo', 'Joe Russo'],
#   'box_office': '2.799 billion $',
#   'countries': ['United States'],
#   'num_val_box_office': 2799000000.0,
#   '_id': ObjectId('67bc98e135a9409ecd46d0e3'),
#   'id': 176},
#  {'title': 'Avengers: Infinity War',
#   'link': 'https://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.orghttps://en.wikipedia.org/wiki/Avengers:_Infinity_War',
#   'release_year': 2018,
#   'directors': ['Anthony Russo', 'Joe Russo'],
#   'box_office': '2.052 billion $',
#   'countries': ['United States'],
#   'num_val_box_office': 2052000000.0,
#   '_id': ObjectId('67bc98e135a9409ecd46d0e4'),
#   'id': 177}]

# %% [markdown]
# # Database setup

# %% [markdown]
# ## Changes in structure
#
# ### Title - same as in PDF
# ### Release_year - same as in PDF
# ### director - list of strings
# ### box_office - same as in PDF
# ### num_val_box_office - numeric value of box office
# ### link to the resource - added
# ### countries - list of origin countries

# %%
# !pip install pymongo
#!pip install --upgrade pymongo
#!pip install pymongo==3.4.0
#!python -m pip install "pymongo[srv]"
# Out:
# Requirement already satisfied: pymongo in c:\users\rails\appdata\local\programs\python\python312\lib\site-packages (4.11)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in c:\users\rails\appdata\local\programs\python\python312\lib\site-packages (from pymongo) (2.7.0)
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: C:\Users\rails\AppData\Local\Programs\Python\Python312\python.exe -m pip install --upgrade pip

# %%
from pymongo import MongoClient


username = "karma"
password = "myPass123"
URL = "@dwassignment1.ycohu.mongodb.net/?retryWrites=true&w=majority&appName=DWAssignment1"

mongo_uri = f"mongodb+srv://{username}:{password}{URL}"

client = MongoClient(mongo_uri)

# %%
try:
    client.admin.command("ping")
    print("Successfully connected to the server!")
except Exception as e:
    print(f"Failed to connect: {e}")
# Out:
# Successfully connected to the server!

# %%
db = client['films_database']
films_collection = db['films']

# %%
result = films_collection.delete_many({})

# %%
films_collection.insert_many(cleaned_entries)
# Out:
# InsertManyResult([ObjectId('67bc98e135a9409ecd46d034'), ObjectId('67bc98e135a9409ecd46d035'), ObjectId('67bc98e135a9409ecd46d036'), ObjectId('67bc98e135a9409ecd46d037'), ObjectId('67bc98e135a9409ecd46d038'), ObjectId('67bc98e135a9409ecd46d039'), ObjectId('67bc98e135a9409ecd46d03a'), ObjectId('67bc98e135a9409ecd46d03b'), ObjectId('67bc98e135a9409ecd46d03c'), ObjectId('67bc98e135a9409ecd46d03d'), ObjectId('67bc98e135a9409ecd46d03e'), ObjectId('67bc98e135a9409ecd46d03f'), ObjectId('67bc98e135a9409ecd46d040'), ObjectId('67bc98e135a9409ecd46d041'), ObjectId('67bc98e135a9409ecd46d042'), ObjectId('67bc98e135a9409ecd46d043'), ObjectId('67bc98e135a9409ecd46d044'), ObjectId('67bc98e135a9409ecd46d045'), ObjectId('67bc98e135a9409ecd46d046'), ObjectId('67bc98e135a9409ecd46d047'), ObjectId('67bc98e135a9409ecd46d048'), ObjectId('67bc98e135a9409ecd46d049'), ObjectId('67bc98e135a9409ecd46d04a'), ObjectId('67bc98e135a9409ecd46d04b'), ObjectId('67bc98e135a9409ecd46d04c'), ObjectId('67bc98e135a9409ecd46d04d'), ObjectId('67bc98e135a9409ecd46d04e'), ObjectId('67bc98e135a9409ecd46d04f'), ObjectId('67bc98e135a9409ecd46d050'), ObjectId('67bc98e135a9409ecd46d051'), ObjectId('67bc98e135a9409ecd46d052'), ObjectId('67bc98e135a9409ecd46d053'), ObjectId('67bc98e135a9409ecd46d054'), ObjectId('67bc98e135a9409ecd46d055'), ObjectId('67bc98e135a9409ecd46d056'), ObjectId('67bc98e135a9409ecd46d057'), ObjectId('67bc98e135a9409ecd46d058'), ObjectId('67bc98e135a9409ecd46d059'), ObjectId('67bc98e135a9409ecd46d05a'), ObjectId('67bc98e135a9409ecd46d05b'), ObjectId('67bc98e135a9409ecd46d05c'), ObjectId('67bc98e135a9409ecd46d05d'), ObjectId('67bc98e135a9409ecd46d05e'), ObjectId('67bc98e135a9409ecd46d05f'), ObjectId('67bc98e135a9409ecd46d060'), ObjectId('67bc98e135a9409ecd46d061'), ObjectId('67bc98e135a9409ecd46d062'), ObjectId('67bc98e135a9409ecd46d063'), ObjectId('67bc98e135a9409ecd46d064'), ObjectId('67bc98e135a9409ecd46d065'), ObjectId('67bc98e135a9409ecd46d066'), ObjectId('67bc98e135a9409ecd46d067'), ObjectId('67bc98e135a9409ecd46d068'), ObjectId('67bc98e135a9409ecd46d069'), ObjectId('67bc98e135a9409ecd46d06a'), ObjectId('67bc98e135a9409ecd46d06b'), ObjectId('67bc98e135a9409ecd46d06c'), ObjectId('67bc98e135a9409ecd46d06d'), ObjectId('67bc98e135a9409ecd46d06e'), ObjectId('67bc98e135a9409ecd46d06f'), ObjectId('67bc98e135a9409ecd46d070'), ObjectId('67bc98e135a9409ecd46d071'), ObjectId('67bc98e135a9409ecd46d072'), ObjectId('67bc98e135a9409ecd46d073'), ObjectId('67bc98e135a9409ecd46d074'), ObjectId('67bc98e135a9409ecd46d075'), ObjectId('67bc98e135a9409ecd46d076'), ObjectId('67bc98e135a9409ecd46d077'), ObjectId('67bc98e135a9409ecd46d078'), ObjectId('67bc98e135a9409ecd46d079'), ObjectId('67bc98e135a9409ecd46d07a'), ObjectId('67bc98e135a9409ecd46d07b'), ObjectId('67bc98e135a9409ecd46d07c'), ObjectId('67bc98e135a9409ecd46d07d'), ObjectId('67bc98e135a9409ecd46d07e'), ObjectId('67bc98e135a9409ecd46d07f'), ObjectId('67bc98e135a9409ecd46d080'), ObjectId('67bc98e135a9409ecd46d081'), ObjectId('67bc98e135a9409ecd46d082'), ObjectId('67bc98e135a9409ecd46d083'), ObjectId('67bc98e135a9409ecd46d084'), ObjectId('67bc98e135a9409ecd46d085'), ObjectId('67bc98e135a9409ecd46d086'), ObjectId('67bc98e135a9409ecd46d087'), ObjectId('67bc98e135a9409ecd46d088'), ObjectId('67bc98e135a9409ecd46d089'), ObjectId('67bc98e135a9409ecd46d08a'), ObjectId('67bc98e135a9409ecd46d08b'), ObjectId('67bc98e135a9409ecd46d08c'), ObjectId('67bc98e135a9409ecd46d08d'), ObjectId('67bc98e135a9409ecd46d08e'), ObjectId('67bc98e135a9409ecd46d08f'), ObjectId('67bc98e135a9409ecd46d090'), ObjectId('67bc98e135a9409ecd46d091'), ObjectId('67bc98e135a9409ecd46d092'), ObjectId('67bc98e135a9409ecd46d093'), ObjectId('67bc98e135a9409ecd46d094'), ObjectId('67bc98e135a9409ecd46d095'), ObjectId('67bc98e135a9409ecd46d096'), ObjectId('67bc98e135a9409ecd46d097'), ObjectId('67bc98e135a9409ecd46d098'), ObjectId('67bc98e135a9409ecd46d099'), ObjectId('67bc98e135a9409ecd46d09a'), ObjectId('67bc98e135a9409ecd46d09b'), ObjectId('67bc98e135a9409ecd46 ...

# %% [markdown]
# # Export DB to JSON

# %%
from pymongo import MongoClient

username = "karma"
password = "myPass123"
URL = "@dwassignment1.ycohu.mongodb.net/?retryWrites=true&w=majority&appName=DWAssignment1"

mongo_uri = f"mongodb+srv://{username}:{password}{URL}"

client = MongoClient(mongo_uri)

# %%
try:
    client.admin.command("ping")
    print("Successfully connected to the server!")
except Exception as e:
    print(f"Failed to connect: {e}")
# Out:
# Successfully connected to the server!

# %%
db = client['films_database']
films_collection = db['films']

# %%
documents = list(films_collection.find())

# %%
for doc in documents:
    doc.pop('_id', None)

output_file_path = 'films_data.json'
with open(output_file_path, 'w', encoding='utf-8') as file:
    json.dump(documents, file, ensure_ascii=False, indent=4)

print(f"Exported {len(documents)} documents to {output_file_path}.")
# Out:
# Exported 177 documents to films_data.json.
